# %% [markdown]
# # Prepare the environment

# %%
# Connect to drive
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
HEAD_DIR = "/content/gdrive/MyDrive/MS_postprocess_code/specificity"

# %% [markdown]
# # ADJECTIVE SPECIFICITY

# %% [markdown]
# ## Prep
#
# ### Before executing, create an venv with either Python 3.9 or 3.10 and install nltk and numpy, as well as the wordnet package for nltk

# %%
# !pip install nltk
# !pip install numpy
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk) (8.2.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk) (1.5.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from nltk) (4.67.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/cli/base_command.py", line 179, in exc_logging_wrapper
#     status = run_func(*args)
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/cli/req_command.py", line 67, in wrapper
#     return func(self, options, args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/commands/install.py", line 447, in run
#     conflicts = self._determine_conflicts(to_install)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/commands/install.py", line 578, in _determine_conflicts
#     return check_install_conflicts(to_install)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/operations/check.py", line 101, in check_install_conflicts
#     package_set, _ = create_package_set_from_installed()
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/operations/check.py", line 43, in create_package_set_from_installed
#     package_set[name] = PackageDetails(dist.version, dependencies)
#                                        ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/metadata/importlib/_dists.py", line 175, in version
#     return parse_version(self._dist.version)
#                          ^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/importlib/metadata/__init__.py", line 632, in version
#     return self.metadata['Version']
#            ^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/importlib/metadata/__init__.py", line 617, in metadata
#     return _adapters.Message(email.message_from_string(text))
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/email/__init__.py", line 37, in message_from_string
#     return Parser(*args, **kws).parsestr(s)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/email/parser.py", line 67, in parsestr
#     return self.parse(StringIO(text), headersonly=headersonly)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/email/parser.py", line 56, in parse
#     feedparser.feed(data)
#   File "/usr/lib/python3.11/email/feedparser.py", line 174, in feed
#     self._call_parse()
#   File "/usr/lib/python3.11/email/feedparser.py", line 178, in _call_parse
#     self._parse()
#   File "/usr/lib/python3.11/email/feedparser.py", line 238, in _parsegen
#     self._parse_headers(headers)
#   File "/usr/lib/python3.11/email/feedparser.py", line 524, in _parse_headers
#     lastvalue = [line]
#     ^^^^^^^^^
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/bin/pip3", line 10, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/cli/main.py", line 80, in main
#     return command.main(cmd_args)
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/cli/base_command.py", line 100, in main
#     return self._main(args)
#            ^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/cli/base_command.py", line 232, in _main
#     return run(options, args)
#            ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/cli/base_command.py", line 215, in exc_logging_wrapper
#     logger.critical("Operation cancelled by user")
#   File "/usr/lib/python3.11/logging/__init__.py", line 1536, in critical
#     self._log(CRITICAL, msg, args, **kwargs)
#   File "/usr/lib/python3.11/logging/__init__.py", line 1634, in _log
#     self.handle(record)
#   File "/usr/lib/python3.11/logging/__init__.py", line 1644, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.11/logging/__init__.py", line 1706, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.11/logging/__init__.py", line 978, in handle
#     self.emit(record)
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/utils/logging.py", line 172, in emit
#     style = Style(color="red")
#             ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_vendor/rich/style.py", line 146, in __init__
#     def _make_color(color: Union[Color, str]) -> Color:
#                            ~~~~~^^^^^^^^^^^^
#   File "/usr/lib/python3.11/typing.py", line 376, in inner
#     return cached(*args, **kwds)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/typing.py", line 502, in __getitem__
#     return self._getitem(self, parameters)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/typing.py", line 716, in Union
#     parameters = _remove_dups_flatten(parameters)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/typing.py", line 347, in _remove_dups_flatten
#     return tuple(_deduplicate(params, unhashable_fallback=True))
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/typing.py", line 309, in _deduplicate
#     return dict.fromkeys(params)
#            ^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# ^C

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [markdown]
# ## Calculate the adjective specificity

# %%
from nltk.corpus import wordnet as wn
import numpy as np
import json

# %%
def calculate_adjective_specificity(adjective):
    """
    Calculates the specificity score of an adjective
    """
    synsets = wn.synsets(adjective, pos=wn.ADJ)
    if synsets:
        lemmas = set()
        antonyms = set()
        total_ssw = 0
        for synset in synsets:
            lemma_names = synset.lemma_names()
            for lemma in lemma_names:
                lemmas.add(lemma) ## crawls all lemmas of all synsets corresponding to the adjective
            for lemma in synset.lemmas():
                for antonym in lemma.antonyms():
                    antonyms.add(antonym) ## crawls all antonyms if all synsets and lemmas corresponding to the adjective
            ssw = sum(len(similar.lemmas()) for similar in synset.similar_tos()) ## Counts all semantic-similar synsets of the adjective
            total_ssw += ssw

        synonym_set_size = len(lemmas)
        antonym_number = len(antonyms)
        total_number_of_cluster = total_ssw + antonym_number + synonym_set_size
        if total_ssw != 0 or antonym_number != 0 or synonym_set_size != 0:
            specificity_score = 1/np.log(1+total_number_of_cluster+len(synsets)) ## Calculates the specificity score
        else:
            specificity_score = float("inf")
        return specificity_score
    else: return f"There are no synsets for the adjective: {adjective}"

# %% [markdown]
# # NOUN SPECIFICITY

# %%
import sys, os
from nltk.corpus import wordnet as wn
import csv

# %%
def create_folder(filepath):
    directory = os.path.dirname(filepath)
    if not os.path.exists(directory):
        os.makedirs(directory)


def read_ratings(inputf):

    ratings_nouns = {}
    with open(inputf, 'r') as fratings:
        fratings = csv.reader(fratings, delimiter='\t')
        next(fratings)
        for row in fratings:
            if row[8] == "Noun":
                rating_score = row[2].replace(',', '.')
                ratings_nouns[row[0]] = float(rating_score)

    return ratings_nouns

def wn_closure(noun, score):

    first_sense = wn.synsets(noun, pos='n')[0]

    """
    Get hypernym closures
    """

    hypernym_closure = lambda s:s.hypernyms()

    inherited_hypernyms = {}
    inherited_hypernyms[(first_sense, len(list(first_sense.closure(hypernym_closure))),)] = list(first_sense.closure(hypernym_closure))

    """
    Get hypernyms based on instance of relations
    """

    for synset, hyper_list in inherited_hypernyms.copy().items():
        if synset[1] == 0:
            hypo_instance_of = synset[0].instance_hypernyms()
            if len(hypo_instance_of) > 0:
                inherited_hypernyms.pop(synset, None)
                inherited_hypernyms[(synset[0], len(list(hypo_instance_of[0].closure(hypernym_closure))),)] = list(
                    hypo_instance_of[0].closure(hypernym_closure))
        else:
            continue

    """
    Depth from Entity node
    """
    depth_measure = {}
    for synset_depth_val, list_hypern in  inherited_hypernyms.items():
        depth_measure[noun] = float(synset_depth_val[1])
    print(depth_measure)

    """
    Group scores for correlations
    """
    group_scores = {}
    final_scores = {}

    for entry, values in depth_measure.items():
        # group_scores[entry] = (keywords[entry], values,)
        group_scores[entry] = (score, values,)

    for entry, scores in group_scores.items():
        human_judgement, depth = scores
        ladder = float(depth * 5) / float(20) # 20 is the max.depht (or max distance from entity node) in WN30
        final_scores[entry] = (human_judgement, depth, ladder)


    return final_scores

# %%
input_files = ["both_154_7879_160721_20_05_2025_features_concrete",
               #"both_154_7879_120801_20_05_2025_features",
               #"both_154_7879_121629_20_05_2025_plo_features"
               ]

# %%
with open(f"{HEAD_DIR}/{input_files[0]}.json") as f:
        wn_top_down_print = {}
        data_dict = json.load(f)
        for _, data in data_dict.items():
            for k in ("zero-shot", "few-shot"):
                if k not in data:
                    continue
                for vlm, answers in data[k].items():
                    if isinstance(answers, dict):
                        for i, w in enumerate(answers["concreteness_words"]):
                            if w[8] == "Adjective":
                                adj_score = calculate_adjective_specificity(w[0])
                                print(f"Adjective '{w[0]}' has specificity score ",adj_score)
                                # Add specificity score to the concreteness list for the iteration simplicity
                                answers["concreteness_words"][i][7] = adj_score

                            if w[8] == "Noun":
                                elem = w[0]
                                score = w[2]
                                wn_synsets = wn.synsets(elem, pos='n')
                                if len(wn_synsets) >=1:
                                    data_correlation = wn_closure(elem, score)
                                    wn_top_down_print.update(data_correlation)

        for _, data in data_dict.items():
            for k in ("zero-shot", "few-shot"):
                if k not in data:
                    continue
                for vlm, answers in data[k].items():
                    if isinstance(answers, dict):
                        for i, w in enumerate(answers["concreteness_words"]):
                            if w[8] == "Noun":
                                spec_val = []
                                for k, v in wn_top_down_print.items():
                                    rating_human, depth, specificity = v
                                    spec_val.append(float(specificity))

                                min_score = min(spec_val)
                                max_score = max(spec_val)

                                # final_scores = {}
                                try:
                                    rating_human, depth, specificity = wn_top_down_print[w[0]]
                                    normalized_score = ((specificity - min_score) / (max_score - min_score)) * (5.0 - 1.0) + 1.0
                                    answers["concreteness_words"][i][5] = rating_human
                                    answers["concreteness_words"][i][6] = depth
                                    answers["concreteness_words"][i][7] = normalized_score
                                # catch the nouns unknown to wordnet and ignore them
                                except KeyError:
                                    continue

with open(f"{HEAD_DIR}/{input_files[0]}_concrete_specific.json", "w") as f:
    json.dump(data_dict, f, indent=2)
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
# {'apartment': 7.0}
# Adjective 'generic' has specificity score  0.5138983423697507
# {'representation': 5.0}
# {'suspect': 8.0}
# Adjective 'real' has specificity score  0.28126641406272834
# {'news': 5.0}
# {'report': 6.0}
# Adjective 'different' has specificity score  0.2790553132756236
# {'person': 7.0}
# {'image': 6.0}
# {'caption': 8.0}
# {'ai': 8.0}
# Adjective 'contraband' has specificity score  0.48089834696298783
# {'good': 6.0}
# {'bread': 10.0}
# {'delivery': 9.0}
# Adjective 'fictional' has specificity score  0.45511961331341866
# {'scenario': 7.0}
# {'man': 10.0}
# Adjective 'consistent' has specificity score  0.3001016285004131
# Adjective 'real' has specificity score  0.28126641406272834
# {'world': 5.0}
# {'reporting': 6.0}
# {'image': 6.0}
# {'caption': 8.0}
# {'ai': 8.0}
# Adjective 'harmful' has specificity score  0.2835784920513334
# Adjective 'misleading' has specificity score  0.5138983423697507
# {'context': 6.0}
# Adjective 'fake' has specificity score  0.36067376022224085
# Adjective 'specific' has specificity score  0.3284587387530511
# {'individual': 7.0}
# {'location': 3.0}
# {'event': 3.0}
# {'snippet': 5.0}
# Adjective 'possible' has specificity score  0.31465798044412485
# {'contraband': 7.0}
# {'good': 6.0}
# {'bread': 10.0}
# {'delivery': 9.0}
# Adjective 'additional' has specificity score  0.6213349345596119
# {'information': 4.0}
# {'veracity': 8.0}
# {'news': 5.0}
# {'image': 6.0}
# {'caption': 8.0}
# {'man': 10.0}
# Adjective 'contraband' has specificity score  0.48089834696298783
# {'good': 6.0}
# {'bread': 10.0}
# {'delivery': 9.0}
# Adjective 'specific' has specificity score  0.3284587387530511
# {'location': 3.0}
# {'entry': 7.0}
# Adjective 'fake' has specificity score  0.36067376022224085
# {'image': 6.0}
# {'man': 10.0}
# {'bread': 10.0}
# Adjective 'consistent' has specificity score  0.3001016285004131
# {'caption': 8.0}
# Adjective 'contraband' has specificity score  0.48089834696298783
# {'good': 6.0}
# {'location': 3.0}
# Adjective 'illegal' has specificity score  0.2835784920513334
# {'activity': 5.0}
# Adjective 'misleading' has specificity score  0.5138983423697507
# {'image': 6.0}
# {'man': 10.0}
# Adjective 'large' has specificity score  0.2088776448560291
# {'stack': 5.0}
# {'bread': 10.0}
# {'indication': 3.0}
# Adjective 'contraband' has specificity score  0.48089834696298783
# {'good': 6.0}
# {'caption': 8.0}
# Adjective 'harmful' has specificity score  0.2835784920513334
# Adjective 'misleading' has specificity score  0.5138983423697507
# {'context': 6.0}
# Adjective 'fake' has specificity score  0.36067376022224085
# {'ai': 8.0}
# Adjective 'specific' has specificity score  0.3284587387530511
# {'individual': 7.0}
# {'location': 3.0}
# Adjective 'sensational' has specificity score  0.36067376022224085
# {'news': 5.0}
# {'story': 4.0}
# Adjective 'consistent' has specificity score  0.3001016285004131
# Adjective 'real' has specificity score  0.28126641406272834
# {'world': 5.0}
# {'reporting': 6.0}
# {'image': 6.0}
# {'man': 10.0}
# {'stack': 5.0}
# {'bread': 10.0}
# Adjective 'consistent' has specificity score  0.3001016285004131
# {'caption': 8.0}
# Adjective 'contraband' has specificity score  0.48089834696298783
# {'good': 6.0}
# {'delivery': 9.0}
# Adjective 'visible' has specificity score  0.31066746727980593
# {'evidence': 5.0}
# Adjective 'fake' has specificity score  0.36067376022224085
# {'image': 6.0}
# {'nurse': 11.0}
# {'scrub': 5.0}
# {'mask': 11.0}
# Adjective 'consistent' has specificity score  0.3001016285004131
# {'description': 5.0}
# {'vaccine': 6.0}
# Adjective 'generic' has specificity score  0.5138983423697507
# {'representation': 5.0}
# {'caption': 8.0}
# Adjective 'other' has specificity score  0.32351545314867247
# {'hand': 7.0}
# Adjective 'real' has specificity score  0.28126641406272834
# {'news': 5.0}
# {'report': 6.0}
# {'outlet': 8.0}
# Adjective 'different' has specificity score  0.2790553132756236
# {'source': 5.0}
# {'image': 6.0}
# {'nurse': 11.0}
# Adjective 'side' has specificity score  0.48089834696298783
# {'effect': 4.0}
# {'vaccine': 6.0}
# {'woman': 10.0}
# Adjective 'medical' has specificity score  0.5138983423697507
# {'uniform': 9.0}
# {'mask': 11.0}
# {'information': 4.0}
# {'caption': 8.0}
# {'claim': 7.0}
# {'caption': 8.0}
# {'nurse': 11.0}
# Adjective 'first' has specificity score  0.2710850306818168
# {'person': 7.0}
# {'vaccine': 6.0}
# {'image': 6.0}
# {'mask': 11.0}
# {'scrub': 5.0}
# Adjective 'specific' has specificity score  0.3284587387530511
# {'location': 3.0}
# Adjective 'severe' has specificity score  0.3001016285004131
# {'side': 5.0}
# {'effect': 4.0}
# Adjective 'second' has specificity score  0.48089834696298783
# {'dose': 8.0}
# {'sign': 6.0}
# {'suffering': 8.0}
# {'indication': 3.0}
# {'time': 6.0}
# {'event': 3.0}
# {'image': 6.0}
# {'person': 7.0}
# Adjective 'blue' has specificity score  0.2473379469500514
# Adjective 'medical' has specificity score  0.5138983423697507
# {'uniform': 9.0}
# {'face': 6.0}
# {'mask': 11.0}
# {'sidewalk': 8.0}
# {'evidence': 5.0}
# {'claim': 7.0}
# Adjective 'first' has specificity score  0.2710850306818168
# {'vaccine': 6.0}
# {'information': 4.0}
# {'location': 3.0}
# Adjective 'visible' has specificity score  0.31066746727980593
# Adjective 'impossible' has specificity score  0.30692767643013485
# {'identity': 4.0}
# {'caption': 8.0}
# {'severity': 6.0}
# {'side': 5.0}
# {'effect': 4.0}
# {'context': 6.0}
# {'event': 3.0}
# Adjective 'difficult' has specificity score  0.2611892565642242
# {'accuracy': 4.0}
# {'news': 5.0}
# {'snippet': 5.0}
# {'woman': 10.0}
# {'image': 6.0}
# Adjective 'medical' has specificity score  0.5138983423697507
# {'uniform': 9.0}
# {'mask': 11.0}
# Adjective 'consistent' has specificity score  0.3001016285004131
# {'caption': 8.0}
# {'location': 3.0}
# {'nurse': 11.0}
# {'building': 6.0}
# {'background': 4.0}
# {'hospital': 8.0}
# {'side': 5.0}
# {'effect': 4.0}
# {'vaccine': 6.0}
# {'evidence': 5.0}
# {'claim': 7.0}
# {'image': 6.0}
# {'woman': 10.0}
# {'police': 10.0}
# {'officer': 11.0}
# Adjective 'consistent' has specificity score  0.3001016285004131
# {'caption': 8.0}
# {'arrest': 7.0}
# {'supporter': 9.0}
# {'measure': 10.0}
# Adjective 'specific' has specificity score  0.3284587387530511
# {'detail': 6.0}
# {'individual': 7.0}
# {'location': 3.0}
# {'limitation': 8.0}
# {'ai': 8.0}
# {'event': 3.0}
# Adjective 'real' has specificity score  0.28126641406272834
# {'world': 5.0}
# {'reporting': 6.0}
# {'image': 6.0}
# {'caption': 8.0}
# {'ai': 8.0}
# Adjective 'harmful' has specificity score  0.2835784920513334
# Adjective 'misleading' has specificity score  0.5138983423697507
# {'context': 6.0}
# Adjective 'fake' has specificity score  0.36067376022224085
# Adjective 'specific' has specificity score  0.3284587387530511
# {'individual': 7.0}
# {'location': 3.0}
# {'event': 3.0}
# {'snippet': 5.0}
# Adjective 'real' has specificity score  0.28126641406272834
# Adjective 'other' has specificity score  0.32351545314867247
# {'supporter': 9.0}
# {'election': 7.0}
# {'interference': 11.0}
# Adjective 'last' has specificity score  0.28853900817779266
# {'month': 5.0}
# Adjective 'factual' has specificity score  0.5138983423697507
# {'news': 5.0}
# Adjective 'various' has specificity score  0.36067376022224085
# {'outlet': 8.0}
# {'image': 6.0}
# {'people': 3.0}
# {'riot': 8.0}
# {'gear': 11.0}
# {'caption': 8.0}
# Adjective 'specific' has specificity score  0.3284587387530511
# {'person': 7.0}
# {'event': 3.0}
# {'indication': 3.0}
# {'arrest': 7.0}
# {'measure': 10.0}
# Adjective 'real' has specificity score  0.28126641406272834
# {'news': 5.0}
# {'outlet': 8.0}
# {'image': 6.0}
# {'woman': 10.0}
# {'police': 10.0}
# {'officer': 11.0}
# Adjective 'consistent' has specificity score  0.3001016285004131
# {'caption': 8.0}
# {'election': 7.0}
# {'interference': 11.0}
# {'information': 4.0}
# {'name': 5.0}
# {'location': 3.0}
# {'arrest': 7.0}
# {'ai': 8.0}
# {'evidence': 5.0}
# {'person': 7.0}
# {'election': 7.0}
# {'interference': 11.0}
# Adjective 'last' has specificity score  0.28853900817779266
# {'month': 5.0}
# {'image': 6.0}
# {'group': 2.0}
# {'people': 3.0}
# {'none': 9.0}
# {'supporter': 9.0}
# {'measure': 10.0}
# {'caption': 8.0}
# Adjective 'fake' has specificity score  0.36067376022224085
# {'news': 5.0}
# {'snippet': 5.0}
# Adjective 'real' has specificity score  0.28126641406272834
# {'outlet': 8.0}
# {'event': 3.0}
# {'woman': 10.0}
# {'middle': 6.0}
# {'image': 6.0}
# Adjective 'purple' has specificity score  0.36067376022224085
# {'sweater': 10.0}
# Adjective 'short' has specificity score  0.22449978268220952
# Adjective 'blonde' has specificity score  0.36926937306885504
# {'hair': 7.0}
# Adjective 'consistent' has specificity score  0.3001016285004131
# {'description': 5.0}
# {'caption': 8.0}
# {'police': 10.0}
# {'officer': 11.0}
# {'riot': 8.0}
# {'gear': 11.0}
# {'mention': 6.0}
# {'arrest': 7.0}
# {'tree': 9.0}
# {'background': 4.0}
# {'autumn': 6.0}
# {'foliage': 7.0}
# {'time': 6.0}
# {'year': 5.0}
# {'event': 3.0}
# {'image': 6.0}
# {'smoke': 8.0}
# {'city': 10.0}
# Adjective 'consistent' has specificity score  0.3001016285004131
# {'caption': 8.0}
# {'rebel': 20.0}
# {'fighter': 8.0}
# {'ammunition': 7.0}
# Adjective 'specific' has specificity score  0.3284587387530511
# {'location': 3.0}
# Adjective 'western' has specificity score  0.36067376022224085
# Adjective 'front' has specificity score  0.4170323914242463
# {'line': 5.0}
# Adjective 'visible' has specificity score  0.31066746727980593
# Adjective 'enough' has specificity score  0.5581106265512472
# {'context': 6.0}
# {'event': 3.0}
# Adjective 'real' has specificity score  0.28126641406272834
# {'news': 5.0}
# {'outlet': 8.0}
# {'image': 6.0}
# {'caption': 8.0}
# {'ai': 8.0}
# Adjective 'harmful' has specificity score  0.2835784920513334
# Adjective 'misleading' has specificity score  0.5138983423697507
# {'context': 6.0}
# Adjective 'fake' has specificity score  0.36067376022224085
# Adjective 'specific' has specificity score  0.3284587387530511
# {'individual': 7.0}
# {'location': 3.0}
# {'event': 3.0}
# {'snippet': 5.0}
# Adjective 'libyan' has specificity score  0.9102392266268373
# {'rebel': 20.0}
# {'fighter': 8.0}
# {'ammunition': 7.0}
# Adjective 'real' has specificity score  0.28126641406272834
# {'news': 5.0}
# Adjective 'fictional' has specificity score  0.45511961331341866
# {'scenario': 7.0}
# Adjective 'western' has specificity score  0.36067376022224085
# Adjective 'front' has specificity score  0.4170323914242463
# {'line': 5.0}
# {'image': 6.0}
# {'smoke': 8.0}
# {'area': 5.0}
# {'building': 6.0}
# {'tree': 9.0}
# {'power': 4.0}
# {'line': 5.0}
# {'tower': 6.0}
# {'background': 4.0}
# {'caption': 8.0}
# {'rebel': 20.0}
# {'fighter': 8.0}
# {'ammunition': 7.0}
# Adjective 'western' has specificity score  0.36067376022224085
# Adjective 'front' has specificity score  0.4170323914242463
# {'event': 3.0}
# Adjective 'real' has specificity score  0.28126641406272834
# Adjective 'consistent' has specificity score  0.3001016285004131
# {'world': 5.0}
# {'reporting': 6.0}
# Adjective 'libyan' has specificity score  0.9102392266268373
# Adjective 'civil' has specificity score  0.36926937306885504
# {'caption': 8.0}
# {'rebel': 20.0}
# {'fighter': 8.0}
# {'ammunition': 7.0}
# Adjective 'western' has specificity score  0.36067376022224085
# Adjective 'front' has specificity score  0.4170323914242463
# {'line': 5.0}
# {'image': 6.0}
# {'cityscape': 7.0}
# {'building': 6.0}
# {'tree': 9.0}
# Adjective 'visible' has specificity score  0.31066746727980593
# Adjective 'fake' has specificity score  0.36067376022224085
# {'scene': 6.0}
# Adjective 'present' has specificity score  0.3396232718951086
# {'image': 6.0}
# {'person': 7.0}
# {'gun': 9.0}
# {'indication': 3.0}
# {'location': 3.0}
# Adjective 'western' has specificity score  0.36067376022224085
# Adjective 'front' has specificity score  0.4170323914242463
# {'line': 5.0}
# Adjective 'black' has specificity score  0.23868315209103041
# {'jacket': 12.0}
# Adjective 'consistent' has specificity score  0.3001016285004131
# {'attire': 9.0}
# Adjective 'libyan' has specificity score  0.9102392266268373
# {'rebel': 20.0}
# {'fighter': 8.0}
# {'context': 6.0}
# {'background': 4.0}
# {'caption': 8.0}
# {'claim': 7.0}
# {'ammunition': 7.0}
# Adjective 'misleading' has specificity score  0.5138983423697507
# {'ai': 8.0}
# Adjective 'fake' has specificity score  0.36067376022224085
# {'image': 6.0}
# {'smoke': 8.0}
# {'area': 5.0}
# Adjective 'consistent' has specificity score  0.3001016285004131
# {'caption': 8.0}
# {'mention': 6.0}
# Adjective 'libyan' has specificity score  0.9102392266268373
# {'rebel': 20.0}
# {'fighter': 8.0}
# {'ammunition': 7.0}
# Adjective 'ongoing' has specificity score  0.6213349345596119
# {'battle': 7.0}
# {'conflict': 6.0}
# Adjective 'specific' has specificity score  0.3284587387530511
# {'individual': 7.0}
# {'location': 3.0}
# {'presence': 5.0}
# {'context': 6.0}
# {'event': 3.0}
# Adjective 'real' has specificity score  0.28126641406272834
# {'image': 6.0}
# {'caption': 8.0}
# {'ai': 8.0}
# Adjective 'real' has specificity score  0.28126641406272834
# {'news': 5.0}
# {'event': 3.0}
# {'individual': 7.0}
# {'location': 3.0}
# {'man': 10.0}
# {'suit': 10.0}
# {'building': 6.0}
# {'description': 5.0}
# {'courthouse': 8.0}
# {'lawyer': 10.0}
# {'image': 6.0}
# {'caption': 8.0}
# Adjective 'real' has specificity score  0.28126641406272834
# {'news': 5.0}
# {'outlet': 8.0}
# {'event': 3.0}
# {'officer': 11.0}
# {'courthouse': 8.0}
# {'lawyer': 10.0}
# {'person': 7.0}
# {'description': 5.0}
# {'individual': 7.0}
# {'context': 6.0}
# Adjective 'consistent' has specificity score  0.3001016285004131
# {'world': 5.0}
# {'reporting': 6.0}
# {'indication': 3.0}
# {'manipulation': 7.0}
# {'misinformation': 5.0}
# {'image': 6.0}
# {'man': 10.0}
# {'suit': 10.0}
# {'caption': 8.0}
# {'lawyer': 10.0}
# Adjective 'other' has specificity score  0.32351545314867247
# {'individual': 7.0}
# {'image': 6.0}
# {'man': 10.0}
# {'suit': 10.0}
# {'person': 7.0}
# {'lawyer': 10.0}
# {'caption': 8.0}
# {'officer': 11.0}
# Adjective 'consistent' has specificity score  0.3001016285004131
# {'information': 4.0}
# {'location': 3.0}
# {'courthouse': 8.0}
# Adjective 'other' has specificity score  0.32351545314867247
# {'people': 3.0}
# Adjective 'harmful' has specificity score  0.2835784920513334
# Adjective 'misleading' has specificity score  0.5138983423697507
# {'context': 6.0}
# Adjective 'entire' has specificity score  0.3789231816899512
# {'snippet': 5.0}
# {'ai': 8.0}
# {'officer': 11.0}
# {'suit': 10.0}
# {'tie': 11.0}
# {'courthouse': 8.0}
# {'lawyer': 10.0}
# {'glass': 4.0}
# {'police': 10.0}
# {'background': 4.0}
# Adjective 'bulletproof' has specificity score  0.4170323914242463
# {'vest': 10.0}
# {'gun': 9.0}
# {'scene': 6.0}
# {'place': 5.0}
# {'presence': 5.0}
# {'image': 6.0}
# {'caption': 8.0}
# {'ai': 8.0}
# Adjective 'specific' has specificity score  0.3284587387530511
# {'event': 3.0}
# {'individual': 7.0}
# Adjective 'consistent' has specificity score  0.3001016285004131
# Adjective 'real' has specificity score  0.28126641406272834
# {'world': 5.0}
# {'reporting': 6.0}
# {'police': 10.0}
# {'officer': 11.0}
# {'flower': 10.0}
# Adjective 'disrespectful' has specificity score  0.3001016285004131
# {'act': 7.0}
# {'funeral': 7.0}
# {'combination': 4.0}
# {'news': 5.0}
# {'snippet': 5.0}
# {'image': 6.0}
# {'caption': 8.0}
# {'ai': 8.0}
# Adjective 'harmful' has specificity score  0.2835784920513334
# Adjective 'misleading' has specificity score  0.5138983423697507
# {'context': 6.0}
# Adjective 'fake' has specificity score  0.36067376022224085
# {'prompt': 10.0}
# {'result': 4.0}
# Adjective 'specific' has specificity score  0.3284587387530511
# {'individual': 7.0}
# {'location': 3.0}
# {'event': 3.0}
# {'snippet': 5.0}
# Adjective 'factual' has specificity score  0.5138983423697507
# Adjective 'inconsistent' has specificity score  0.3284587387530511
# Adjective 'real' has specificity score  0.28126641406272834
# {'world': 5.0}
# {'reporting': 6.0}
# {'person': 7.0}
# {'evidence': 5.0}
# {'officer': 11.0}
# {'funeral': 7.0}
# {'preparation': 6.0}
# {'misinformation': 5.0}
# {'reaction': 5.0}
# {'viewer': 9.0}
# {'image': 6.0}
# {'event': 3.0}
# {'caption': 8.0}
# {'police': 10.0}
# {'officer': 11.0}
# {'flower': 10.0}
# {'indication': 3.0}
# {'disrespect': 4.0}
# {'funeral': 7.0}
# {'preparation': 6.0}
# {'image': 6.0}
# {'police': 10.0}
# {'officer': 11.0}
# {'uniform': 9.0}
# {'caption': 8.0}
# {'funeral': 7.0}
# {'preparation': 6.0}
# Adjective 'fake' has specificity score  0.36067376022224085
# Adjective 'specific' has specificity score  0.3284587387530511
# {'event': 3.0}
# {'image': 6.0}
# {'police': 10.0}
# {'officer': 11.0}
# {'flower': 10.0}
# {'arrangement': 8.0}
# {'indication': 3.0}
# {'funeral': 7.0}
# {'preparation': 6.0}
# {'caption': 8.0}
# Adjective 'misleading' has specificity score  0.5138983423697507
# {'context': 6.0}
# {'evidence': 5.0}
# Adjective 'disrespectful' has specificity score  0.3001016285004131
# {'behavior': 6.0}
# {'ai': 8.0}
# {'event': 3.0}
# {'image': 6.0}
# {'police': 10.0}
# {'officer': 11.0}
# {'uniform': 9.0}
# Adjective 'consistent' has specificity score  0.3001016285004131
# {'caption': 8.0}
# {'funeral': 7.0}
# {'preparation': 6.0}
# Adjective 'visible' has specificity score  0.31066746727980593
# {'flower': 10.0}
# {'indication': 3.0}
# {'disrespect': 4.0}
# Adjective 'fake' has specificity score  0.36067376022224085
# {'image': 6.0}
# {'group': 2.0}
# {'man': 10.0}
# Adjective 'black' has specificity score  0.23868315209103041
# {'hat': 10.0}
# {'beard': 9.0}
# Adjective 'consistent' has specificity score  0.3001016285004131
# {'description': 5.0}
# Adjective 'ultra' has specificity score  0.5581106265512472
# Adjective '-' has specificity score  There are no synsets for the adjective: -
# Adjective 'orthodox' has specificity score  0.3284587387530511
# {'caption': 8.0}
# {'passing': 10.0}
# Adjective 'specific' has specificity score  0.3284587387530511
# {'event': 3.0}
# {'individual': 7.0}
# {'location': 3.0}
# {'ai': 8.0}
# {'entry': 7.0}
# Adjective 'real' has specificity score  0.28126641406272834
# {'image': 6.0}
# {'caption': 8.0}
# Adjective 'real' has specificity score  0.28126641406272834
# {'news': 5.0}
# {'outlet': 8.0}
# {'event': 3.0}
# {'snippet': 5.0}
# {'celebration': 6.0}
# {'passing': 10.0}
# Adjective '-' has specificity score  There are no synsets for the adjective: -
# Adjective 'orthodox' has specificity score  0.3284587387530511
# Adjective 'consistent' has specificity score  0.3001016285004131
# {'world': 5.0}
# {'reporting': 6.0}
# {'indication': 3.0}
# {'ai': 8.0}
# {'image': 6.0}
# {'group': 2.0}
# {'man': 10.0}
# {'beard': 9.0}
# Adjective 'black' has specificity score  0.23868315209103041
# {'hat': 10.0}
# Adjective 'happy' has specificity score  0.3284587387530511
# {'caption': 8.0}
# Adjective 'religious' has specificity score  0.36067376022224085
# {'celebration': 6.0}
# Adjective 'specific' has specificity score  0.3284587387530511
# {'individual': 7.0}
# {'location': 3.0}
# Adjective 'consistent' has specificity score  0.3001016285004131
# {'theme': 4.0}
# Adjective 'factual' has specificity score  0.5138983423697507
# {'event': 3.0}
# {'people': 3.0}
# {'passing': 10.0}
# {'rabbi': 10.0}
# Adjective 'accurate' has specificity score  0.33380820069533407
# {'caption': 8.0}
# Adjective 'ultra' has specificity score  0.5581106265512472
# Adjective '-' has specificity score  There are no synsets for the adjective: -
# Adjective 'orthodox' has specificity score  0.3284587387530511
# {'passing': 10.0}
# {'rival': 9.0}
# {'image': 6.0}
# {'group': 2.0}
# {'man': 10.0}
# Adjective 'black' has specificity score  0.23868315209103041
# {'hat': 10.0}
# {'clothing': 8.0}
# {'description': 5.0}
# {'sign': 6.0}
# {'celebration': 6.0}
# {'mourning': 9.0}
# Adjective 'inconsistent' has specificity score  0.3284587387530511
# {'image': 6.0}
# {'group': 2.0}
# {'people': 3.0}
# Adjective 'black' has specificity score  0.23868315209103041
# {'hat': 10.0}
# Adjective 'ultra' has specificity score  0.5581106265512472
# Adjective '-' has specificity score  There are no synsets for the adjective: -
# Adjective 'orthodox' has specificity score  0.3284587387530511
# Adjective 'jewish' has specificity score  0.7213475204444817
# {'community': 5.0}
# {'caption': 8.0}
# Adjective 'fake' has specificity score  0.36067376022224085
# {'passing': 10.0}
# {'rival': 9.0}
# Adjective 'consistent' has specificity score  0.3001016285004131
# Adjective 'real' has specificity score  0.28126641406272834
# {'world': 5.0}
# {'reporting': 6.0}
# {'death': 6.0}
# Adjective 'harmful' has specificity score  0.2835784920513334
# Adjective 'misleading' has specificity score  0.5138983423697507
# {'context': 6.0}
# {'ai': 8.0}
# Adjective 'possible' has specificity score  0.31465798044412485
# Adjective 'specific' has specificity score  0.3284587387530511
# {'individual': 7.0}
# {'location': 3.0}
# {'man': 10.0}
# {'image': 6.0}
# Adjective 'black' has specificity score  0.23868315209103041
# {'hat': 10.0}
# {'suit': 10.0}
# Adjective 'common' has specificity score  0.2710850306818168
# Adjective 'ultra' has specificity score  0.5581106265512472
# Adjective '-' has specificity score  There are no synsets for the adjective: -
# Adjective 'orthodox' has specificity score  0.3284587387530511
# Adjective 'jewish' has specificity score  0.7213475204444817
# {'community': 5.0}
# {'way': 4.0}
# {'respect': 7.0}
# {'mourning': 9.0}
# Adjective 'consistent' has specificity score  0.3001016285004131
# {'caption': 8.0}
# {'ai': 8.0}
# {'image': 6.0}
# {'person': 7.0}
# {'hazmat': 8.0}
# {'suit': 10.0}
# Adjective 'consistent' has specificity score  0.3001016285004131
# {'scenario': 7.0}
# {'caption': 8.0}
# {'quarantine': 6.0}
# {'scare': 7.0}
# {'presence': 5.0}
# Adjective 'actual' has specificity score  0.33380820069533407
# Adjective 'various' has specificity score  0.36067376022224085
# {'context': 6.0}
# Adjective 'chemical' has specificity score  0.6213349345596119
# {'spill': 5.0}
# Adjective 'other' has specificity score  0.32351545314867247
# Adjective 'hazardous' has specificity score  0.5138983423697507
# {'material': 7.0}
# {'health': 9.0}
# {'care': 7.0}
# {'worker': 8.0}
# Adjective 'enough' has specificity score  0.5581106265512472
# {'ai': 8.0}
# {'image': 6.0}
# {'caption': 8.0}
# {'ai': 8.0}
# Adjective 'harmful' has specificity score  0.2835784920513334
# Adjective 'misleading' has specificity score  0.5138983423697507
# {'context': 6.0}
# Adjective 'fake' has specificity score  0.36067376022224085
# Adjective 'specific' has specificity score  0.3284587387530511
# {'individual': 7.0}
# {'location': 3.0}
# {'event': 3.0}
# {'snippet': 5.0}
# {'police': 10.0}
# {'quarantine': 6.0}
# {'scare': 7.0}
# {'health': 9.0}
# {'care': 7.0}
# {'worker': 8.0}
# Adjective 'consistent' has specificity score  0.3001016285004131
# Adjective 'real' has specificity score  0.28126641406272834
# {'world': 5.0}
# {'reporting': 6.0}
# Adjective 'such' has specificity score  0.7213475204444817
# Adjective 'reputable' has specificity score  0.36067376022224085
# {'news': 5.0}
# {'outlet': 8.0}
# {'person': 7.0}
# {'hazmat': 8.0}
# {'suit': 10.0}
# Adjective 'yellow' has specificity score  0.3001016285004131
# {'bag': 7.0}
# Adjective 'credible' has specificity score  0.4170323914242463
# Adjective 'factual' has specificity score  0.5138983423697507
# {'image': 6.0}
# Adjective 'specific' has specificity score  0.3284587387530511
# {'neighborhood': 7.0}
# {'person': 7.0}
# {'hazmat': 8.0}
# {'suit': 10.0}
# Adjective 'yellow' has specificity score  0.3001016285004131
# {'bag': 7.0}
# {'scare': 7.0}
# {'connection': 3.0}
# {'news': 5.0}
# {'event': 3.0}
# {'caption': 8.0}
# {'image': 6.0}
# {'person': 7.0}
# {'hazmat': 8.0}
# {'suit': 10.0}
# Adjective 'yellow' has specificity score  0.3001016285004131
# {'bag': 7.0}
# Adjective 'consistent' has specificity score  0.3001016285004131
# {'caption': 8.0}
# {'quarantine': 6.0}
# {'scare': 7.0}
# {'sign': 6.0}
# {'image': 6.0}
# {'person': 7.0}
# Adjective 'white' has specificity score  0.265872585674852
# {'hazmat': 8.0}
# {'suit': 10.0}
# {'street': 8.0}
# Adjective 'yellow' has specificity score  0.3001016285004131
# {'bag': 7.0}
# {'caption': 8.0}
# {'police': 10.0}
# {'quarantine': 6.0}
# {'scare': 7.0}
# {'health': 9.0}
# {'care': 7.0}
# {'worker': 8.0}
# Adjective 'real' has specificity score  0.28126641406272834
# {'world': 5.0}
# {'event': 3.0}
# {'setting': 7.0}
# {'description': 5.0}
# {'ai': 8.0}
# {'image': 6.0}
# {'person': 7.0}
# {'hazmat': 8.0}
# {'suit': 10.0}
# Adjective 'yellow' has specificity score  0.3001016285004131
# {'bag': 7.0}
# Adjective 'consistent' has specificity score  0.3001016285004131
# {'caption': 8.0}
# {'mention': 6.0}
# {'worker': 8.0}
# {'neighborhood': 7.0}
# {'quarantine': 6.0}
# {'scare': 7.0}
# {'health': 9.0}
# {'care': 7.0}
# Adjective 'real' has specificity score  0.28126641406272834
# {'world': 5.0}
# {'news': 5.0}
# {'report': 6.0}
# {'information': 4.0}
# {'location': 3.0}
# Adjective 'specific' has specificity score  0.3284587387530511
# Adjective 'difficult' has specificity score  0.2611892565642242
# {'ai': 8.0}
# {'image': 6.0}
# {'caption': 8.0}
# {'ai': 8.0}
# Adjective 'violent' has specificity score  0.2835784920513334
# {'crackdown': 8.0}
# Adjective 'real' has specificity score  0.28126641406272834
# {'event': 3.0}
# {'individual': 7.0}
# {'group': 2.0}
# {'police': 10.0}
# {'officer': 11.0}
# {'cityscape': 7.0}
# {'context': 6.0}
# {'location': 3.0}
# {'detail': 6.0}
# {'representation': 5.0}
# {'image': 6.0}
# {'caption': 8.0}
# Adjective 'real' has specificity score  0.28126641406272834
# {'news': 5.0}
# {'outlet': 8.0}
# {'event': 3.0}
# Adjective 'violent' has specificity score  0.2835784920513334
# {'crackdown': 8.0}
# {'police': 10.0}
# {'protester': 8.0}
# Adjective 'consistent' has specificity score  0.3001016285004131
# {'world': 5.0}
# {'reporting': 6.0}
# {'group': 2.0}
# {'people': 3.0}
# {'helmet': 10.0}
# {'weapon': 8.0}
# {'officer': 11.0}
# {'presence': 5.0}
# {'situation': 4.0}
# Adjective 'tense' has specificity score  0.2710850306818168
# Adjective 'dangerous' has specificity score  0.28853900817779266
# {'fact': 5.0}
# Adjective 'reputable' has specificity score  0.36067376022224085
# {'scene': 6.0}
# {'image': 6.0}
# {'protester': 8.0}
# {'violence': 7.0}
# {'police': 10.0}
# {'officer': 11.0}
# {'front': 9.0}
# {'building': 6.0}
# {'caption': 8.0}
# {'event': 3.0}
# {'image': 6.0}
# {'group': 2.0}
# {'police': 10.0}
# {'officer': 11.0}
# {'riot': 8.0}
# {'gear': 11.0}
# {'front': 9.0}
# {'building': 6.0}
# {'sign': 6.0}
# {'caption': 8.0}
# Adjective 'violent' has specificity score  0.2835784920513334
# {'crackdown': 8.0}
# {'violence': 7.0}
# {'protest': 7.0}
# {'helmet': 10.0}
# {'mask': 11.0}
# Adjective 'consistent' has specificity score  0.3001016285004131
# {'image': 6.0}
# {'group': 2.0}
# {'people': 3.0}
# {'front': 9.0}
# {'building': 6.0}
# {'helmet': 10.0}
# {'gun': 9.0}
# {'caption': 8.0}
# Adjective 'violent' has specificity score  0.2835784920513334
# {'crackdown': 8.0}
# Adjective 'consistent' has specificity score  0.3001016285004131
# Adjective 'visual' has specificity score  0.45511961331341866
# {'content': 4.0}
# {'presence': 5.0}
# {'fact': 5.0}
# Adjective 'false' has specificity score  0.25973030217227155
# {'narrative': 4.0}
# Adjective 'harmful' has specificity score  0.2835784920513334
# Adjective 'misleading' has specificity score  0.5138983423697507
# {'context': 6.0}
# Adjective 'entire' has specificity score  0.3789231816899512
# {'snippet': 5.0}
# {'ai': 8.0}
# {'image': 6.0}
# {'group': 2.0}
# {'police': 10.0}
# {'officer': 11.0}
# {'helmet': 10.0}
# Adjective 'protective' has specificity score  0.32351545314867247
# {'gear': 11.0}
# {'front': 9.0}
# {'building': 6.0}
# {'air': 5.0}
# {'conditioner': 11.0}
# {'shield': 7.0}
# {'mask': 11.0}
# Adjective 'consistent' has specificity score  0.3001016285004131
# {'caption': 8.0}
# Adjective 'violent' has specificity score  0.2835784920513334
# {'crackdown': 8.0}
# {'protester': 8.0}
# {'presence': 5.0}
# {'description': 5.0}
# {'image': 6.0}
# {'caption': 8.0}
# {'ai': 8.0}
# {'protest': 7.0}
# {'person': 7.0}
# {'smoke': 8.0}
# {'event': 3.0}
# Adjective 'tear' has specificity score  There are no synsets for the adjective: tear
# {'gas': 7.0}
# {'location': 3.0}
# Adjective 'difficult' has specificity score  0.2611892565642242
# {'authenticity': 5.0}
# {'image': 6.0}
# {'caption': 8.0}
# Adjective 'real' has specificity score  0.28126641406272834
# {'news': 5.0}
# {'outlet': 8.0}
# {'event': 3.0}
# {'protest': 7.0}
# {'overhaul': 11.0}
# Adjective 'french' has specificity score  0.7213475204444817
# {'labor': 5.0}
# {'law': 4.0}
# Adjective 'consistent' has specificity score  0.3001016285004131
# {'world': 5.0}
# {'reporting': 6.0}
# {'misinformation': 5.0}
# {'manipulation': 7.0}
# {'building': 6.0}
# {'smoke': 8.0}
# Adjective 'additional' has specificity score  0.6213349345596119
# {'context': 6.0}
# Adjective 'possible' has specificity score  0.31465798044412485
# Adjective 'specific' has specificity score  0.3284587387530511
# {'location': 3.0}
# {'presence': 5.0}
# {'mention': 6.0}
# Adjective 'tear' has specificity score  There are no synsets for the adjective: tear
# {'gas': 7.0}
# {'form': 6.0}
# {'disturbance': 6.0}
# {'confrontation': 7.0}
# {'image': 6.0}
# Adjective 'specific' has specificity score  0.3284587387530511
# {'individual': 7.0}
# {'location': 3.0}
# Adjective 'consistent' has specificity score  0.3001016285004131
# {'caption': 8.0}
# Adjective 'real' has specificity score  0.28126641406272834
# {'news': 5.0}
# {'outlet': 8.0}
# {'detail': 6.0}
# {'protest': 7.0}
# {'labor': 5.0}
# {'law': 4.0}
# {'world': 5.0}
# {'reporting': 6.0}
# {'event': 3.0}
# {'figure': 6.0}
# {'image': 6.0}
# {'person': 7.0}
# {'umbrella': 9.0}
# {'fog': 8.0}
# Adjective 'consistent' has specificity score  0.3001016285004131
# {'caption': 8.0}
# Adjective 'tear' has specificity score  There are no synsets for the adjective: tear
# {'gas': 7.0}
# {'protest': 7.0}
# {'overhaul': 11.0}
# Adjective 'french' has specificity score  0.7213475204444817
# {'labor': 5.0}
# {'law': 4.0}
# {'image': 6.0}
# {'person': 7.0}
# {'umbrella': 9.0}
# Adjective 'visible' has specificity score  0.31066746727980593
# {'tear': 6.0}
# {'gas': 7.0}
# {'scene': 6.0}
# {'caption': 8.0}
# Adjective 'harmful' has specificity score  0.2835784920513334
# Adjective 'misleading' has specificity score  0.5138983423697507
# {'context': 6.0}
# Adjective 'fake' has specificity score  0.36067376022224085
# {'ai': 8.0}
# {'protest': 7.0}
# {'event': 3.0}
# Adjective 'factual' has specificity score  0.5138983423697507
# Adjective 'inconsistent' has specificity score  0.3284587387530511
# Adjective 'real' has specificity score  0.28126641406272834
# {'world': 5.0}
# {'reporting': 6.0}
# {'image': 6.0}
# {'building': 6.0}
# {'smoke': 8.0}
# {'foreground': 9.0}
# Adjective 'consistent' has specificity score  0.3001016285004131
# {'caption': 8.0}
# {'protest': 7.0}
# Adjective 'common' has specificity score  0.2710850306818168
# {'occurrence': 4.0}
# Adjective 'specific' has specificity score  0.3284587387530511
# {'individual': 7.0}
# {'location': 3.0}
# {'presence': 5.0}
# {'labor': 5.0}
# {'law': 4.0}
# Adjective 'likely' has specificity score  0.33380820069533407
# Adjective 'real' has specificity score  0.28126641406272834
# {'image': 6.0}
# {'caption': 8.0}
# {'ai': 8.0}
# {'train': 8.0}
# {'crash': 7.0}
# Adjective 'specific' has specificity score  0.3284587387530511
# {'location': 3.0}
# {'date': 5.0}
# Adjective 'consistent' has specificity score  0.3001016285004131
# Adjective 'visual' has specificity score  0.45511961331341866
# {'content': 4.0}
# {'authority': 6.0}
# Adjective 'typical' has specificity score  0.36067376022224085
# {'practice': 6.0}
# Adjective 'real' has specificity score  0.28126641406272834
# {'news': 5.0}
# {'reporting': 6.0}
# {'image': 6.0}
# {'caption': 8.0}
# {'ai': 8.0}
# {'train': 8.0}
# {'collision': 6.0}
# {'authority': 6.0}
# Adjective 'typical' has specificity score  0.36067376022224085
# {'behavior': 6.0}
# Adjective 'real' has specificity score  0.28126641406272834
# {'news': 5.0}
# {'outlet': 8.0}
# {'narrative': 4.0}
# Adjective 'harmful' has specificity score  0.2835784920513334
# Adjective 'misleading' has specificity score  0.5138983423697507
# {'context': 6.0}
# {'combination': 4.0}
# Adjective 'consistent' has specificity score  0.3001016285004131
# {'world': 5.0}
# {'reporting': 6.0}
# {'image': 6.0}
# {'train': 8.0}
# {'collision': 6.0}
# {'caption': 8.0}
# Adjective 'massive' has specificity score  0.3789231816899512
# {'authority': 6.0}
# {'dozen': 7.0}
# {'injury': 8.0}
# {'ai': 8.0}
# {'event': 3.0}
# {'image': 6.0}
# {'train': 8.0}
# {'collision': 6.0}
# {'derailment': 8.0}
# {'location': 3.0}
# {'presence': 5.0}
# Adjective 'multiple' has specificity score  0.24325728130826463
# {'people': 3.0}
# {'vehicle': 7.0}
# {'caption': 8.0}
# {'claim': 7.0}
# Adjective 'massive' has specificity score  0.3789231816899512
# {'ai': 8.0}
# {'event': 3.0}
# {'image': 6.0}
# {'train': 8.0}
# {'collision': 6.0}
# {'caption': 8.0}
# {'dozen': 7.0}
# {'authority': 6.0}
# {'people': 3.0}
# {'indication': 3.0}
# {'location': 3.0}
# {'date': 5.0}
# Adjective 'impossible' has specificity score  0.30692767643013485
# {'accuracy': 4.0}
# {'ai': 8.0}
# {'image': 6.0}
# {'caption': 8.0}
# {'ai': 8.0}
# {'location': 3.0}
# Adjective 'harmful' has specificity score  0.2835784920513334
# Adjective 'misleading' has specificity score  0.5138983423697507
# {'context': 6.0}
# {'characteristic': 8.0}
# {'news': 5.0}
# {'snippet': 5.0}
# {'image': 6.0}
# {'caption': 8.0}
# {'ai': 8.0}
# Adjective 'harmful' has specificity score  0.2835784920513334
# Adjective 'misleading' has specificity score  0.5138983423697507
# {'context': 6.0}
# Adjective 'fake' has specificity score  0.36067376022224085
# Adjective 'specific' has specificity score  0.3284587387530511
# {'individual': 7.0}
# {'location': 3.0}
# {'event': 3.0}
# {'snippet': 5.0}
# {'police': 10.0}
# {'harassment': 8.0}
# Adjective 'real' has specificity score  0.28126641406272834
# {'news': 5.0}
# {'image': 6.0}
# {'people': 3.0}
# {'place': 5.0}
# {'caption': 8.0}
# Adjective 'specific' has specificity score  0.3284587387530511
# {'event': 3.0}
# {'news': 5.0}
# Adjective 'consistent' has specificity score  0.3001016285004131
# Adjective 'real' has specificity score  0.28126641406272834
# {'world': 5.0}
# {'reporting': 6.0}
# {'caption': 8.0}
# {'city': 10.0}
# {'image': 6.0}
# {'man': 10.0}
# {'street': 8.0}
# Adjective 'clear' has specificity score  0.22334705684109696
# {'area': 5.0}
# {'resident': 9.0}
# Adjective 'tired' has specificity score  0.24842549839846914
# {'police': 10.0}
# {'harassment': 8.0}
# {'officer': 11.0}
# {'sign': 6.0}
# Adjective 'real' has specificity score  0.28126641406272834
# {'person': 7.0}
# {'news': 5.0}
# {'outlet': 8.0}
# {'experience': 6.0}
# {'image': 6.0}
# {'man': 10.0}
# {'street': 8.0}
# {'corner': 6.0}
# Adjective 'consistent' has specificity score  0.3001016285004131
# {'caption': 8.0}
# {'description': 5.0}
# {'content': 4.0}
# {'indication': 3.0}
# {'misinformation': 5.0}
# {'manipulation': 7.0}
# {'man': 10.0}
# {'image': 6.0}
# {'cap': 10.0}
# Adjective 'white' has specificity score  0.265872585674852
# {'t': 12.0}
# {'shirt': 10.0}
# {'middle': 6.0}
# {'street': 8.0}
# {'police': 10.0}
# {'officer': 11.0}
# {'indication': 3.0}
# {'harassment': 8.0}
# {'caption': 8.0}
# {'connection': 3.0}
# {'image': 6.0}
# {'building': 6.0}
# Adjective 'consistent' has specificity score  0.3001016285004131
# {'text': 6.0}
# {'bias': 7.0}
# Adjective 'typical' has specificity score  0.36067376022224085
# {'term': 6.0}
# Adjective 'legal' has specificity score  0.318928988903801
# {'context': 6.0}
# {'accusation': 7.0}
# {'ai': 8.0}
# Adjective 'harmful' has specificity score  0.2835784920513334
# Adjective 'misleading' has specificity score  0.5138983423697507
# {'image': 6.0}
# {'caption': 8.0}
# Adjective 'real' has specificity score  0.28126641406272834
# {'news': 5.0}
# {'outlet': 8.0}
# {'institution': 5.0}
# {'building': 6.0}
# {'event': 3.0}
# Adjective 'consistent' has specificity score  0.3001016285004131
# {'world': 5.0}
# {'reporting': 6.0}
# Adjective 'controversial' has specificity score  0.40242960438184466
# {'ruling': 8.0}
# Adjective 'various' has specificity score  0.36067376022224085
# {'law': 4.0}
# {'presence': 5.0}
# {'officer': 11.0}
# {'authenticity': 5.0}
# {'image': 6.0}
# {'building': 6.0}
# Adjective 'real' has specificity score  0.28126641406272834
# {'location': 3.0}
# {'caption': 8.0}
# Adjective 'fake' has specificity score  0.36067376022224085
# {'justice': 10.0}
# Adjective 'controversial' has specificity score  0.40242960438184466
# {'ruling': 8.0}
# {'law': 4.0}
# {'morning': 5.0}
# {'event': 3.0}
# {'officer': 11.0}
# {'bias': 7.0}
# Adjective 'subjective' has specificity score  0.4170323914242463
# {'claim': 7.0}
# Adjective 'factual' has specificity score  0.5138983423697507
# {'theme': 4.0}
# {'subject': 4.0}
# {'matter': 10.0}
# {'photograph': 7.0}
# {'image': 6.0}
# {'building': 6.0}
# {'location': 3.0}
# {'caption': 8.0}
# Adjective 'real' has specificity score  0.28126641406272834
# {'entity': 0.0}
# {'court': 6.0}
# {'law': 4.0}
# {'enforcement': 7.0}
# {'agency': 7.0}
# Adjective 'fake' has specificity score  0.36067376022224085
# {'image': 6.0}
# {'building': 6.0}
# {'column': 7.0}
# {'statue': 14.0}
# {'front': 9.0}
# Adjective 'distinct' has specificity score  0.2969742043733701
# Adjective 'architectural' has specificity score  0.9102392266268373
# {'style': 4.0}
# {'ai': 8.0}
# {'caption': 8.0}
# Adjective 'specific' has specificity score  0.3284587387530511
# {'detail': 6.0}
# {'event': 3.0}
# {'individual': 7.0}
# Adjective 'real' has specificity score  0.28126641406272834
# {'news': 5.0}
# {'outlet': 8.0}
# Adjective 'factual' has specificity score  0.5138983423697507
# {'image': 6.0}
# {'building': 6.0}
# Adjective 'iconic' has specificity score  0.9102392266268373
# {'column': 7.0}
# {'step': 10.0}
# {'caption': 8.0}
# Adjective 'controversial' has specificity score  0.40242960438184466
# {'ruling': 8.0}
# Adjective 'real' has specificity score  0.28126641406272834
# {'event': 3.0}
# {'location': 3.0}
# {'justice': 10.0}
# Adjective 'visible' has specificity score  0.31066746727980593
# {'entry': 7.0}
# {'image': 6.0}
# {'scene': 6.0}
# {'police': 10.0}
# {'officer': 11.0}
# {'caption': 8.0}
# Adjective 'specific' has specificity score  0.3284587387530511
# {'event': 3.0}
# Adjective 'real' has specificity score  0.28126641406272834
# {'world': 5.0}
# {'location': 3.0}
# Adjective 'enough' has specificity score  0.5581106265512472
# {'context': 6.0}
# {'presence': 5.0}
# {'security': 6.0}
# {'situation': 4.0}
# Adjective 'more' has specificity score  0.5138983423697507
# {'information': 4.0}
# Adjective 'possible' has specificity score  0.31465798044412485
# {'ai': 8.0}
# {'image': 6.0}
# {'caption': 8.0}
# Adjective 'real' has specificity score  0.28126641406272834
# {'news': 5.0}
# {'outlet': 8.0}
# {'event': 3.0}
# {'suicide': 10.0}
# {'bomb': 9.0}
# {'attack': 7.0}
# Adjective 'consistent' has specificity score  0.3001016285004131
# {'world': 5.0}
# {'reporting': 6.0}
# Adjective 'various' has specificity score  0.36067376022224085
# {'police': 10.0}
# {'officer': 11.0}
# {'guard': 10.0}
# {'entrance': 7.0}
# {'building': 6.0}
# {'headquarters': 9.0}
# {'indication': 3.0}
# Adjective 'accurate' has specificity score  0.33380820069533407
# {'representation': 5.0}
# {'image': 6.0}
# {'entrance': 7.0}
# {'police': 10.0}
# {'headquarters': 9.0}
# {'officer': 11.0}
# {'man': 10.0}
# Adjective 'military' has specificity score  0.3459762562611936
# {'uniform': 9.0}
# {'guard': 10.0}
# {'gate': 9.0}
# Adjective 'other' has specificity score  0.32351545314867247
# {'background': 4.0}
# {'suicide': 10.0}
# {'bomber': 14.0}
# {'attack': 7.0}
# {'caption': 8.0}
# {'suicide': 10.0}
# {'bomber': 14.0}
# {'attack': 7.0}
# {'image': 6.0}
# {'sign': 6.0}
# {'police': 10.0}
# {'officer': 11.0}
# {'guard': 10.0}
# {'entrance': 7.0}
# Adjective 'consistent' has specificity score  0.3001016285004131
# Adjective 'fake' has specificity score  0.36067376022224085
# {'image': 6.0}
# {'group': 2.0}
# {'police': 10.0}
# {'officer': 11.0}
# {'front': 9.0}
# {'building': 6.0}
# {'sign': 6.0}
# {'presence': 5.0}
# {'signage': 4.0}
# {'location': 3.0}
# {'headquarters': 9.0}
# {'caption': 8.0}
# Adjective 'consistent' has specificity score  0.3001016285004131
# Adjective 'real' has specificity score  0.28126641406272834
# {'world': 5.0}
# {'reporting': 6.0}
# {'event': 3.0}
# {'past': 4.0}
# {'scene': 6.0}
# {'man': 10.0}
# {'image': 6.0}
# {'uniform': 9.0}
# {'gun': 9.0}
# Adjective 'typical' has specificity score  0.36067376022224085
# {'police': 10.0}
# {'officer': 11.0}
# {'building': 6.0}
# {'background': 4.0}
# {'headquarters': 9.0}
# Adjective 'consistent' has specificity score  0.3001016285004131
# {'caption': 8.0}
# {'guard': 10.0}
# Adjective 'common' has specificity score  0.2710850306818168
# {'practice': 6.0}
# {'image': 6.0}
# {'caption': 8.0}
# Adjective 'real' has specificity score  0.28126641406272834
# {'news': 5.0}
# {'outlet': 8.0}
# {'event': 3.0}
# {'snippet': 5.0}
# Adjective 'factual' has specificity score  0.5138983423697507
# Adjective 'consistent' has specificity score  0.3001016285004131
# {'world': 5.0}
# {'reporting': 6.0}
# {'speech': 6.0}
# {'description': 5.0}
# Adjective 'young' has specificity score  0.2530848692773169
# {'leader': 8.0}
# {'peace': 5.0}
# {'image': 6.0}
# {'caption': 8.0}
# Adjective 'real' has specificity score  0.28126641406272834
# {'news': 5.0}
# {'outlet': 8.0}
# {'event': 3.0}
# Adjective 'consistent' has specificity score  0.3001016285004131
# {'world': 5.0}
# {'reporting': 6.0}
# {'speech': 6.0}
# Adjective 'young' has specificity score  0.2530848692773169
# {'leader': 8.0}
# {'peace': 5.0}
# {'man': 10.0}
# {'background': 4.0}
# Adjective 'israeli' has specificity score  0.9102392266268373
# {'flag': 8.0}
# {'location': 3.0}
# {'image': 6.0}
# {'speech': 6.0}
# {'sign': 6.0}
# {'place': 5.0}
# {'indication': 3.0}
# {'location': 3.0}
# {'event': 3.0}
# {'caption': 8.0}
# {'man': 10.0}
# {'suit': 10.0}
# {'hand': 7.0}
# {'background': 4.0}
# {'flag': 8.0}
# Adjective 'blue' has specificity score  0.2473379469500514
# Adjective 'consistent' has specificity score  0.3001016285004131
# Adjective 'real' has specificity score  0.28126641406272834
# {'world': 5.0}
# {'reporting': 6.0}
# {'text': 6.0}
# {'caption': 8.0}
# {'speech': 6.0}
# Adjective 'real' has specificity score  0.28126641406272834
# {'event': 3.0}
# {'image': 6.0}
# {'man': 10.0}
# {'suit': 10.0}
# {'front': 9.0}
# {'flag': 8.0}
# {'menorah': 11.0}
# Adjective 'consistent' has specificity score  0.3001016285004131
# {'image': 6.0}
# {'man': 10.0}
# {'suit': 10.0}
# {'camera': 8.0}
# Adjective 'consistent' has specificity score  0.3001016285004131
# {'caption': 8.0}
# {'description': 5.0}
# {'background': 4.0}
# Adjective 'american' has specificity score  0.7213475204444817
# {'flag': 8.0}
# Adjective 'israeli' has specificity score  0.9102392266268373
# {'claim': 7.0}
# {'event': 3.0}
# {'place': 5.0}
# {'presence': 5.0}
# {'attire': 9.0}
# Adjective 'real' has specificity score  0.28126641406272834
# {'news': 5.0}
# {'image': 6.0}
# {'front': 9.0}
# Adjective 'blue' has specificity score  0.2473379469500514
# Adjective 'white' has specificity score  0.265872585674852
# {'sign': 6.0}
# {'word': 5.0}
# Adjective 'real' has specificity score  0.28126641406272834
# {'organization': 4.0}
# {'speech': 6.0}
# {'event': 3.0}
# Adjective 'consistent' has specificity score  0.3001016285004131
# Adjective 'dark' has specificity score  0.22509081678177853
# {'suit': 10.0}
# {'tie': 11.0}
# Adjective 'appropriate' has specificity score  0.45511961331341866
# Adjective 'formal' has specificity score  0.2729584204093974
# {'flag': 8.0}
# {'background': 4.0}
# Adjective 'american' has specificity score  0.7213475204444817
# Adjective 'israeli' has specificity score  0.9102392266268373
# Adjective 'such' has specificity score  0.7213475204444817
# {'image': 6.0}
# {'caption': 8.0}
# {'ai': 8.0}
# {'news': 5.0}
# {'event': 3.0}
# {'person': 7.0}
# {'publisher': 8.0}
# {'publishing': 9.0}
# {'dispute': 7.0}
# {'individual': 7.0}
# {'poster': 4.0}
# Adjective 'different' has specificity score  0.2790553132756236
# {'people': 3.0}
# {'location': 3.0}
# Adjective 'consistent' has specificity score  0.3001016285004131
# Adjective 'real' has specificity score  0.28126641406272834
# {'world': 5.0}
# {'reporting': 6.0}
# {'image': 6.0}
# {'caption': 8.0}
# Adjective 'real' has specificity score  0.28126641406272834
# {'news': 5.0}
# {'outlet': 8.0}
# {'poster': 4.0}
# {'office': 8.0}
# {'people': 3.0}
# {'uniform': 9.0}
# {'front': 9.0}
# {'wall': 7.0}
# {'event': 3.0}
# {'image': 6.0}
# {'group': 2.0}
# {'police': 10.0}
# {'officer': 11.0}
# {'front': 9.0}
# {'sign': 6.0}
# {'People': 3.0}
# Adjective 'real' has specificity score  0.28126641406272834
# {'location': 3.0}
# {'text': 6.0}
# Adjective 'consistent' has specificity score  0.3001016285004131
# {'caption': 8.0}
# {'poster': 4.0}
# Adjective 'visible' has specificity score  0.31066746727980593
# {'image': 6.0}
# {'poster': 4.0}
# Adjective 'consistent' has specificity score  0.3001016285004131
# {'caption': 8.0}
# {'wall': 7.0}
# {'location': 3.0}
# {'liaison': 6.0}
# {'office': 8.0}
# {'presence': 5.0}
# {'event': 3.0}
# Adjective 'real' has specificity score  0.28126641406272834
# Adjective 'ongoing' has specificity score  0.6213349345596119
# Adjective 'human' has specificity score  0.33380820069533407
# {'right': 8.0}
# {'issue': 5.0}
# {'form': 6.0}
# {'protest': 7.0}
# {'awareness': 7.0}
# {'raising': 8.0}
# Adjective 'common' has specificity score  0.2710850306818168
# {'practice': 6.0}
# {'world': 5.0}
# {'reporting': 6.0}
# {'image': 6.0}
# {'police': 10.0}
# {'officer': 11.0}
# {'front': 9.0}
# {'wall': 7.0}
# {'poster': 4.0}
# {'man': 10.0}
# Adjective 'black' has specificity score  0.23868315209103041
# {'uniform': 9.0}
# {'cap': 10.0}
# Adjective 'chinese' has specificity score  0.5581106265512472
# {'text': 6.0}
# Adjective 'consistent' has specificity score  0.3001016285004131
# {'caption': 8.0}
# {'sign': 6.0}
# {'image': 6.0}
# {'caption': 8.0}
# {'ai': 8.0}
# Adjective 'real' has specificity score  0.28126641406272834
# {'news': 5.0}
# {'event': 3.0}
# {'individual': 7.0}
# {'setting': 7.0}
# {'man': 10.0}
# {'suit': 10.0}
# Adjective 'unclear' has specificity score  0.3396232718951086
# {'background': 4.0}
# {'lighting': 5.0}
# {'description': 5.0}
# {'hearing': 8.0}
# {'image': 6.0}
# {'caption': 8.0}
# Adjective 'real' has specificity score  0.28126641406272834
# {'news': 5.0}
# {'outlet': 8.0}
# {'event': 3.0}
# {'snippet': 5.0}
# Adjective 'consistent' has specificity score  0.3001016285004131
# {'world': 5.0}
# {'reporting': 6.0}
# Adjective 'public' has specificity score  0.3898712452512801
# {'figure': 6.0}
# {'presence': 5.0}
# {'hearing': 8.0}
# {'matter': 10.0}
# {'record': 5.0}
# {'man': 10.0}
# {'suit': 10.0}
# Adjective 'formal' has specificity score  0.2729584204093974
# {'setting': 7.0}
# {'individual': 7.0}
# {'image': 6.0}
# {'man': 10.0}
# {'suit': 10.0}
# Adjective 'other' has specificity score  0.32351545314867247
# {'people': 3.0}
# {'background': 4.0}
# {'light': 10.0}
# {'wall': 7.0}
# {'caption': 8.0}
# {'setting': 7.0}
# {'government': 6.0}
# {'building': 6.0}
# Adjective 'real' has specificity score  0.28126641406272834
# {'event': 3.0}
# {'man': 10.0}
# {'image': 6.0}
# {'suit': 10.0}
# Adjective 'consistent' has specificity score  0.3001016285004131
# Adjective 'formal' has specificity score  0.2729584204093974
# {'attire': 9.0}
# {'government': 6.0}
# {'official': 10.0}
# {'background': 4.0}
# {'room': 7.0}
# {'microphone': 10.0}
# Adjective 'typical' has specificity score  0.36067376022224085
# {'hearing': 8.0}
# Adjective 'specific' has specificity score  0.3284587387530511
# {'detail': 6.0}
# {'location': 3.0}
# {'individual': 7.0}
# {'name': 5.0}
# {'context': 6.0}
# {'caption': 8.0}
# Adjective 'real' has specificity score  0.28126641406272834
# {'event': 3.0}
# {'image': 6.0}
# {'caption': 8.0}
# Adjective 'real' has specificity score  0.28126641406272834
# {'news': 5.0}
# {'outlet': 8.0}
# {'event': 3.0}
# {'snippet': 5.0}
# {'police': 10.0}
# {'officer': 11.0}
# {'scene': 6.0}
# {'fire': 5.0}
# {'neighborhood': 7.0}
# {'image': 6.0}
# {'caption': 8.0}
# Adjective 'real' has specificity score  0.28126641406272834
# {'news': 5.0}
# {'outlet': 8.0}
# {'event': 3.0}
# {'snippet': 5.0}
# {'house': 9.0}
# {'fire': 5.0}
# {'neighborhood': 7.0}
# Adjective 'consistent' has specificity score  0.3001016285004131
# {'world': 5.0}
# {'reporting': 6.0}
# {'presence': 5.0}
# {'police': 10.0}
# {'officer': 11.0}
# {'incident': 5.0}
# Adjective 'public' has specificity score  0.3898712452512801
# {'safety': 5.0}
# Adjective 'clear' has specificity score  0.22334705684109696
# Adjective 'accurate' has specificity score  0.33380820069533407
# {'representation': 5.0}
# {'indication': 3.0}
# {'misinformation': 5.0}
# {'manipulation': 7.0}
# {'image': 6.0}
# {'caption': 8.0}
# Adjective 'real' has specificity score  0.28126641406272834
# {'news': 5.0}
# {'outlet': 8.0}
# {'police': 10.0}
# {'officer': 11.0}
# {'house': 9.0}
# {'fire': 5.0}
# {'neighborhood': 7.0}
# {'event': 3.0}
# {'location': 3.0}
# {'uniform': 9.0}
# {'gun': 9.0}
# {'belt': 9.0}
# Adjective 'consistent' has specificity score  0.3001016285004131
# {'role': 8.0}
# Adjective 'blue' has specificity score  0.2473379469500514
# {'tape': 6.0}
# {'crime': 8.0}
# {'scene': 6.0}
# {'world': 5.0}
# {'reporting': 6.0}
# {'presence': 5.0}
# {'caption': 8.0}
# {'police': 10.0}
# {'officer': 11.0}
# Adjective 'charred' has specificity score  There are no synsets for the adjective: charred
# {'house': 9.0}
# {'fire': 5.0}
# {'neighborhood': 7.0}
# {'image': 6.0}
# {'front': 9.0}
# Adjective 'blue' has specificity score  0.2473379469500514
# {'tape': 6.0}
# Adjective 'consistent' has specificity score  0.3001016285004131
# {'image': 6.0}
# {'police': 10.0}
# {'officer': 11.0}
# {'house': 9.0}
# {'fire': 5.0}
# {'uniform': 9.0}
# Adjective 'consistent' has specificity score  0.3001016285004131
# {'description': 5.0}
# {'caption': 8.0}
# Adjective 'charred' has specificity score  There are no synsets for the adjective: charred
# {'area': 5.0}
# Adjective 'devastated' has specificity score  There are no synsets for the adjective: devastated
# {'presence': 5.0}
# {'incident': 5.0}
# Adjective 'real' has specificity score  0.28126641406272834
# {'world': 5.0}
# {'reporting': 6.0}
# {'indication': 3.0}
# {'misinformation': 5.0}
# {'manipulation': 7.0}
# {'police': 10.0}
# {'officer': 11.0}
# {'uniform': 9.0}
# {'handcuff': 9.0}
# {'belt': 9.0}
# ...
# Adjective 'consistent' has specificity score  0.3001016285004131
# {'world': 5.0}
# {'reporting': 6.0}
# Adjective 'former' has specificity score  0.33380820069533407
# {'president': 13.0}
# {'capital': 5.0}
# Adjective 'last' has specificity score  0.28853900817779266
# {'month': 5.0}
# {'bribery': 10.0}
# Adjective 'other' has specificity score  0.32351545314867247
# Adjective 'criminal' has specificity score  0.3898712452512801
# {'charge': 8.0}
# {'image': 6.0}
# {'caption': 8.0}
# Adjective 'real' has specificity score  0.28126641406272834
# {'news': 5.0}
# {'outlet': 8.0}
# {'event': 3.0}
# Adjective 'consistent' has specificity score  0.3001016285004131
# {'world': 5.0}
# {'reporting': 6.0}
# Adjective 'former' has specificity score  0.33380820069533407
# {'president': 13.0}
# {'bribery': 10.0}
# Adjective 'other' has specificity score  0.32351545314867247
# Adjective 'criminal' has specificity score  0.3898712452512801
# {'charge': 8.0}
# Adjective 'last' has specificity score  0.28853900817779266
# {'month': 5.0}
# {'person': 7.0}
# Adjective 'accurate' has specificity score  0.33380820069533407
# {'information': 4.0}
# Adjective 'significant' has specificity score  0.28599966750267436
# {'image': 6.0}
# Adjective 'other' has specificity score  0.32351545314867247
# Adjective 'specific' has specificity score  0.3284587387530511
# {'individual': 7.0}
# {'location': 3.0}
# {'sign': 6.0}
# {'arrest': 7.0}
# {'jail': 10.0}
# {'people': 3.0}
# {'stair': 8.0}
# {'caption': 8.0}
# Adjective 'real' has specificity score  0.28126641406272834
# {'image': 6.0}
# {'woman': 10.0}
# Adjective 'dark' has specificity score  0.22509081678177853
# Adjective 'blue' has specificity score  0.2473379469500514
# {'coat': 11.0}
# Adjective 'black' has specificity score  0.23868315209103041
# {'tie': 11.0}
# Adjective 'consistent' has specificity score  0.3001016285004131
# {'caption': 8.0}
# Adjective 'former' has specificity score  0.33380820069533407
# {'president': 13.0}
# {'bribery': 10.0}
# Adjective 'other' has specificity score  0.32351545314867247
# Adjective 'criminal' has specificity score  0.3898712452512801
# {'charge': 8.0}
# {'indication': 3.0}
# {'jail': 10.0}
# {'image': 6.0}
# {'person': 7.0}
# {'street': 8.0}
# {'indication': 3.0}
# Adjective 'former' has specificity score  0.33380820069533407
# {'president': 13.0}
# {'caption': 8.0}
# Adjective 'real' has specificity score  0.28126641406272834
# {'news': 5.0}
# {'event': 3.0}
# {'ai': 8.0}
# {'outlet': 8.0}
# {'image': 6.0}
# {'man': 10.0}
# {'woman': 10.0}
# {'stair': 8.0}
# Adjective 'blue' has specificity score  0.2473379469500514
# {'dress': 10.0}
# Adjective 'beige' has specificity score  0.7213475204444817
# {'coat': 11.0}
# {'tie': 11.0}
# {'husband': 11.0}
# Adjective 'last' has specificity score  0.28853900817779266
# {'month': 5.0}
# Adjective 'consistent' has specificity score  0.3001016285004131
# {'caption': 8.0}
# {'bribery': 10.0}
# Adjective 'other' has specificity score  0.32351545314867247
# Adjective 'criminal' has specificity score  0.3898712452512801
# {'charge': 8.0}
# {'image': 6.0}
# {'caption': 8.0}
# {'ai': 8.0}
# Adjective 'real' has specificity score  0.28126641406272834
# {'person': 7.0}
# {'man': 10.0}
# {'suit': 10.0}
# {'tie': 11.0}
# Adjective 'clear' has specificity score  0.22334705684109696
# Adjective 'same' has specificity score  0.2969742043733701
# {'individual': 7.0}
# {'protest': 7.0}
# Adjective 'small' has specificity score  0.2227848098240302
# {'town': 10.0}
# {'southeast': 6.0}
# {'context': 6.0}
# {'location': 3.0}
# {'information': 4.0}
# {'image': 6.0}
# {'caption': 8.0}
# {'ai': 8.0}
# Adjective 'harmful' has specificity score  0.2835784920513334
# Adjective 'misleading' has specificity score  0.5138983423697507
# {'context': 6.0}
# Adjective 'fake' has specificity score  0.36067376022224085
# Adjective 'specific' has specificity score  0.3284587387530511
# {'individual': 7.0}
# {'location': 3.0}
# {'event': 3.0}
# {'snippet': 5.0}
# Adjective 'consistent' has specificity score  0.3001016285004131
# Adjective 'real' has specificity score  0.28126641406272834
# {'world': 5.0}
# {'reporting': 6.0}
# {'protest': 7.0}
# {'visit': 8.0}
# Adjective 'political' has specificity score  0.45511961331341866
# {'career': 7.0}
# {'controversy': 8.0}
# {'administration': 8.0}
# {'man': 10.0}
# {'suit': 10.0}
# {'tie': 11.0}
# {'image': 6.0}
# Adjective 'specific' has specificity score  0.3284587387530511
# {'location': 3.0}
# {'crowd': 5.0}
# {'people': 3.0}
# {'number': 6.0}
# {'issue': 5.0}
# {'caption': 8.0}
# {'reference': 6.0}
# {'ai': 8.0}
# {'theme': 4.0}
# {'image': 6.0}
# {'man': 10.0}
# {'suit': 10.0}
# {'tie': 11.0}
# Adjective 'consistent' has specificity score  0.3001016285004131
# {'caption': 8.0}
# {'president': 13.0}
# {'visit': 8.0}
# Adjective 'small' has specificity score  0.2227848098240302
# {'town': 10.0}
# {'southeast': 6.0}
# Adjective 'specific' has specificity score  0.3284587387530511
# {'location': 3.0}
# {'image': 6.0}
# {'man': 10.0}
# {'suit': 10.0}
# {'crowd': 5.0}
# {'people': 3.0}
# {'indication': 3.0}
# {'evidence': 5.0}
# {'protest': 7.0}
# {'visit': 8.0}
# {'caption': 8.0}
# Adjective 'fake' has specificity score  0.36067376022224085
# {'news': 5.0}
# {'snippet': 5.0}
# {'ai': 8.0}
# Adjective 'entire' has specificity score  0.3789231816899512
# {'entry': 7.0}
# {'image': 6.0}
# {'crowd': 5.0}
# {'people': 3.0}
# {'fist': 8.0}
# {'man': 10.0}
# {'center': 6.0}
# {'glass': 4.0}
# Adjective 'dark' has specificity score  0.22509081678177853
# {'suit': 10.0}
# Adjective 'consistent' has specificity score  0.3001016285004131
# {'description': 5.0}
# Adjective 'specific' has specificity score  0.3284587387530511
# {'location': 3.0}
# {'clothing': 8.0}
# {'setting': 7.0}
# Adjective 'public' has specificity score  0.3898712452512801
# {'place': 5.0}
# {'caption': 8.0}
# {'image': 6.0}
# {'caption': 8.0}
# {'ai': 8.0}
# {'man': 10.0}
# {'podium': 8.0}
# Adjective 'specific' has specificity score  0.3284587387530511
# {'detail': 6.0}
# {'location': 3.0}
# {'event': 3.0}
# Adjective 'accurate' has specificity score  0.33380820069533407
# {'resignation': 6.0}
# {'individual': 7.0}
# {'image': 6.0}
# {'caption': 8.0}
# Adjective 'real' has specificity score  0.28126641406272834
# {'news': 5.0}
# {'outlet': 8.0}
# Adjective 'specific' has specificity score  0.3284587387530511
# {'event': 3.0}
# {'resignation': 6.0}
# Adjective 'consistent' has specificity score  0.3001016285004131
# {'world': 5.0}
# {'reporting': 6.0}
# {'man': 10.0}
# {'podium': 8.0}
# Adjective 'common' has specificity score  0.2710850306818168
# {'setting': 7.0}
# {'press': 8.0}
# {'conference': 6.0}
# {'announcement': 5.0}
# {'attire': 9.0}
# Adjective 'formal' has specificity score  0.2729584204093974
# {'description': 5.0}
# {'indication': 3.0}
# {'ai': 8.0}
# {'inconsistency': 5.0}
# {'inaccuracy': 4.0}
# {'information': 4.0}
# {'image': 6.0}
# {'man': 10.0}
# {'suit': 10.0}
# {'podium': 8.0}
# {'microphone': 10.0}
# {'front': 9.0}
# {'flag': 8.0}
# Adjective 'wooden' has specificity score  0.5581106265512472
# {'wall': 7.0}
# {'left': 6.0}
# {'caption': 8.0}
# Adjective 'real' has specificity score  0.28126641406272834
# {'news': 5.0}
# {'event': 3.0}
# {'resignation': 6.0}
# {'face': 6.0}
# {'setting': 7.0}
# Adjective 'consistent' has specificity score  0.3001016285004131
# {'description': 5.0}
# {'image': 6.0}
# {'man': 10.0}
# {'suit': 10.0}
# {'podium': 8.0}
# {'microphone': 10.0}
# Adjective 'consistent' has specificity score  0.3001016285004131
# {'caption': 8.0}
# Adjective 'possible' has specificity score  0.31465798044412485
# Adjective 'same' has specificity score  0.2969742043733701
# {'person': 7.0}
# {'ai': 8.0}
# {'image': 6.0}
# {'man': 10.0}
# {'podium': 8.0}
# {'indication': 3.0}
# {'suit': 10.0}
# {'tie': 11.0}
# Adjective 'typical' has specificity score  0.36067376022224085
# {'attire': 9.0}
# {'sign': 6.0}
# Adjective 'other' has specificity score  0.32351545314867247
# Adjective 'recognizable' has specificity score  0.48089834696298783
# {'landmark': 6.0}
# {'caption': 8.0}
# Adjective 'fake' has specificity score  0.36067376022224085
# {'resignation': 6.0}
# {'ai': 8.0}
# Adjective 'real' has specificity score  0.28126641406272834
# {'news': 5.0}
# {'event': 3.0}
# {'man': 10.0}
# {'suit': 10.0}
# {'tie': 11.0}
# {'podium': 8.0}
# {'microphone': 10.0}
# {'front': 9.0}
# Adjective 'consistent' has specificity score  0.3001016285004131
# {'caption': 8.0}
# {'seal': 9.0}
# {'audience': 5.0}
# {'image': 6.0}
# Adjective 'real' has specificity score  0.28126641406272834
# {'news': 5.0}
# {'outlet': 8.0}
# {'event': 3.0}
# {'image': 6.0}
# {'caption': 8.0}
# Adjective 'real' has specificity score  0.28126641406272834
# {'news': 5.0}
# {'outlet': 8.0}
# {'event': 3.0}
# {'snippet': 5.0}
# {'individual': 7.0}
# Adjective 'other' has specificity score  0.32351545314867247
# {'people': 3.0}
# {'location': 3.0}
# {'place': 5.0}
# {'year': 5.0}
# {'image': 6.0}
# {'caption': 8.0}
# Adjective 'real' has specificity score  0.28126641406272834
# {'news': 5.0}
# {'outlet': 8.0}
# Adjective 'specific' has specificity score  0.3284587387530511
# {'event': 3.0}
# Adjective 'former' has specificity score  0.33380820069533407
# {'man': 10.0}
# {'individual': 7.0}
# {'setting': 7.0}
# {'attire': 9.0}
# Adjective 'consistent' has specificity score  0.3001016285004131
# {'description': 5.0}
# {'indication': 3.0}
# {'ai': 8.0}
# Adjective 'various' has specificity score  0.36067376022224085
# {'image': 6.0}
# {'man': 10.0}
# Adjective 'white' has specificity score  0.265872585674852
# {'shirt': 10.0}
# {'golf': 11.0}
# {'course': 7.0}
# Adjective 'red' has specificity score  0.31066746727980593
# {'hat': 10.0}
# Adjective 'other' has specificity score  0.32351545314867247
# {'hand': 7.0}
# {'face': 6.0}
# {'watch': 10.0}
# Adjective 'left' has specificity score  0.3001016285004131
# {'wrist': 8.0}
# {'background': 4.0}
# Adjective 'green' has specificity score  0.32351545314867247
# {'focus': 8.0}
# {'tree': 9.0}
# {'grass': 10.0}
# Adjective 'real' has specificity score  0.28126641406272834
# {'caption': 8.0}
# {'people': 3.0}
# {'setting': 7.0}
# {'image': 6.0}
# {'man': 10.0}
# Adjective 'white' has specificity score  0.265872585674852
# {'shirt': 10.0}
# {'hat': 10.0}
# {'caption': 8.0}
# Adjective 'fake' has specificity score  0.36067376022224085
# {'city': 10.0}
# Adjective 'northern' has specificity score  0.3459762562611936
# {'suburb': 7.0}
# {'golf': 11.0}
# {'club': 8.0}
# {'image': 6.0}
# {'man': 10.0}
# Adjective 'white' has specificity score  0.265872585674852
# {'shirt': 10.0}
# Adjective 'red' has specificity score  0.31066746727980593
# {'hat': 10.0}
# {'front': 9.0}
# {'building': 6.0}
# {'sign': 6.0}
# {'evidence': 5.0}
# {'claim': 7.0}
# Adjective 'former' has specificity score  0.33380820069533407
# {'ai': 8.0}
# {'record': 5.0}
# {'individual': 7.0}
# {'location': 3.0}
# {'time': 6.0}
# {'period': 4.0}
# {'caption': 8.0}
# Adjective 'false' has specificity score  0.25973030217227155
# {'narrative': 4.0}
# {'image': 6.0}
# {'man': 10.0}
# Adjective 'white' has specificity score  0.265872585674852
# {'shirt': 10.0}
# Adjective 'red' has specificity score  0.31066746727980593
# {'cap': 10.0}
# {'caption': 8.0}
# Adjective 'striped' has specificity score  0.6213349345596119
# {'pattern': 5.0}
# {'background': 4.0}
# {'tree': 9.0}
# {'grass': 10.0}
# Adjective 'consistent' has specificity score  0.3001016285004131
# {'location': 3.0}
# {'suburb': 7.0}
# {'image': 6.0}
# {'caption': 8.0}
# Adjective 'real' has specificity score  0.28126641406272834
# {'news': 5.0}
# {'outlet': 8.0}
# {'event': 3.0}
# {'snippet': 5.0}
# {'strike': 10.0}
# Adjective 'historical' has specificity score  0.3898712452512801
# {'group': 2.0}
# {'woman': 10.0}
# {'flag': 8.0}
# Adjective 'consistent' has specificity score  0.3001016285004131
# {'description': 5.0}
# {'image': 6.0}
# {'caption': 8.0}
# {'ai': 8.0}
# Adjective 'harmful' has specificity score  0.2835784920513334
# Adjective 'misleading' has specificity score  0.5138983423697507
# {'context': 6.0}
# Adjective 'fake' has specificity score  0.36067376022224085
# Adjective 'specific' has specificity score  0.3284587387530511
# {'individual': 7.0}
# {'location': 3.0}
# {'event': 3.0}
# {'snippet': 5.0}
# Adjective 'real' has specificity score  0.28126641406272834
# {'woman': 10.0}
# Adjective 'high' has specificity score  0.23233849357411737
# {'food': 4.0}
# {'price': 6.0}
# {'protest': 7.0}
# {'part': 3.0}
# Adjective 'broad' has specificity score  0.265872585674852
# {'suffrage': 11.0}
# {'movement': 7.0}
# {'right': 8.0}
# Adjective 'well' has specificity score  0.3789231816899512
# {'working': 6.0}
# {'condition': 4.0}
# {'wage': 9.0}
# Adjective 'significant' has specificity score  0.28599966750267436
# {'history': 5.0}
# {'labor': 5.0}
# {'image': 6.0}
# {'group': 2.0}
# {'woman': 10.0}
# {'flag': 8.0}
# Adjective 'specific' has specificity score  0.3284587387530511
# {'event': 3.0}
# {'hundred': 7.0}
# Adjective 'high' has specificity score  0.23233849357411737
# {'food': 4.0}
# {'price': 6.0}
# {'individual': 7.0}
# {'location': 3.0}
# {'caption': 8.0}
# Adjective 'real' has specificity score  0.28126641406272834
# {'news': 5.0}
# {'outlet': 8.0}
# {'entry': 7.0}
# Adjective 'fake' has specificity score  0.36067376022224085
# {'image': 6.0}
# {'group': 2.0}
# {'woman': 10.0}
# {'flag': 8.0}
# Adjective 'clear' has specificity score  0.22334705684109696
# {'caption': 8.0}
# {'protest': 7.0}
# {'information': 4.0}
# {'location': 3.0}
# {'time': 6.0}
# {'period': 4.0}
# {'black': 7.0}
# {'white': 8.0}
# Adjective 'consistent' has specificity score  0.3001016285004131
# {'image': 6.0}
# {'group': 2.0}
# {'people': 3.0}
# {'flag': 8.0}
# Adjective 'american' has specificity score  0.7213475204444817
# {'caption': 8.0}
# Adjective 'different' has specificity score  0.2790553132756236
# {'design': 8.0}
# {'period': 4.0}
# {'clothing': 8.0}
# Adjective 'consistent' has specificity score  0.3001016285004131
# {'time': 6.0}
# {'event': 3.0}
# Adjective 'real' has specificity score  0.28126641406272834
# Adjective 'historical' has specificity score  0.3898712452512801
# {'news': 5.0}
# {'outlet': 8.0}
# Adjective 'fake' has specificity score  0.36067376022224085
# {'snippet': 5.0}
# {'image': 6.0}
# {'group': 2.0}
# {'woman': 10.0}
# {'flag': 8.0}
# Adjective 'consistent' has specificity score  0.3001016285004131
# {'caption': 8.0}
# Adjective 'historical' has specificity score  0.3898712452512801
# {'record': 5.0}
# {'suffrage': 11.0}
# {'movement': 7.0}
# Adjective 'early' has specificity score  0.25433477814404226
# Adjective '20th' has specificity score  0.6213349345596119
# {'century': 5.0}
# {'image': 6.0}
# {'caption': 8.0}
# Adjective 'real' has specificity score  0.28126641406272834
# {'news': 5.0}
# {'outlet': 8.0}
# {'event': 3.0}
# {'parade': 9.0}
# Adjective 'factual' has specificity score  0.5138983423697507
# {'man': 10.0}
# {'float': 4.0}
# Adjective 'consistent' has specificity score  0.3001016285004131
# {'description': 5.0}
# {'image': 6.0}
# {'caption': 8.0}
# Adjective 'real' has specificity score  0.28126641406272834
# {'news': 5.0}
# {'outlet': 8.0}
# {'event': 3.0}
# {'snippet': 5.0}
# {'man': 10.0}
# {'outside': 5.0}
# {'parade': 9.0}
# {'float': 4.0}
# Adjective 'consistent' has specificity score  0.3001016285004131
# {'world': 5.0}
# {'reporting': 6.0}
# Adjective 'misleading' has specificity score  0.5138983423697507
# Adjective 'harmful' has specificity score  0.2835784920513334
# {'context': 6.0}
# Adjective 'colorful' has specificity score  0.19931118704250333
# {'costume': 10.0}
# Adjective 'common' has specificity score  0.2710850306818168
# {'sight': 8.0}
# {'indication': 3.0}
# {'ai': 8.0}
# {'image': 6.0}
# {'man': 10.0}
# Adjective 'red' has specificity score  0.31066746727980593
# {'outfit': 6.0}
# {'parade': 9.0}
# {'float': 4.0}
# {'caption': 8.0}
# {'location': 3.0}
# {'date': 5.0}
# {'identity': 4.0}
# Adjective 'other' has specificity score  0.32351545314867247
# {'detail': 6.0}
# {'event': 3.0}
# {'lack': 6.0}
# {'information': 4.0}
# Adjective 'difficult' has specificity score  0.2611892565642242
# Adjective 'real' has specificity score  0.28126641406272834
# {'people': 3.0}
# {'costume': 10.0}
# Adjective 'common' has specificity score  0.2710850306818168
# Adjective 'possible' has specificity score  0.31465798044412485
# Adjective 'more' has specificity score  0.5138983423697507
# Adjective 'impossible' has specificity score  0.30692767643013485
# {'entry': 7.0}
# Adjective 'fake' has specificity score  0.36067376022224085
# {'image': 6.0}
# {'man': 10.0}
# {'outside': 5.0}
# {'parade': 9.0}
# {'float': 4.0}
# {'indication': 3.0}
# {'location': 3.0}
# Adjective 'typical' has specificity score  0.36067376022224085
# Adjective 'distinctive' has specificity score  0.48089834696298783
# {'clothing': 8.0}
# {'accessory': 9.0}
# {'caption': 8.0}
# {'context': 6.0}
# {'ai': 8.0}
# Adjective 'fake' has specificity score  0.36067376022224085

# %% [markdown]
# # Новый раздел

# %%
"""
Usage: python3 specificty3.py [./materials/Concreteness_ratings_Brysbaert_et_al_BRM.txt]
"""

"""
read Breysbart ratings - only nouns
"""

ratings_cogsci = "/content/gdrive/MyDrive/MS_postprocess_code/concreteness/data/Concreteness_ratings_Brysbaert_et_al_BRM.txt"
keywords = read_ratings(ratings_cogsci)


"""
apply measure to nouns in ratings
"""

wn_top_down_print = {}


for elem, score in keywords.items():
    wn_synsets = wn.synsets(elem, pos='n')
    if len(wn_synsets) >=1:
        data_correlation = wn_closure(elem, score)
        wn_top_down_print.update(data_correlation)

print("Printing output...")

# outdir = '/data/p281734/Specificty3/'
# create_folder(outdir)

# outfile = HEAD_DIR + "specificity3.csv"

spec_val = []
for k, v in wn_top_down_print.items():
    rating_human, depth, specificity = v
    spec_val.append(float(specificity))

min_score = min(spec_val)
max_score = max(spec_val)

final_scores = {}
for k, v in wn_top_down_print.items():
    rating_human, depth, specificity = v
    normalized_score = ((specificity - min_score) / (max_score - min_score)) * (5.0 - 1.0) + 1.0
    final_scores[k] = (v[0], v[1], normalized_score,)

with open(outfile, 'a') as outcsv:
    # configure writer to write standard csv file
    writer = csv.writer(outcsv, delimiter=',', lineterminator='\n')
    writer.writerow(['token', 'rating-human', 'depth', 'normalized_specificity'])
    for elem, values in final_scores.items():
        # Write item to outcsv
        writer.writerow([elem, values[0], values[1], values[2]])
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
# {'paleontology': 10.0}
# {'premises': 8.0}
# {'preview': 6.0}
# {'rehearsal': 8.0}
# {'riffle': 7.0}
# {'shortcut': 7.0}
# {'tenet': 8.0}
# {'thud': 6.0}
# {'abortionist': 13.0}
# {'aerospace': 5.0}
# {'alumni': 10.0}
# {'aphrodisiac': 8.0}
# {'bandwidth': 5.0}
# {'blip': 8.0}
# {'cameo': 17.0}
# {'chump': 9.0}
# {'clatter': 7.0}
# {'concussion': 10.0}
# {'cosmos': 5.0}
# {'decade': 5.0}
# {'defender': 9.0}
# {'discoloration': 5.0}
# {'duelist': 9.0}
# {'facade': 8.0}
# {'facsimile': 8.0}
# {'fermentation': 6.0}
# {'fool': 9.0}
# {'genetics': 11.0}
# {'ghost': 9.0}
# {'grammar': 10.0}
# {'gridlock': 8.0}
# {'job': 6.0}
# {'liberator': 10.0}
# {'luminescence': 11.0}
# {'menopause': 5.0}
# {'murmur': 6.0}
# {'nappy': 10.0}
# {'osteoporosis': 9.0}
# {'ovulation': 4.0}
# {'particulate': 8.0}
# {'prettiness': 6.0}
# {'professorship': 8.0}
# {'region': 4.0}
# {'rewriter': 11.0}
# {'scheduler': 6.0}
# {'screener': 11.0}
# {'slut': 12.0}
# {'storminess': 9.0}
# {'supremacist': 9.0}
# {'symptom': 6.0}
# {'tidbit': 7.0}
# {'tightwad': 12.0}
# {'translucence': 5.0}
# {'undergrad': 11.0}
# {'undergraduate': 11.0}
# {'uprights': 9.0}
# {'verse': 5.0}
# {'wailer': 13.0}
# {'waveform': 7.0}
# {'commencement': 4.0}
# {'debate': 6.0}
# {'dislocation': 6.0}
# {'fatness': 5.0}
# {'feud': 7.0}
# {'fray': 8.0}
# {'fund': 7.0}
# {'goofball': 10.0}
# {'locator': 10.0}
# {'narrative': 4.0}
# {'pallor': 7.0}
# {'pickings': 6.0}
# {'protegee': 11.0}
# {'repeater': 8.0}
# {'siege': 8.0}
# {'weekday': 7.0}
# {'adrenalin': 21.0}
# {'anagrams': 9.0}
# {'catchphrase': 19.0}
# {'conservationist': 10.0}
# {'coupe': 13.0}
# {'distance': 6.0}
# {'editing': 5.0}
# {'egghead': 9.0}
# {'election': 7.0}
# {'extortionist': 12.0}
# {'forgiver': 8.0}
# {'funding': 6.0}
# {'icebreaker': 11.0}
# {'kickback': 9.0}
# {'kilo': 8.0}
# {'megaton': 6.0}
# {'meltdown': 7.0}
# {'nightlife': 8.0}
# {'outskirts': 7.0}
# {'overdraft': 9.0}
# {'ping': 5.0}
# {'placebo': 8.0}
# {'playoffs': 6.0}
# {'prostitution': 10.0}
# {'puritan': 11.0}
# {'rasp': 5.0}
# {'reconstruction': 6.0}
# {'repellant': 10.0}
# {'repetition': 6.0}
# {'shelling': 9.0}
# {'suspension': 8.0}
# {'tempest': 6.0}
# {'thing': 5.0}
# {'triage': 8.0}
# {'addressee': 10.0}
# {'ambush': 9.0}
# {'antitoxin': 17.0}
# {'bellyful': 9.0}
# {'butchery': 7.0}
# {'byproduct': 5.0}
# {'consumption': 5.0}
# {'drunkenness': 5.0}
# {'falconry': 7.0}
# {'glutton': 11.0}
# {'hallucinogen': 8.0}
# {'loudmouth': 10.0}
# {'meddler': 9.0}
# {'projection': 9.0}
# {'tandem': 5.0}
# {'tingle': 7.0}
# {'toots': 6.0}
# {'user': 8.0}
# {'aerobatics': 11.0}
# {'aftercare': 10.0}
# {'anniversary': 7.0}
# {'astigmatism': 12.0}
# {'audit': 7.0}
# {'behemoth': 9.0}
# {'braggart': 11.0}
# {'charter': 6.0}
# {'detonation': 6.0}
# {'draft': 8.0}
# {'falsetto': 8.0}
# {'follower': 8.0}
# {'holidays': 7.0}
# {'informer': 10.0}
# {'itch': 9.0}
# {'lineage': 6.0}
# {'listing': 6.0}
# {'lobotomy': 11.0}
# {'lockout': 7.0}
# {'marksmanship': 6.0}
# {'math': 8.0}
# {'mister': 8.0}
# {'mountaineering': 10.0}
# {'noun': 8.0}
# {'nuptials': 7.0}
# {'oceanography': 10.0}
# {'roomful': 5.0}
# {'scruff': 10.0}
# {'slack': 11.0}
# {'slugger': 12.0}
# {'spacing': 5.0}
# {'takeaway': 6.0}
# {'throng': 5.0}
# {'township': 7.0}
# {'activator': 7.0}
# {'addict': 11.0}
# {'algebra': 10.0}
# {'aridity': 4.0}
# {'ballast': 8.0}
# {'bastard': 10.0}
# {'budget': 8.0}
# {'coarseness': 4.0}
# {'cuss': 12.0}
# {'end': 6.0}
# {'extraction': 4.0}
# {'fatigue': 5.0}
# {'fling': 7.0}
# {'grouping': 2.0}
# {'guesser': 8.0}
# {'homebody': 9.0}
# {'hyphenation': 10.0}
# {'impostor': 11.0}
# {'legislation': 6.0}
# {'madwoman': 11.0}
# {'masses': 3.0}
# {'midnight': 9.0}
# {'moneymaker': 9.0}
# {'mortgage': 8.0}
# {'mutilation': 10.0}
# {'neuroscience': 12.0}
# {'overpayment': 8.0}
# {'pennyweight': 7.0}
# {'plot': 9.0}
# {'rampage': 9.0}
# {'reentry': 9.0}
# {'reorder': 8.0}
# {'reservation': 7.0}
# {'schooldays': 6.0}
# {'shape': 5.0}
# {'shortness': 10.0}
# {'sighting': 10.0}
# {'smut': 9.0}
# {'spook': 10.0}
# {'strategist': 9.0}
# {'subject': 4.0}
# {'swag': 9.0}
# {'thievery': 10.0}
# {'trading': 8.0}
# {'vacation': 7.0}
# {'weakling': 8.0}
# {'whacker': 2.0}
# {'asker': 11.0}
# {'breeder': 11.0}
# {'cultivation': 8.0}
# {'damper': 7.0}
# {'encephalitis': 8.0}
# {'eviction': 7.0}
# {'form': 6.0}
# {'frill': 7.0}
# {'newcomer': 10.0}
# {'proofs': 6.0}
# {'rage': 7.0}
# {'shortlist': 7.0}
# {'size': 5.0}
# {'stuff': 7.0}
# {'sufferer': 9.0}
# {'suppressant': 7.0}
# {'trademark': 5.0}
# {'acoustics': 10.0}
# {'apnea': 7.0}
# {'ballistics': 8.0}
# {'banshee': 8.0}
# {'blackball': 8.0}
# {'blunderer': 10.0}
# {'bogeyman': 9.0}
# {'burlesque': 6.0}
# {'clampdown': 9.0}
# {'constituent': 4.0}
# {'damages': 10.0}
# {'denseness': 6.0}
# {'dysplasia': 7.0}
# {'finery': 10.0}
# {'florescence': 5.0}
# {'furlough': 7.0}
# {'hospitalization': 5.0}
# {'ingestion': 5.0}
# {'inspection': 9.0}
# {'lockup': 11.0}
# {'lowlander': 11.0}
# {'matchmaker': 11.0}
# {'menagerie': 4.0}
# {'neurotoxin': 6.0}
# {'phlebotomy': 17.0}
# {'predecessor': 9.0}
# {'psychics': 9.0}
# {'simpleton': 8.0}
# {'snooper': 11.0}
# {'townie': 11.0}
# {'urinalysis': 14.0}
# {'vertex': 11.0}
# {'airwave': 7.0}
# {'appraisal': 7.0}
# {'authenticator': 12.0}
# {'backtalk': 8.0}
# {'bigot': 10.0}
# {'caucus': 6.0}
# {'chitchat': 7.0}
# {'depth': 6.0}
# {'distillation': 4.0}
# {'energy': 6.0}
# {'fathead': 10.0}
# {'femaleness': 7.0}
# {'fitness': 5.0}
# {'gentlefolk': 5.0}
# {'geography': 10.0}
# {'getaway': 7.0}
# {'handiwork': 8.0}
# {'highlight': 5.0}
# {'hygiene': 7.0}
# {'masterpiece': 8.0}
# {'matrix': 5.0}
# {'metamorphosis': 4.0}
# {'minion': 11.0}
# {'miscarriage': 6.0}
# {'muddiness': 6.0}
# {'pace': 5.0}
# {'perkiness': 7.0}
# {'presentation': 7.0}
# {'pyromaniac': 11.0}
# {'remainder': 4.0}
# {'retrieval': 7.0}
# {'revenue': 6.0}
# {'royalty': 8.0}
# {'screening': 4.0}
# {'seductress': 10.0}
# {'sightseeing': 9.0}
# {'slavery': 6.0}
# {'subspecies': 5.0}
# {'surveillance': 9.0}
# {'symbol': 4.0}
# {'teatime': 7.0}
# {'unemployment': 4.0}
# {'afterglow': 7.0}
# {'aid': 6.0}
# {'binge': 10.0}
# {'bleep': 6.0}
# {'capacity': 6.0}
# {'comedy': 6.0}
# {'composition': 5.0}
# {'daydreamer': 10.0}
# {'deal': 7.0}
# {'decomposition': 12.0}
# {'dignitary': 10.0}
# {'disorder': 6.0}
# {'dork': 10.0}
# {'fraction': 9.0}
# {'hotness': 8.0}
# {'hour': 4.0}
# {'inheritance': 7.0}
# {'insomniac': 10.0}
# {'madhouse': 10.0}
# {'malnutrition': 11.0}
# {'maniac': 10.0}
# {'profile': 5.0}
# {'province': 7.0}
# {'punk': 12.0}
# {'reflex': 6.0}
# {'self': 8.0}
# {'sequence': 6.0}
# {'sir': 11.0}
# {'softness': 5.0}
# {'solstice': 5.0}
# {'synonym': 6.0}
# {'trajectory': 7.0}
# {'coot': 13.0}
# {'disrepair': 6.0}
# {'emissary': 11.0}
# {'genus': 9.0}
# {'piecework': 8.0}
# {'springtime': 6.0}
# {'tatters': 9.0}
# {'account': 6.0}
# {'advert': 5.0}
# {'aeronautics': 10.0}
# {'alimony': 9.0}
# {'amperage': 7.0}
# {'archaeology': 10.0}
# {'autopilot': 8.0}
# {'beeline': 6.0}
# {'buildup': 10.0}
# {'caesarean': 6.0}
# {'crockery': 8.0}
# {'cryptology': 8.0}
# {'ephedrine': 18.0}
# {'epigram': 6.0}
# {'euthanasia': 10.0}
# {'freelancer': 9.0}
# {'glimpse': 9.0}
# {'habitation': 8.0}
# {'hardball': 5.0}
# {'labor': 5.0}
# {'mandate': 7.0}
# {'moonlighter': 9.0}
# {'omega': 6.0}
# {'overture': 5.0}
# {'quartering': 10.0}
# {'recitation': 6.0}
# {'ripper': 14.0}
# {'savant': 10.0}
# {'scorcher': 9.0}
# {'slant': 7.0}
# {'stardust': 5.0}
# {'stranglehold': 5.0}
# {'tailwind': 9.0}
# {'temptress': 11.0}
# {'thingamabob': 4.0}
# {'thousand': 7.0}
# {'tiebreaker': 6.0}
# {'trade': 8.0}
# {'visitation': 7.0}
# {'abbreviation': 7.0}
# {'abduction': 11.0}
# {'abyss': 11.0}
# {'algorithm': 8.0}
# {'allowance': 6.0}
# {'anthology': 10.0}
# {'arrival': 7.0}
# {'attendance': 6.0}
# {'awakening': 9.0}
# {'blondness': 7.0}
# {'brewing': 11.0}
# {'cannibalism': 7.0}
# {'cinch': 8.0}
# {'compression': 8.0}
# {'counterterrorist': 8.0}
# {'creator': 0.0}
# {'decompression': 9.0}
# {'definition': 6.0}
# {'deflection': 8.0}
# {'delegate': 11.0}
# {'departure': 5.0}
# {'devourer': 11.0}
# {'digest': 10.0}
# {'disaster': 8.0}
# {'discussion': 6.0}
# {'dizziness': 7.0}
# {'drift': 7.0}
# {'entirety': 6.0}
# {'entrepreneur': 10.0}
# {'exes': 11.0}
# {'exponent': 8.0}
# {'extremity': 6.0}
# {'fable': 6.0}
# {'factoid': 5.0}
# {'franchise': 13.0}
# {'friend': 8.0}
# {'gigolo': 10.0}
# {'gourmet': 9.0}
# {'gumminess': 6.0}
# {'guzzler': 11.0}
# {'handicap': 9.0}
# {'hero': 9.0}
# {'implantation': 4.0}
# {'impotence': 4.0}
# {'income': 8.0}
# {'increment': 3.0}
# {'insider': 13.0}
# {'lender': 10.0}
# {'locality': 7.0}
# {'loudness': 5.0}
# {'maintenance': 10.0}
# {'martyr': 10.0}
# {'megabyte': 6.0}
# {'member': 10.0}
# {'middleweight': 10.0}
# {'monotone': 7.0}
# {'notation': 5.0}
# {'offence': 7.0}
# {'overlap': 6.0}
# {'physics': 9.0}
# {'placement': 4.0}
# {'pressure': 6.0}
# {'profit': 9.0}
# {'proponent': 8.0}
# {'rant': 9.0}
# {'rebel': 20.0}
# {'recess': 6.0}
# {'reenactment': 13.0}
# {'renovation': 9.0}
# {'rhythm': 5.0}
# {'schooling': 10.0}
# {'scrambler': 10.0}
# {'semester': 7.0}
# {'settlement': 5.0}
# {'sham': 9.0}
# {'sinner': 10.0}
# {'sleuth': 11.0}
# {'speller': 10.0}
# {'supplement': 6.0}
# {'survivalist': 8.0}
# {'tallness': 6.0}
# {'teleportation': 9.0}
# {'time': 6.0}
# {'tone': 5.0}
# {'treaty': 11.0}
# {'trial': 7.0}
# {'turnout': 5.0}
# {'tutorial': 8.0}
# {'urology': 12.0}
# {'utility': 8.0}
# {'valuables': 8.0}
# {'violence': 7.0}
# {'volume': 3.0}
# {'warp': 8.0}
# {'wiz': 9.0}
# {'zodiac': 5.0}
# {'zone': 6.0}
# {'goal': 5.0}
# {'badlands': 4.0}
# {'despot': 10.0}
# {'houseful': 5.0}
# {'rummy': 11.0}
# {'vamp': 11.0}
# {'adrenaline': 21.0}
# {'aerial': 11.0}
# {'airspeed': 6.0}
# {'atmosphere': 5.0}
# {'attachment': 6.0}
# {'backflow': 8.0}
# {'backwater': 4.0}
# {'beholder': 8.0}
# {'bimbo': 12.0}
# {'blurb': 5.0}
# {'bonus': 7.0}
# {'boundary': 6.0}
# {'chancellery': 8.0}
# {'chatterbox': 13.0}
# {'cleanup': 10.0}
# {'commission': 7.0}
# {'compact': 8.0}
# {'component': 8.0}
# {'confessor': 17.0}
# {'copyright': 14.0}
# {'crescendo': 6.0}
# {'crossbreed': 6.0}
# {'debugger': 9.0}
# {'deconstruction': 8.0}
# {'deuce': 7.0}
# {'diocese': 7.0}
# {'docudrama': 13.0}
# {'drowsiness': 5.0}
# {'east': 7.0}
# {'exhaustion': 6.0}
# {'flakiness': 8.0}
# {'frolic': 7.0}
# {'frontage': 6.0}
# {'grafting': 10.0}
# {'gunnery': 7.0}
# {'holdup': 12.0}
# {'jokester': 11.0}
# {'kilobyte': 6.0}
# {'kwanza': 7.0}
# {'lag': 7.0}
# {'latecomer': 10.0}
# {'lord': 0.0}
# {'membership': 5.0}
# {'minute': 4.0}
# {'misalignment': 5.0}
# {'newsbreak': 8.0}
# {'nymphomaniac': 12.0}
# {'outbreak': 5.0}
# {'panic': 7.0}
# {'performance': 6.0}
# {'plunge': 10.0}
# {'prodigy': 10.0}
# {'profanity': 5.0}
# {'prowl': 10.0}
# {'radiotherapy': 11.0}
# {'ragtime': 6.0}
# {'rambler': 10.0}
# {'relaxation': 4.0}
# {'replay': 7.0}
# {'residency': 5.0}
# {'savior': 9.0}
# {'scrimmage': 8.0}
# {'specs': 9.0}
# {'specter': 9.0}
# {'squall': 9.0}
# {'stimulus': 5.0}
# {'sublet': 6.0}
# {'teetotaler': 9.0}
# {'tenor': 5.0}
# {'thirst': 7.0}
# {'toiler': 9.0}
# {'transfer': 8.0}
# {'visibility': 6.0}
# {'vitals': 6.0}
# {'wretch': 11.0}
# {'adoption': 9.0}
# {'annoyer': 9.0}
# {'artisan': 10.0}
# {'astronomy': 10.0}
# {'biohazard': 6.0}
# {'captive': 9.0}
# {'casework': 8.0}
# {'circulation': 8.0}
# {'coding': 7.0}
# {'commuter': 10.0}
# {'compound': 8.0}
# {'confidant': 9.0}
# {'crime': 8.0}
# {'custody': 7.0}
# {'ejection': 6.0}
# {'evaporation': 5.0}
# {'example': 5.0}
# {'forgery': 9.0}
# {'fossilization': 4.0}
# {'fuzziness': 5.0}
# {'glitch': 6.0}
# {'handoff': 10.0}
# {'homosexuality': 6.0}
# {'immigration': 9.0}
# {'maneuver': 7.0}
# {'perk': 9.0}
# {'postponement': 5.0}
# {'preservative': 10.0}
# {'research': 8.0}
# {'rest': 4.0}
# {'retirement': 5.0}
# {'retraction': 8.0}
# {'retreat': 7.0}
# {'revolt': 7.0}
# {'rival': 9.0}
# {'simulation': 8.0}
# {'slogan': 6.0}
# {'summary': 5.0}
# {'tech': 8.0}
# {'transparency': 6.0}
# {'vocabulary': 12.0}
# {'volumes': 3.0}
# {'warfare': 7.0}
# {'wattage': 7.0}
# {'alternation': 9.0}
# {'appointment': 8.0}
# {'appreciator': 8.0}
# {'assemblage': 4.0}
# {'astrophysics': 11.0}
# {'bearings': 5.0}
# {'beneficiary': 10.0}
# {'biotech': 12.0}
# {'bluff': 7.0}
# {'bombard': 15.0}
# {'booking': 8.0}
# {'borderline': 7.0}
# {'bout': 8.0}
# {'bragger': 11.0}
# {'bylaw': 6.0}
# {'calculation': 7.0}
# {'caliber': 5.0}
# {'calibration': 6.0}
# {'campaign': 7.0}
# {'coconspirator': 12.0}
# {'code': 4.0}
# {'conjuror': 10.0}
# {'connection': 3.0}
# {'constriction': 7.0}
# {'contender': 9.0}
# {'contortion': 8.0}
# {'correction': 9.0}
# {'cosmetology': 8.0}
# {'coup': 6.0}
# {'defibrillation': 10.0}
# {'deformation': 7.0}
# {'degree': 4.0}
# {'descent': 7.0}
# {'dialogue': 7.0}
# {'dope': 12.0}
# {'ectoplasm': 4.0}
# {'electromagnetism': 9.0}
# {'embargo': 13.0}
# {'empire': 6.0}
# {'evaluation': 6.0}
# {'expansion': 9.0}
# {'exportation': 6.0}
# {'eyeful': 11.0}
# {'finder': 9.0}
# {'fodder': 13.0}
# {'force': 6.0}
# {'forefront': 10.0}
# {'friction': 5.0}
# {'fumigation': 10.0}
# {'genius': 9.0}
# {'geometry': 10.0}
# {'geophysics': 11.0}
# {'gesture': 8.0}
# {'glitz': 6.0}
# {'gossip': 7.0}
# {'grade': 5.0}
# {'handover': 10.0}
# {'hellhole': 5.0}
# {'humidity': 6.0}
# {'imbecile': 9.0}
# {'immobilization': 8.0}
# {'impalement': 10.0}
# {'inductor': 8.0}
# {'industrialist': 11.0}
# {'infiltrator': 14.0}
# {'influx': 5.0}
# {'internship': 8.0}
# {'intoxication': 6.0}
# {'introduction': 9.0}
# {'ion': 7.0}
# {'jumble': 6.0}
# {'juncture': 5.0}
# {'keeper': 10.0}
# {'lifeblood': 10.0}
# {'location': 3.0}
# {'longways': 17.0}
# {'lordship': 8.0}
# {'mastermind': 9.0}
# {'medium': 6.0}
# {'midpoint': 5.0}
# {'mimicry': 14.0}
# {'mismatch': 6.0}
# {'motherhood': 4.0}
# {'numerator': 6.0}
# {'oncology': 12.0}
# {'organization': 4.0}
# {'ornithology': 12.0}
# {'oxidization': 6.0}
# {'paleface': 9.0}
# {'peacemaker': 11.0}
# {'pigeonhole': 8.0}
# {'pounder': 6.0}
# {'priesthood': 7.0}
# {'producer': 10.0}
# {'prologue': 9.0}
# {'proton': 12.0}
# {'purveyor': 11.0}
# {'ragamuffin': 11.0}
# {'receivables': 5.0}
# {'removal': 9.0}
# {'replication': 9.0}
# {'response': 5.0}
# {'rubberneck': 10.0}
# {'sacrament': 8.0}
# {'search': 6.0}
# {'showstopper': 8.0}
# {'smidgen': 5.0}
# {'solver': 10.0}
# {'span': 6.0}
# {'specialist': 9.0}
# {'strain': 7.0}
# {'submission': 4.0}
# {'subroutine': 8.0}
# {'suburbanite': 10.0}
# {'sympathizer': 9.0}
# {'tattler': 10.0}
# {'telecommunication': 7.0}
# {'televangelism': 9.0}
# {'tourism': 9.0}
# {'trance': 6.0}
# {'underlay': 7.0}
# {'uproar': 6.0}
# {'widowhood': 6.0}
# {'yardage': 7.0}
# {'acceleration': 6.0}
# {'accumulation': 4.0}
# {'apologist': 9.0}
# {'aristocracy': 7.0}
# {'botany': 4.0}
# {'disagreement': 5.0}
# {'hollowness': 6.0}
# {'intro': 7.0}
# {'keynote': 5.0}
# {'maltreatment': 8.0}
# {'mankind': 16.0}
# {'megabits': 6.0}
# {'nickname': 7.0}
# {'nourishment': 5.0}
# {'overhaul': 11.0}
# {'pediatrics': 12.0}
# {'percentile': 10.0}
# {'pervert': 11.0}
# {'preamble': 9.0}
# {'programming': 8.0}
# {'quantity': 2.0}
# {'referendum': 7.0}
# {'relative': 8.0}
# {'sloppiness': 6.0}
# {'spectrum': 5.0}
# {'summons': 21.0}
# {'tearjerker': 5.0}
# {'untidiness': 6.0}
# {'winnings': 8.0}
# {'absorber': 10.0}
# {'accommodation': 8.0}
# {'adulterer': 10.0}
# {'aerodynamics': 11.0}
# {'altitude': 8.0}
# {'arrhythmia': 9.0}
# {'assessor': 12.0}
# {'blacklist': 7.0}
# {'boldface': 9.0}
# {'borderland': 6.0}
# {'breech': 6.0}
# {'breeding': 5.0}
# {'brood': 5.0}
# {'bullshit': 6.0}
# {'busybody': 10.0}
# {'catastrophe': 7.0}
# {'charge': 8.0}
# {'chronicle': 6.0}
# {'citizenship': 6.0}
# {'commentary': 5.0}
# {'conclave': 6.0}
# {'consummation': 10.0}
# {'deadlock': 7.0}
# {'deviation': 7.0}
# {'diagnostics': 12.0}
# {'diatribe': 7.0}
# {'disintegration': 7.0}
# {'downswing': 11.0}
# {'earshot': 8.0}
# {'electron': 10.0}
# {'enlarger': 8.0}
# {'enrollment': 8.0}
# {'evaluator': 10.0}
# {'exhaust': 11.0}
# {'expedition': 8.0}
# {'facilitator': 10.0}
# {'feature': 8.0}
# {'filthiness': 7.0}
# {'flexibility': 6.0}
# {'foe': 9.0}
# {'gigahertz': 5.0}
# {'gluttony': 7.0}
# {'greenness': 9.0}
# {'guild': 6.0}
# {'history': 5.0}
# {'hothead': 11.0}
# {'hypochondriac': 12.0}
# {'hypoglycemia': 7.0}
# {'hypotension': 8.0}
# {'infusion': 9.0}
# {'layman': 9.0}
# {'legend': 8.0}
# {'litigation': 8.0}
# {'locale': 7.0}
# {'manipulator': 3.0}
# {'maverick': 10.0}
# {'monopolist': 11.0}
# {'motionlessness': 4.0}
# {'nightmare': 7.0}
# {'nitrate': 10.0}
# {'ordnance': 8.0}
# {'overdrive': 5.0}
# {'partaker': 11.0}
# {'portrayer': 11.0}
# {'possession': 7.0}
# {'postgraduate': 11.0}
# {'prefect': 11.0}
# {'premiere': 7.0}
# {'profiteer': 9.0}
# {'purchase': 7.0}
# {'realm': 7.0}
# {'recuperation': 6.0}
# {'refiner': 10.0}
# {'remedy': 10.0}
# {'renegade': 11.0}
# {'reply': 5.0}
# {'repurchase': 8.0}
# {'rerun': 7.0}
# {'scholarship': 9.0}
# {'separation': 4.0}
# {'solicitation': 8.0}
# {'source': 5.0}
# {'statement': 4.0}
# {'strength': 4.0}
# {'subsidiary': 10.0}
# {'summertime': 6.0}
# {'swordsmanship': 6.0}
# {'talkativeness': 5.0}
# {'techno': 6.0}
# {'translation': 7.0}
# {'triplicate': 8.0}
# {'troublemaker': 9.0}
# {'turnaround': 6.0}
# {'twang': 6.0}
# {'undercurrent': 7.0}
# {'underworld': 5.0}
# {'unison': 7.0}
# {'viscosity': 5.0}
# {'wetback': 13.0}
# {'witchcraft': 9.0}
# {'lawsuit': 8.0}
# {'system': 6.0}
# {'transformation': 6.0}
# {'admirer': 9.0}
# {'adversary': 8.0}
# {'ailment': 7.0}
# {'alcoholism': 8.0}
# {'amplification': 10.0}
# {'antichrist': 8.0}
# {'archangel': 8.0}
# {'atheist': 10.0}
# {'beauty': 5.0}
# {'bloodline': 6.0}
# {'blurriness': 5.0}
# {'booster': 9.0}
# {'character': 8.0}
# {'clue': 4.0}
# {'constraint': 7.0}
# {'countermeasure': 11.0}
# {'coward': 8.0}
# {'curvature': 5.0}
# {'education': 6.0}
# {'encounter': 8.0}
# {'excursion': 10.0}
# {'extension': 6.0}
# {'fag': 10.0}
# {'fairyland': 8.0}
# {'fairytale': 5.0}
# {'fiend': 10.0}
# {'foreground': 9.0}
# {'freak': 7.0}
# {'girlhood': 7.0}
# {'hoaxer': 10.0}
# {'hobby': 8.0}
# {'infertility': 6.0}
# {'inheritor': 10.0}
# {'interference': 11.0}
# {'layover': 6.0}
# {'lightweight': 11.0}
# {'longitude': 11.0}
# {'luster': 7.0}
# {'medley': 6.0}
# {'microbiology': 11.0}
# {'montage': 10.0}
# {'narration': 4.0}
# {'nearsightedness': 12.0}
# {'nutcase': 11.0}
# {'opacity': 6.0}
# {'paraplegia': 11.0}
# {'patter': 7.0}
# {'philanthropist': 11.0}
# {'prepayment': 9.0}
# {'process': 6.0}
# {'progeny': 9.0}
# {'propagandist': 9.0}
# {'proximity': 8.0}
# {'rebellion': 7.0}
# {'rebuttal': 9.0}
# {'reception': 6.0}
# {'resignation': 6.0}
# {'scoundrel': 9.0}
# {'slapstick': 7.0}
# {'spoiler': 11.0}
# {'standoff': 6.0}
# {'stiffness': 6.0}
# {'suppresser': 9.0}
# {'suppressor': 9.0}
# {'teaser': 9.0}
# {'techie': 11.0}
# {'theft': 10.0}
# {'treatment': 8.0}
# {'tribune': 10.0}
# {'unconsciousness': 7.0}
# {'varsity': 6.0}
# {'veto': 8.0}
# {'amplitude': 9.0}
# {'asset': 4.0}
# {'astonishment': 5.0}
# {'bigwig': 10.0}
# {'bootleg': 20.0}
# {'calcification': 5.0}
# {'cliffhanger': 6.0}
# {'clinch': 9.0}
# {'computation': 7.0}
# {'contester': 9.0}
# {'counterattack': 8.0}
# {'cubism': 6.0}
# {'deposition': 5.0}
# {'dermatology': 12.0}
# {'elasticity': 5.0}
# {'entertainment': 7.0}
# {'filler': 9.0}
# {'flashpoint': 10.0}
# {'imitator': 11.0}
# {'joiner': 11.0}
# {'leavings': 5.0}
# {'malleability': 5.0}
# {'mechanization': 5.0}
# {'monarchist': 11.0}
# {'myopia': 12.0}
# {'nature': 4.0}
# {'neurotransmitter': 12.0}
# {'poltergeist': 7.0}
# {'pursuit': 8.0}
# {'regeneration': 4.0}
# {'reproduction': 4.0}
# {'selector': 8.0}
# {'series': 5.0}
# {'spendthrift': 11.0}
# {'spree': 11.0}
# {'stoppage': 5.0}
# {'subcompact': 13.0}
# {'temp': 9.0}
# {'testimonial': 5.0}
# {'theatricals': 7.0}
# {'throwaway': 12.0}
# {'timekeeping': 6.0}
# {'twain': 8.0}
# {'washday': 7.0}
# {'wisecrack': 6.0}
# {'commodity': 5.0}
# {'ode': 8.0}
# {'pestilence': 13.0}
# {'strider': 10.0}
# {'whoremonger': 11.0}
# {'bedtime': 9.0}
# {'betrayer': 10.0}
# {'biotechnology': 12.0}
# {'bulimia': 8.0}
# {'captor': 8.0}
# {'chilliness': 13.0}
# {'communication': 5.0}
# {'confiscation': 8.0}
# {'decibel': 6.0}
# {'deployment': 7.0}
# {'dispute': 7.0}
# {'format': 5.0}
# {'fortune': 4.0}
# {'geology': 10.0}
# {'giveaway': 7.0}
# {'inbreeding': 7.0}
# {'joke': 5.0}
# {'magic': 7.0}
# {'microsecond': 4.0}
# {'million': 7.0}
# {'mission': 6.0}
# {'monoxide': 11.0}
# {'ordinance': 6.0}
# {'percentage': 7.0}
# {'prank': 9.0}
# {'rush': 8.0}
# {'shutout': 8.0}
# {'spec': 6.0}
# {'transaction': 6.0}
# {'wimp': 9.0}
# {'asymmetry': 5.0}
# {'balance': 6.0}
# {'balancer': 11.0}
# {'boost': 7.0}
# {'bribery': 10.0}
# {'buffer': 10.0}
# {'chill': 13.0}
# {'comfort': 5.0}
# {'commune': 7.0}
# {'disposal': 5.0}
# {'embolism': 4.0}
# {'endowment': 7.0}
# {'extras': 11.0}
# {'faker': 11.0}
# {'flatterer': 9.0}
# {'fortunetelling': 6.0}
# {'fury': 7.0}
# {'gig': 12.0}
# {'growth': 4.0}
# {'hallmark': 5.0}
# {'heaviness': 6.0}
# {'hypertension': 8.0}
# {'incantation': 6.0}
# {'interchange': 7.0}
# {'iteration': 3.0}
# {'largeness': 6.0}
# {'liaison': 6.0}
# {'locals': 8.0}
# {'nemesis': 8.0}
# {'proceedings': 7.0}
# {'query': 8.0}
# {'quota': 5.0}
# {'recirculation': 13.0}
# {'redeemer': 9.0}
# {'remnant': 5.0}
# {'staging': 6.0}
# {'sum': 5.0}
# {'verbalization': 6.0}
# {'allotment': 6.0}
# {'cutaway': 7.0}
# {'cutback': 9.0}
# {'easement': 10.0}
# {'facet': 9.0}
# {'freeware': 8.0}
# {'gastronomy': 10.0}
# {'government': 6.0}
# {'grayness': 7.0}
# {'grumbler': 10.0}
# {'irradiation': 5.0}
# {'larcenist': 13.0}
# {'megahertz': 5.0}
# {'offshoot': 5.0}
# {'oracle': 11.0}
# {'raid': 9.0}
# {'statistic': 6.0}
# {'warrantee': 10.0}
# {'discourse': 5.0}
# {'entomology': 12.0}
# {'gab': 7.0}
# {'herald': 10.0}
# {'information': 4.0}
# {'lightheadedness': 7.0}
# {'numskull': 10.0}
# {'oratory': 7.0}
# {'parentage': 6.0}
# {'quest': 7.0}
# {'recommendation': 6.0}
# {'rep': 13.0}
# {'revolution': 6.0}
# {'sedation': 6.0}
# {'sensation': 7.0}
# {'superpower': 8.0}
# {'vanquisher': 10.0}
# {'wisp': 7.0}
# {'action': 5.0}
# {'afternoons': 6.0}
# {'age': 4.0}
# {'alias': 6.0}
# {'apology': 5.0}
# {'atrophy': 7.0}
# {'baseline': 5.0}
# {'bracer': 7.0}
# {'climax': 6.0}
# {'cohabitation': 8.0}
# {'combination': 4.0}
# {'confederation': 6.0}
# {'coordination': 5.0}
# {'devotee': 9.0}
# {'emancipator': 11.0}
# {'embellishment': 8.0}
# {'enquirer': 11.0}
# {'exchanger': 9.0}
# {'exorcism': 7.0}
# {'expulsion': 7.0}
# {'fabrication': 6.0}
# {'fatso': 9.0}
# {'flaw': 5.0}
# {'gravity': 8.0}
# {'holiday': 7.0}
# {'hysteria': 10.0}
# {'incident': 5.0}
# {'insurance': 6.0}
# {'isolationist': 9.0}
# {'level': 4.0}
# {'meld': 9.0}
# {'occultist': 8.0}
# {'ophthalmology': 12.0}
# {'participation': 6.0}
# {'penalty': 7.0}
# {'phrase': 14.0}
# {'preserver': 10.0}
# {'provocateur': 13.0}
# {'publishing': 9.0}
# {'queue': 6.0}
# {'rank': 6.0}
# {'refraction': 6.0}
# {'regime': 6.0}
# {'reinforcement': 7.0}
# {'sales': 9.0}
# {'sauciness': 6.0}
# {'sequel': 7.0}
# {'slippage': 4.0}
# {'spitfire': 9.0}
# {'stern': 8.0}
# {'stigmatism': 5.0}
# {'supermom': 14.0}
# {'timing': 6.0}
# {'underling': 10.0}
# {'viewing': 4.0}
# {'addiction': 6.0}
# {'argument': 5.0}
# {'banter': 6.0}
# {'blitz': 9.0}
# {'breed': 7.0}
# {'casualty': 10.0}
# {'catalyst': 8.0}
# {'coagulator': 6.0}
# {'conveyance': 7.0}
# {'counseling': 4.0}
# {'counteroffer': 5.0}
# {'earl': 13.0}
# {'electrostatics': 10.0}
# {'emancipationist': 10.0}
# {'esquire': 11.0}
# {'expert': 8.0}
# {'faction': 6.0}
# {'forerunner': 8.0}
# {'gigabyte': 6.0}
# {'harmonizer': 11.0}
# {'highflier': 9.0}
# {'iconoclast': 10.0}
# {'inquirer': 11.0}
# {'intermission': 7.0}
# {'intervention': 7.0}
# {'knockoff': 8.0}
# {'lapse': 7.0}
# {'meditation': 9.0}
# {'nanosecond': 4.0}
# {'nomination': 9.0}
# {'pitfall': 6.0}
# {'puzzler': 7.0}
# {'reimbursement': 10.0}
# {'relaxant': 7.0}
# {'result': 4.0}
# {'sanctum': 7.0}
# {'sleepiness': 5.0}
# {'tales': 4.0}
# {'therapy': 10.0}
# {'typhus': 13.0}
# {'verb': 8.0}
# {'virtuoso': 9.0}
# {'beta': 8.0}
# {'clank': 7.0}
# {'enchantress': 11.0}
# {'exobiology': 11.0}
# {'inactivity': 4.0}
# {'scrounger': 12.0}
# {'suppleness': 7.0}
# {'task': 7.0}
# {'admission': 8.0}
# {'adornment': 6.0}
# {'anarchist': 9.0}
# {'ancestry': 6.0}
# {'arousal': 8.0}
# {'behaviorist': 10.0}
# {'bigamist': 11.0}
# {'bigness': 6.0}
# {'biophysics': 10.0}
# {'busywork': 7.0}
# {'century': 5.0}
# {'conjurer': 10.0}
# {'countersign': 10.0}
# {'crackdown': 8.0}
# {'criminology': 10.0}
# {'deceleration': 6.0}
# {'decryption': 8.0}
# {'defiler': 9.0}
# {'effects': 6.0}
# {'emersion': 7.0}
# {'enemy': 7.0}
# {'enumeration': 7.0}
# {'exploration': 11.0}
# {'imitation': 7.0}
# {'instigator': 10.0}
# {'layoff': 10.0}
# {'messiness': 6.0}
# {'miniaturization': 10.0}
# {'mirth': 7.0}
# {'mutilator': 8.0}
# {'nanotechnology': 8.0}
# {'neurophysiology': 14.0}
# {'newbie': 10.0}
# {'nonpayment': 7.0}
# {'outage': 4.0}
# {'peasantry': 5.0}
# {'polygamy': 8.0}
# {'profession': 6.0}
# {'pullback': 8.0}
# {'radiology': 11.0}
# {'relaxer': 4.0}
# {'restorer': 10.0}
# {'rhapsody': 8.0}
# {'rookie': 10.0}
# {'spoils': 6.0}
# {'stint': 6.0}
# {'subtraction': 10.0}
# {'support': 6.0}
# {'surrogate': 10.0}
# {'sweetness': 9.0}
# {'takeover': 6.0}
# {'tradecraft': 7.0}
# {'visualization': 7.0}
# {'zenith': 6.0}
# {'adjournment': 9.0}
# {'battering': 8.0}
# {'buzzword': 5.0}
# {'category': 4.0}
# {'compliment': 6.0}
# {'customs': 10.0}
# {'finisher': 15.0}
# {'groundwork': 9.0}
# {'grownup': 8.0}
# {'hoarseness': 6.0}
# {'hydrophobia': 7.0}
# {'hypnotism': 7.0}
# {'laundering': 8.0}
# {'nutrition': 4.0}
# {'orchestration': 7.0}
# {'partnership': 7.0}
# {'perfectionist': 9.0}
# {'phonics': 11.0}
# {'populace': 4.0}
# {'predictor': 10.0}
# {'procrastinator': 9.0}
# {'recreation': 6.0}
# {'security': 6.0}
# {'substitute': 5.0}
# {'term': 6.0}
# {'tidiness': 6.0}
# {'vertigo': 7.0}
# {'virginity': 5.0}
# {'adjustment': 8.0}
# {'adolescence': 6.0}
# {'arranger': 10.0}
# {'blight': 9.0}
# {'bombardment': 4.0}
# {'codefendant': 11.0}
# {'compilation': 10.0}
# {'complainer': 10.0}
# {'delicacy': 5.0}
# {'dioxide': 11.0}
# {'dissertation': 6.0}
# {'domination': 7.0}
# {'draughts': 9.0}
# {'durability': 7.0}
# {'encore': 11.0}
# {'evildoer': 10.0}
# {'importation': 8.0}
# {'inhibitor': 4.0}
# {'interface': 8.0}
# {'internment': 8.0}
# {'liquidation': 9.0}
# {'nobility': 7.0}
# {'periphery': 6.0}
# {'piracy': 13.0}
# {'refusal': 7.0}
# {'republic': 5.0}
# {'review': 8.0}
# {'shift': 8.0}
# {'singsong': 7.0}
# {'stamina': 6.0}
# {'stinker': 10.0}
# {'stronghold': 7.0}
# {'tempo': 5.0}
# {'tirade': 10.0}
# {'updraft': 10.0}
# {'backer': 11.0}
# {'clamor': 7.0}
# {'corporal': 13.0}
# {'deletion': 5.0}
# {'division': 8.0}
# {'firebrand': 6.0}
# {'frequenter': 11.0}
# {'inset': 8.0}
# {'moron': 9.0}
# {'overtime': 6.0}
# {'pseudonym': 6.0}
# {'reflux': 9.0}
# {'relationship': 3.0}
# {'repressor': 4.0}
# {'sacrifice': 5.0}
# {'surcharge': 8.0}
# {'theses': 8.0}
# {'tidings': 5.0}
# {'adultery': 9.0}
# {'announcement': 5.0}
# {'attractor': 9.0}
# {'brawn': 5.0}
# {'briefing': 7.0}
# {'chaos': 6.0}
# {'confederacy': 5.0}
# {'consolidation': 7.0}
# {'contagion': 11.0}
# {'corporation': 8.0}
# {'delay': 5.0}
# {'direction': 6.0}
# {'discount': 9.0}
# {'eliminator': 4.0}
# {'evolutionist': 11.0}
# {'factor': 8.0}
# {'furlong': 6.0}
# {'imaging': 7.0}
# {'kleptomaniac': 10.0}
# {'lesson': 10.0}
# {'middleman': 12.0}
# {'modification': 7.0}
# {'oath': 6.0}
# {'order': 7.0}
# {'parting': 6.0}
# {'pedigree': 6.0}
# {'phosphorescence': 12.0}
# {'potshot': 7.0}
# {'powerhouse': 9.0}
# {'proportionality': 5.0}
# {'republican': 10.0}
# {'revival': 8.0}
# {'science': 7.0}
# {'seamanship': 6.0}
# {'solo': 6.0}
# {'struggle': 7.0}
# {'surname': 6.0}
# {'sweetheart': 9.0}
# {'symmetry': 5.0}
# {'terrorism': 10.0}
# {'tightness': 7.0}
# {'toxicity': 4.0}
# {'turnabout': 7.0}
# {'update': 6.0}
# {'weirdo': 10.0}
# {'administration': 8.0}
# {'compromiser': 10.0}
# {'crusade': 9.0}
# {'decontamination': 10.0}
# {'deepness': 7.0}
# {'dispersal': 12.0}
# {'dud': 10.0}
# {'forecast': 6.0}
# {'furies': 7.0}
# {'grubbiness': 7.0}
# {'hodgepodge': 5.0}
# {'hypnosis': 6.0}
# {'indices': 6.0}
# {'jaunt': 10.0}
# {'knighthood': 8.0}
# {'laughingstock': 9.0}
# {'luminary': 11.0}
# {'motherland': 8.0}
# {'nemeses': 8.0}
# {'pharmacology': 12.0}
# {'retrial': 9.0}
# {'saboteur': 10.0}
# {'shakeup': 10.0}
# {'squalor': 7.0}
# {'storyline': 9.0}
# {'surge': 8.0}
# {'trimester': 5.0}
# {'warpath': 9.0}
# {'aeration': 4.0}
# {'babyhood': 6.0}
# {'confessional': 10.0}
# {'decease': 6.0}
# {'denomination': 6.0}
# {'dictatorship': 6.0}
# {'disturber': 10.0}
# {'dweeb': 9.0}
# {'enquiry': 8.0}
# {'expatriate': 10.0}
# {'judgeship': 8.0}
# {'provoker': 10.0}
# {'quietness': 6.0}
# {'reiteration': 8.0}
# {'rematch': 7.0}
# {'rollback': 8.0}
# {'sleeplessness': 5.0}
# {'washout': 8.0}
# {'whiff': 10.0}
# {'anticoagulation': 10.0}
# {'bargaining': 7.0}
# {'boycott': 8.0}
# {'breathlessness': 8.0}
# {'captivity': 7.0}
# {'charm': 7.0}
# {'commerce': 7.0}
# {'devastation': 8.0}
# {'dividend': 10.0}
# {'doer': 8.0}
# {'endocrinology': 12.0}
# {'entanglement': 8.0}
# {'exhibitionism': 5.0}
# {'expenditure': 5.0}
# {'export': 6.0}
# {'fatherhood': 4.0}
# {'finale': 9.0}
# {'fluster': 7.0}
# {'habit': 6.0}
# {'healing': 5.0}
# {'individualist': 8.0}
# {'internationalist': 9.0}
# {'lifelessness': 4.0}
# {'maternity': 6.0}
# {'oppressor': 10.0}
# {'outburst': 6.0}
# {'palsy': 10.0}
# {'policy': 8.0}
# {'pundit': 10.0}
# {'roleplaying': 13.0}
# {'romp': 8.0}
# {'sigma': 8.0}
# {'slurry': 9.0}
# {'sovereignty': 8.0}
# {'stead': 9.0}
# {'stealth': 7.0}
# {'synopsis': 6.0}
# {'thinness': 6.0}
# {'uptake': 5.0}
# {'antagonist': 8.0}
# {'bestiality': 5.0}
# {'biosynthesis': 6.0}
# {'bounciness': 6.0}
# {'breakdown': 10.0}
# {'chauvinist': 11.0}
# {'cleansing': 9.0}
# {'coalition': 5.0}
# {'cohort': 7.0}
# {'dictation': 6.0}
# {'engagement': 7.0}
# {'immunotherapy': 11.0}
# {'interruption': 7.0}
# {'linkage': 4.0}
# {'proposal': 4.0}
# {'reduction': 8.0}
# {'rendezvous': 8.0}
# {'retort': 7.0}
# {'silliness': 5.0}
# {'wayside': 9.0}
# {'amino': 5.0}
# {'amount': 5.0}
# {'appetite': 7.0}
# {'approach': 9.0}
# {'arithmetic': 10.0}
# {'augmentation': 7.0}
# {'blankness': 6.0}
# {'convection': 5.0}
# {'cusp': 8.0}
# {'detainment': 7.0}
# {'exchange': 6.0}
# {'fatherland': 8.0}
# {'hypnotherapy': 12.0}
# {'indictment': 7.0}
# {'interaction': 6.0}
# {'malfunction': 6.0}
# {'mayday': 5.0}
# {'mocker': 10.0}
# {'molestation': 11.0}
# {'nationality': 4.0}
# {'noisiness': 6.0}
# {'oddball': 9.0}
# {'outtake': 9.0}
# {'payoff': 8.0}
# {'pliability': 7.0}
# {'publicity': 4.0}
# {'pungency': 5.0}
# {'regimen': 7.0}
# {'revision': 9.0}
# {'sake': 6.0}
# {'sampling': 7.0}
# {'semi': 7.0}
# {'tenderfoot': 10.0}
# {'thermodynamics': 10.0}
# {'advice': 5.0}
# {'beginner': 9.0}
# {'believer': 10.0}
# {'clause': 14.0}
# {'council': 7.0}
# {'curfew': 5.0}
# {'dandy': 11.0}
# {'engorgement': 9.0}
# {'festivity': 7.0}
# {'freestyle': 7.0}
# {'getup': 10.0}
# {'grouch': 10.0}
# {'incandescence': 11.0}
# {'indicator': 6.0}
# {'jihad': 8.0}
# {'mantra': 7.0}
# {'masochist': 12.0}
# {'nexus': 5.0}
# {'orthography': 5.0}
# {'preface': 9.0}
# {'repayment': 9.0}
# {'repose': 6.0}
# {'shakedown': 9.0}
# {'snitcher': 13.0}
# {'sourpuss': 9.0}
# {'vegetarianism': 7.0}
# {'abrasiveness': 7.0}
# {'activity': 5.0}
# {'advocate': 8.0}
# {'blockbuster': 11.0}
# {'christening': 10.0}
# {'debt': 6.0}
# {'dexterity': 6.0}
# {'dilapidation': 8.0}
# {'directive': 7.0}
# {'displacement': 9.0}
# {'dryness': 5.0}
# {'eradicator': 9.0}
# {'fact': 5.0}
# {'grump': 10.0}
# {'heft': 7.0}
# {'hypochondria': 7.0}
# {'maidenhood': 7.0}
# {'management': 7.0}
# {'misfit': 9.0}
# {'nosiness': 9.0}
# {'opportunist': 11.0}
# {'outing': 10.0}
# {'overpopulation': 4.0}
# {'paradise': 5.0}
# {'physiology': 11.0}
# {'presence': 5.0}
# {'ragtag': 5.0}
# {'rants': 9.0}
# {'redeployment': 8.0}
# {'sadist': 12.0}
# {'saturation': 6.0}
# {'soliloquy': 5.0}
# {'theme': 4.0}
# {'trait': 3.0}
# {'trauma': 8.0}
# {'treble': 6.0}
# {'trillion': 5.0}
# {'undulation': 6.0}
# {'whopper': 7.0}
# {'abuse': 8.0}
# {'access': 9.0}
# {'commotion': 5.0}
# {'concession': 12.0}
# {'cootie': 11.0}
# {'credit': 5.0}
# {'cult': 7.0}
# {'downer': 9.0}
# {'dynamo': 11.0}
# {'enormousness': 7.0}
# {'escrow': 11.0}
# {'flattery': 7.0}
# {'fortnight': 5.0}
# {'looseness': 7.0}
# {'malformation': 9.0}
# {'moocher': 12.0}
# {'procreation': 6.0}
# {'quotient': 5.0}
# {'sellout': 9.0}
# {'shocker': 9.0}
# {'slipstream': 5.0}
# {'swiftness': 6.0}
# {'tussle': 8.0}
# {'underclass': 5.0}
# {'underdog': 10.0}
# {'undernourishment': 8.0}
# {'vagrancy': 6.0}
# {'vampirism': 6.0}
# {'apprenticeship': 8.0}
# {'cadence': 8.0}
# {'connoisseur': 10.0}
# {'contamination': 6.0}
# {'conversationalist': 11.0}
# {'coverage': 6.0}
# {'crosscurrent': 7.0}
# {'delegation': 5.0}
# {'disturbance': 6.0}
# {'emigration': 9.0}
# {'epidemiology': 12.0}
# {'equilateral': 5.0}
# {'ghoul': 13.0}
# {'grief': 7.0}
# {'inquiry': 8.0}
# {'instant': 7.0}
# {'interception': 7.0}
# {'loaner': 10.0}
# {'markup': 10.0}
# {'millionth': 6.0}
# {'miscreant': 10.0}
# {'misogynist': 12.0}
# {'oldness': 5.0}
# {'pang': 5.0}
# {'percent': 7.0}
# {'pushover': 10.0}
# {'reflexology': 11.0}
# {'routine': 7.0}
# {'snob': 10.0}
# {'stupor': 7.0}
# {'tabulation': 5.0}
# {'testament': 8.0}
# {'tribunal': 6.0}
# {'utterance': 4.0}
# {'vintage': 18.0}
# {'vocation': 7.0}
# {'annihilation': 10.0}
# {'autism': 8.0}
# {'bidding': 6.0}
# {'cloning': 11.0}
# {'colonization': 10.0}
# {'complaint': 7.0}
# {'covenant': 11.0}
# {'crux': 5.0}
# {'enchanter': 10.0}
# {'engineering': 10.0}
# {'event': 3.0}
# {'extortion': 9.0}
# {'forces': 6.0}
# {'frequency': 5.0}
# {'impeachment': 7.0}
# {'inaccuracy': 4.0}
# {'indenture': 6.0}
# {'inflow': 5.0}
# {'integrator': 9.0}
# {'kleptomania': 6.0}
# {'legion': 8.0}
# {'life': 5.0}
# {'masochism': 7.0}
# {'mastery': 5.0}
# {'millisecond': 4.0}
# {'monopoly': 7.0}
# {'neutron': 12.0}
# {'omen': 7.0}
# {'overload': 7.0}
# {'rebound': 6.0}
# {'rottenness': 8.0}
# {'sharpness': 6.0}
# {'skirmish': 8.0}
# {'swagger': 13.0}
# {'trifle': 9.0}
# {'weightlessness': 6.0}
# {'accreditation': 10.0}
# {'aggression': 7.0}
# {'ambassadorship': 8.0}
# {'bachelorhood': 6.0}
# {'bankruptcy': 7.0}
# {'bisexuality': 7.0}
# {'bitchiness': 7.0}
# {'blockhead': 10.0}
# {'byte': 6.0}
# {'challenger': 9.0}
# {'clique': 5.0}
# {'counterirritant': 8.0}
# {'custom': 9.0}
# {'dabbler': 9.0}
# {'danger': 5.0}
# {'decree': 8.0}
# {'elongation': 11.0}
# {'entity': 0.0}
# {'error': 6.0}
# {'expanse': 7.0}
# {'expressionist': 10.0}
# {'gains': 4.0}
# {'gentile': 9.0}
# {'guardianship': 7.0}
# {'holdout': 10.0}
# {'insomnia': 8.0}
# {'luminosity': 5.0}
# {'novice': 9.0}
# {'problem': 6.0}
# {'recovery': 8.0}
# {'repossession': 6.0}
# {'resistance': 6.0}
# {'reverberation': 6.0}
# {'ruddiness': 7.0}
# {'severance': 7.0}
# {'sleight': 6.0}
# {'swindle': 10.0}
# {'tiredness': 5.0}
# {'twit': 9.0}
# {'uppers': 11.0}
# {'yuppie': 10.0}
# {'analog': 6.0}
# {'aura': 7.0}
# {'betrothal': 10.0}
# {'bungler': 10.0}
# {'caste': 5.0}
# {'conductivity': 6.0}
# {'coolness': 6.0}
# {'deportment': 4.0}
# {'derailment': 8.0}
# {'dialect': 6.0}
# {'dingbat': 9.0}
# {'dinky': 12.0}
# {'disinfection': 10.0}
# {'distension': 10.0}
# {'diversion': 6.0}
# {'doohickey': 4.0}
# {'electorate': 4.0}
# {'embezzlement': 11.0}
# {'escapade': 8.0}
# {'freebie': 7.0}
# {'heroism': 7.0}
# {'hoax': 10.0}
# {'incursion': 8.0}
# {'jabber': 6.0}
# {'lookup': 6.0}
# {'masculinity': 7.0}
# {'moralist': 11.0}
# {'noon': 9.0}
# {'peon': 12.0}
# {'pinnacle': 8.0}
# {'procedure': 6.0}
# {'proof': 6.0}
# {'quickie': 10.0}
# {'retailing': 9.0}
# {'retardant': 4.0}
# {'style': 4.0}
# {'submersion': 9.0}
# {'taxation': 7.0}
# {'toil': 7.0}
# {'tribute': 5.0}
# {'violation': 9.0}
# {'vocalization': 3.0}
# {'agenda': 7.0}
# {'deadline': 4.0}
# {'deceiver': 10.0}
# {'distress': 6.0}
# {'parole': 10.0}
# {'politics': 4.0}
# {'pro': 10.0}
# {'riffraff': 5.0}
# {'shares': 5.0}
# {'tiptop': 5.0}
# {'articulation': 6.0}
# {'citizenry': 3.0}
# {'conduction': 6.0}
# {'cosmopolitan': 10.0}
# {'crossover': 4.0}
# {'estimate': 9.0}
# {'gamut': 7.0}
# {'limbo': 7.0}
# {'logarithm': 8.0}
# {'minority': 4.0}
# {'nimrod': 10.0}
# {'overabundance': 6.0}
# {'prospectus': 5.0}
# {'provision': 9.0}
# {'rental': 5.0}
# {'restoration': 6.0}
# {'sandman': 9.0}
# {'segregation': 4.0}
# {'signatory': 8.0}
# {'steadiness': 5.0}
# {'tinge': 5.0}
# {'accumulator': 9.0}
# {'acronym': 7.0}
# {'anecdote': 8.0}
# {'annuity': 9.0}
# {'assent': 7.0}
# {'bigamy': 8.0}
# {'cakewalk': 17.0}
# {'consequence': 4.0}
# {'contrast': 4.0}
# {'couture': 9.0}
# {'craftsmanship': 6.0}
# {'cynic': 10.0}
# {'demander': 8.0}
# {'diction': 7.0}
# {'digitalization': 10.0}
# {'disbursement': 7.0}
# {'downbeat': 6.0}
# {'dyslexia': 8.0}
# {'ecology': 6.0}
# {'excuser': 8.0}
# {'immersion': 9.0}
# {'kilter': 6.0}
# {'liquidity': 7.0}
# {'modulation': 7.0}
# {'naysayer': 10.0}
# {'odyssey': 10.0}
# {'overheads': 8.0}
# {'permeability': 6.0}
# {'scam': 11.0}
# {'smithereens': 4.0}
# {'superconductivity': 8.0}
# {'tamer': 11.0}
# {'telekinesis': 5.0}
# {'touchstone': 4.0}
# {'trivia': 3.0}
# {'tryout': 10.0}
# {'upstart': 10.0}
# {'victimizer': 9.0}
# {'withholder': 8.0}
# {'birthrate': 5.0}
# {'burden': 8.0}
# {'cavalier': 11.0}
# {'clash': 7.0}
# {'cleanliness': 11.0}
# {'consignment': 7.0}
# {'counterpart': 5.0}
# {'deflation': 6.0}
# {'deposer': 13.0}
# {'deterrent': 6.0}
# {'diagnosis': 8.0}
# {'disorganization': 6.0}
# {'edict': 6.0}
# {'forfeiture': 6.0}
# {'goddess': 8.0}
# {'harmonics': 11.0}
# {'hertz': 5.0}
# {'heterosexuality': 6.0}
# {'libido': 7.0}
# {'linguistics': 8.0}
# {'localization': 7.0}
# {'loophole': 7.0}
# {'master': 10.0}
# {'matriarchy': 5.0}
# {'meteorology': 6.0}
# {'millennium': 5.0}
# {'relocation': 9.0}
# {'reprimand': 6.0}
# {'reversal': 8.0}
# {'sissy': 9.0}
# {'squabble': 9.0}
# {'wartime': 5.0}
# {'wealth': 6.0}
# {'worrywart': 10.0}
# {'acknowledgement': 6.0}
# {'alarmist': 9.0}
# {'baroque': 6.0}
# {'charity': 8.0}
# {'cocksucker': 9.0}
# {'coherence': 6.0}
# {'descendent': 9.0}
# {'equilibrium': 5.0}
# {'fallout': 10.0}
# {'frailty': 9.0}
# {'harm': 8.0}
# {'induction': 7.0}
# {'outcast': 9.0}
# {'photojournalism': 9.0}
# {'position': 5.0}
# {'rascal': 10.0}
# {'reformist': 9.0}
# {'scenario': 7.0}
# {'slowness': 6.0}
# {'stress': 6.0}
# {'subsection': 5.0}
# {'synchronization': 4.0}
# {'togetherness': 8.0}
# {'torment': 8.0}
# {'void': 6.0}
# {'whir': 6.0}
# {'ally': 8.0}
# {'ascent': 5.0}
# {'digitization': 10.0}
# {'evolution': 3.0}
# {'expiration': 5.0}
# {'extrusion': 7.0}
# {'fucker': 9.0}
# {'netherworld': 8.0}
# {'pledge': 8.0}
# {'psychiatry': 12.0}
# {'sense': 8.0}
# {'sexuality': 6.0}
# {'solution': 8.0}
# {'tradeoff': 7.0}
# {'acquisition': 6.0}
# {'antics': 7.0}
# {'commemoration': 7.0}
# {'dream': 8.0}
# {'ethnicity': 4.0}
# {'ferociousness': 8.0}
# {'gall': 11.0}
# {'happiness': 7.0}
# {'improvement': 7.0}
# {'juggernaut': 4.0}
# {'larceny': 10.0}
# {'leverage': 7.0}
# {'lightness': 7.0}
# {'mediation': 7.0}
# {'poundage': 8.0}
# {'propulsion': 7.0}
# {'retrovirus': 12.0}
# {'ritual': 10.0}
# {'sojourner': 10.0}
# {'sponsorship': 8.0}
# {'sustainer': 10.0}
# {'tension': 8.0}
# {'venture': 8.0}
# {'vigil': 11.0}
# {'wizardry': 6.0}
# {'adventure': 8.0}
# {'aftertaste': 9.0}
# {'aggressiveness': 5.0}
# {'aloha': 5.0}
# {'arachnophobia': 12.0}
# {'bargain': 6.0}
# {'bestseller': 11.0}
# {'collaboration': 7.0}
# {'coloration': 6.0}
# {'content': 4.0}
# {'countermove': 8.0}
# {'cuteness': 6.0}
# {'ditto': 7.0}
# {'enunciation': 7.0}
# {'exodus': 7.0}
# {'fertility': 5.0}
# {'fervor': 6.0}
# {'handedness': 6.0}
# {'hesitation': 9.0}
# {'hierarchy': 6.0}
# {'highroad': 8.0}
# {'impact': 6.0}
# {'ironclad': 13.0}
# {'luxury': 6.0}
# {'manhood': 6.0}
# {'millennia': 5.0}
# {'mineralogy': 11.0}
# {'nearside': 7.0}
# {'occult': 3.0}
# {'paternity': 4.0}
# {'patriarchy': 5.0}
# {'patsy': 9.0}
# {'pedophilia': 8.0}
# {'physic': 8.0}
# {'plagiarism': 5.0}
# {'plural': 7.0}
# {'proceeds': 9.0}
# {'production': 5.0}
# {'request': 4.0}
# {'scorn': 6.0}
# {'spellbinder': 12.0}
# {'stimuli': 5.0}
# {'suspect': 8.0}
# {'tomfoolery': 8.0}
# {'topic': 4.0}
# {'urbanization': 5.0}
# {'voodoo': 4.0}
# {'weakness': 5.0}
# {'workings': 8.0}
# {'androgyny': 7.0}
# {'arraignment': 7.0}
# {'bioelectricity': 6.0}
# {'blasphemer': 9.0}
# {'brotherhood': 4.0}
# {'chairmanship': 8.0}
# {'ex': 11.0}
# {'extravaganza': 8.0}
# {'fullness': 6.0}
# {'halftime': 5.0}
# {'harassment': 8.0}
# {'headmastership': 9.0}
# {'hypothyroidism': 8.0}
# {'lawlessness': 5.0}
# {'nearness': 7.0}
# {'override': 7.0}
# {'physiotherapy': 11.0}
# {'protagonist': 9.0}
# {'session': 7.0}
# {'yahoo': 10.0}
# {'advance': 7.0}
# {'alibi': 8.0}
# {'appearance': 4.0}
# {'buster': 11.0}
# {'cataclysm': 6.0}
# {'catechism': 9.0}
# {'characteristics': 8.0}
# {'cheerfulness': 3.0}
# {'demigod': 9.0}
# {'detection': 7.0}
# {'dole': 6.0}
# {'economy': 4.0}
# {'equivalent': 4.0}
# {'expense': 7.0}
# {'fear': 6.0}
# {'heavens': 8.0}
# {'hyperactivity': 7.0}
# {'interval': 3.0}
# {'irritation': 6.0}
# {'isometrics': 10.0}
# {'journey': 9.0}
# {'law': 4.0}
# {'neuropathy': 9.0}
# {'occupancy': 6.0}
# {'occurrence': 4.0}
# {'oldie': 7.0}
# {'outreach': 9.0}
# {'parlay': 12.0}
# {'proportion': 6.0}
# {'retardation': 6.0}
# {'rule': 7.0}
# {'specialization': 8.0}
# {'trump': 11.0}
# {'unfitness': 8.0}
# {'welfare': 8.0}
# {'yuletide': 6.0}
# {'analysis': 8.0}
# {'analyzer': 8.0}
# {'collaborationist': 13.0}
# {'constituency': 5.0}
# {'defrauder': 11.0}
# {'dimwit': 9.0}
# {'emergence': 6.0}
# {'gratitude': 5.0}
# {'grounding': 6.0}
# {'impediment': 6.0}
# {'insertion': 4.0}
# {'parody': 6.0}
# {'pleasantry': 8.0}
# {'polarization': 7.0}
# {'preseason': 6.0}
# {'retraining': 7.0}
# {'temper': 8.0}
# {'twinge': 5.0}
# {'weekender': 10.0}
# {'zealot': 9.0}
# {'aficionado': 12.0}
# {'brainchild': 7.0}
# {'brainstorm': 8.0}
# {'consistency': 4.0}
# {'counterproposal': 5.0}
# {'critique': 6.0}
# {'cutthroat': 14.0}
# {'fluidity': 6.0}
# {'hypocrite': 11.0}
# {'ladylove': 10.0}
# {'lifespan': 5.0}
# {'minimalist': 10.0}
# {'monarchy': 6.0}
# {'namesake': 8.0}
# {'parenthood': 6.0}
# {'payback': 10.0}
# {'ratio': 4.0}
# {'reappearance': 6.0}
# {'resource': 5.0}
# {'sadism': 7.0}
# {'spoilsport': 9.0}
# {'stupidity': 5.0}
# {'victory': 7.0}
# {'womanhood': 6.0}
# {'abandonment': 6.0}
# {'adventuress': 9.0}
# {'array': 4.0}
# {'bebop': 9.0}
# {'career': 7.0}
# {'charmer': 12.0}
# {'classics': 9.0}
# {'configuration': 7.0}
# {'conquest': 7.0}
# {'cyberspace': 9.0}
# {'darling': 9.0}
# {'deadliness': 5.0}
# {'disarmament': 8.0}
# {'discrepancy': 5.0}
# {'equalizer': 8.0}
# {'expansionism': 7.0}
# {'expression': 6.0}
# {'flub': 7.0}
# {'flux': 5.0}
# {'goodwill': 6.0}
# {'goof': 10.0}
# {'gravitation': 8.0}
# {'humanist': 10.0}
# {'hussy': 11.0}
# {'indexing': 8.0}
# {'inebriate': 11.0}
# {'inflation': 4.0}
# {'installment': 8.0}
# {'isolation': 5.0}
# {'jive': 9.0}
# {'latitude': 11.0}
# {'legislature': 6.0}
# {'limelight': 7.0}
# {'magnetism': 8.0}
# {'majority': 7.0}
# {'miss': 11.0}
# {'mistranslation': 8.0}
# {'necromancy': 8.0}
# {'pessimist': 10.0}
# {'plurality': 4.0}
# {'poverty': 6.0}
# {'pronunciation': 5.0}
# {'punctuality': 7.0}
# {'quitter': 8.0}
# {'rationing': 7.0}
# {'rite': 8.0}
# {'romanticist': 8.0}
# {'sexiness': 7.0}
# {'society': 4.0}
# {'stewardship': 8.0}
# {'sweetie': 9.0}
# {'theorist': 9.0}
# {'thinker': 9.0}
# {'verbiage': 5.0}
# {'childhood': 6.0}
# {'commandment': 7.0}
# {'confrontation': 7.0}
# {'dominance': 5.0}
# {'endorsement': 5.0}
# {'espionage': 10.0}
# {'gradation': 6.0}
# {'instrumentation': 5.0}
# {'nonconformist': 11.0}
# {'sisterhood': 4.0}
# {'whippersnapper': 10.0}
# {'abstractionist': 11.0}
# {'acquirer': 8.0}
# {'advisement': 8.0}
# {'authorship': 9.0}
# {'classification': 7.0}
# {'claustrophobia': 11.0}
# {'concealment': 6.0}
# {'conglomerate': 9.0}
# {'conglomeration': 6.0}
# {'consortium': 6.0}
# {'cosmology': 10.0}
# {'courtship': 8.0}
# {'daze': 7.0}
# {'declaration': 5.0}
# {'declination': 5.0}
# {'density': 7.0}
# {'disobedience': 8.0}
# {'dissipation': 9.0}
# {'drawback': 7.0}
# {'egoist': 10.0}
# {'eroticism': 8.0}
# {'fore': 8.0}
# {'fright': 6.0}
# {'guise': 6.0}
# {'hellfire': 9.0}
# {'hotshot': 9.0}
# {'hyperacidity': 8.0}
# {'identifier': 5.0}
# {'import': 6.0}
# {'impulse': 4.0}
# {'innovator': 10.0}
# {'investigation': 9.0}
# {'ionization': 5.0}
# {'lethargy': 7.0}
# {'mathematics': 8.0}
# {'merrymaking': 8.0}
# {'metabolite': 4.0}
# {'niche': 7.0}
# {'occasion': 5.0}
# {'originator': 9.0}
# {'outlay': 9.0}
# {'pact': 11.0}
# {'pageantry': 7.0}
# {'peril': 4.0}
# {'practice': 6.0}
# {'prohibition': 8.0}
# {'purgatory': 7.0}
# {'quickness': 5.0}
# {'reflectivity': 7.0}
# {'requirement': 8.0}
# {'ruckus': 9.0}
# {'scapegoat': 10.0}
# {'sobriety': 5.0}
# {'substitution': 7.0}
# {'threat': 4.0}
# {'wholeness': 4.0}
# {'windfall': 14.0}
# {'marriage': 7.0}
# {'accomplishment': 6.0}
# {'adulthood': 6.0}
# {'affiliate': 10.0}
# {'aftereffect': 5.0}
# {'alliance': 6.0}
# {'assortment': 4.0}
# {'astronautics': 10.0}
# {'beginning': 5.0}
# {'changeling': 9.0}
# {'con': 6.0}
# {'criteria': 4.0}
# {'detail': 6.0}
# {'detoxification': 9.0}
# {'dimension': 5.0}
# {'dissident': 8.0}
# {'enslavement': 6.0}
# {'flashiness': 6.0}
# {'folklore': 6.0}
# {'frigidity': 5.0}
# {'horror': 7.0}
# {'imminence': 4.0}
# {'incorporation': 10.0}
# {'infraction': 9.0}
# {'input': 4.0}
# {'interim': 4.0}
# {'mind': 4.0}
# {'mishap': 5.0}
# {'momentum': 7.0}
# {'neurology': 11.0}
# {'otherworld': 2.0}
# {'pastime': 7.0}
# {'patient': 11.0}
# {'peewee': 9.0}
# {'protection': 6.0}
# {'rate': 4.0}
# {'readership': 5.0}
# {'reelection': 8.0}
# {'reexamination': 9.0}
# {'refresher': 11.0}
# {'riddle': 7.0}
# {'sequestration': 7.0}
# {'slowdown': 7.0}
# {'sociopath': 11.0}
# {'uncleanness': 6.0}
# {'usurper': 10.0}
# {'abnormality': 6.0}
# {'advent': 8.0}
# {'airhead': 9.0}
# {'astrology': 9.0}
# {'automation': 12.0}
# {'benchmark': 5.0}
# {'biddy': 13.0}
# {'bonding': 5.0}
# {'boon': 7.0}
# {'breach': 9.0}
# {'brink': 6.0}
# {'brutality': 8.0}
# {'clearness': 5.0}
# {'command': 6.0}
# {'counsel': 11.0}
# {'defect': 5.0}
# {'deliciousness': 7.0}
# {'dependant': 10.0}
# {'detachment': 7.0}
# {'dissenter': 8.0}
# {'dramatization': 10.0}
# {'elopement': 6.0}
# {'enforcement': 7.0}
# {'erasure': 7.0}
# {'exasperation': 8.0}
# {'excise': 9.0}
# {'excitement': 7.0}
# {'exclamation': 5.0}
# {'feedback': 4.0}
# {'fetish': 7.0}
# {'gawkiness': 7.0}
# {'governorship': 8.0}
# {'homestretch': 7.0}
# {'horsepower': 7.0}
# {'illiteracy': 6.0}
# {'illusion': 7.0}
# {'imagery': 7.0}
# {'impairment': 6.0}
# {'inpatient': 12.0}
# {'interloper': 11.0}
# {'invalid': 10.0}
# {'lesbianism': 7.0}
# {'logistics': 7.0}
# {'misdemeanor': 9.0}
# {'motto': 6.0}
# {'ohm': 7.0}
# {'output': 7.0}
# {'outspokenness': 5.0}
# {'parameter': 9.0}
# {'physicality': 6.0}
# {'pretender': 10.0}
# {'probation': 6.0}
# {'pronoun': 7.0}
# {'propaganda': 5.0}
# {'recruitment': 7.0}
# {'retaliation': 7.0}
# {'runabout': 13.0}
# {'singleness': 9.0}
# {'slang': 6.0}
# {'subcontract': 12.0}
# {'symbiosis': 5.0}
# {'syndrome': 9.0}
# {'tactics': 8.0}
# {'thingamajig': 4.0}
# {'trailblazer': 10.0}
# {'transgression': 7.0}
# {'upheaval': 5.0}
# {'vibes': 9.0}
# {'barrenness': 7.0}
# {'confidentiality': 7.0}
# {'fib': 7.0}
# {'interjection': 6.0}
# {'morbidity': 7.0}
# {'queasiness': 8.0}
# {'rendering': 7.0}
# {'tardiness': 7.0}
# {'termination': 5.0}
# {'truce': 6.0}
# {'accolade': 5.0}
# {'alternative': 7.0}
# {'apparition': 8.0}
# {'boaster': 11.0}
# {'compiler': 10.0}
# {'conversion': 7.0}
# {'deadbeat': 9.0}
# {'denial': 6.0}
# {'desecration': 10.0}
# {'distraction': 8.0}
# {'dynasty': 8.0}
# {'evasion': 7.0}
# {'exposition': 7.0}
# {'fandom': 5.0}
# {'flair': 8.0}
# {'fraternity': 7.0}
# {'gaffe': 8.0}
# {'guidance': 4.0}
# {'harmony': 6.0}
# {'impersonation': 5.0}
# {'intonation': 6.0}
# {'maxim': 6.0}
# {'mode': 4.0}
# {'occlusion': 8.0}
# {'outpouring': 4.0}
# {'phase': 5.0}
# {'prerequisite': 8.0}
# {'psychopathology': 9.0}
# {'punishment': 7.0}
# {'putridity': 6.0}
# {'racketeering': 10.0}
# {'rapidity': 6.0}
# {'separateness': 5.0}
# {'shortage': 7.0}
# {'soundings': 7.0}
# {'stickler': 13.0}
# {'tanginess': 6.0}
# {'therapeutics': 12.0}
# {'thrill': 8.0}
# {'uniformity': 5.0}
# {'upsides': 9.0}
# {'variation': 6.0}
# {'vernacular': 6.0}
# {'adherent': 9.0}
# {'affair': 10.0}
# {'authorization': 7.0}
# {'companionship': 6.0}
# {'defense': 7.0}
# {'enactment': 9.0}
# {'homespun': 6.0}
# {'homonym': 6.0}
# {'motif': 7.0}
# {'muse': 9.0}
# {'noncombatant': 11.0}
# {'observance': 9.0}
# {'outrage': 7.0}
# {'overproduction': 11.0}
# {'relief': 7.0}
# {'specification': 6.0}
# {'summarization': 8.0}
# {'verification': 7.0}
# {'wording': 5.0}
# {'zoning': 10.0}
# {'amendment': 10.0}
# {'commendation': 6.0}
# {'congratulations': 5.0}
# {'demeanor': 4.0}
# {'depopulation': 6.0}
# {'drudge': 9.0}
# {'emotion': 5.0}
# {'exertion': 8.0}
# {'feat': 7.0}
# {'fibber': 12.0}
# {'fragmentation': 10.0}
# {'highness': 10.0}
# {'homeostasis': 6.0}
# {'hypersensitivity': 7.0}
# {'immodesty': 7.0}
# {'insurgency': 8.0}
# {'klutz': 10.0}
# {'municipality': 9.0}
# {'necrophilia': 6.0}
# {'nonviolence': 9.0}
# {'pacifist': 9.0}
# {'participle': 9.0}
# {'peacetime': 5.0}
# {'plasticity': 5.0}
# {'pomp': 6.0}
# {'pubescence': 6.0}
# {'resurvey': 10.0}
# {'spunk': 6.0}
# {'stimulation': 9.0}
# {'traditionalist': 10.0}
# {'twerp': 9.0}
# {'unsteadiness': 6.0}
# {'upkeep': 10.0}
# {'abolition': 9.0}
# {'adjective': 8.0}
# {'buyout': 7.0}
# {'cause': 7.0}
# {'composure': 6.0}
# {'description': 5.0}
# {'diagnoses': 8.0}
# {'embarrassment': 6.0}
# {'extinction': 5.0}
# {'fuss': 7.0}
# {'giddiness': 5.0}
# {'hubbub': 7.0}
# {'inertia': 4.0}
# {'leadership': 6.0}
# {'magnitude': 4.0}
# {'meanie': 11.0}
# {'orientation': 7.0}
# {'overage': 5.0}
# {'oxygenation': 4.0}
# {'persecution': 9.0}
# {'phantom': 8.0}
# {'plainness': 6.0}
# {'ranking': 6.0}
# {'referral': 9.0}
# {'sabbatical': 7.0}
# {'specialty': 5.0}
# {'terror': 7.0}
# {'vindicator': 9.0}
# {'weariness': 5.0}
# {'wrongdoing': 6.0}
# {'bourgeoisie': 5.0}
# {'curate': 11.0}
# {'deportation': 7.0}
# {'edibility': 4.0}
# {'geriatrics': 12.0}
# {'idiom': 5.0}
# {'killjoy': 9.0}
# {'mania': 5.0}
# {'multitude': 5.0}
# {'neatness': 7.0}
# {'neurobiology': 11.0}
# {'ownership': 3.0}
# {'probate': 7.0}
# {'recession': 6.0}
# {'rendition': 7.0}
# {'sexploitation': 9.0}
# {'showmanship': 6.0}
# {'signifier': 6.0}
# {'starvation': 8.0}
# {'tackiness': 6.0}
# {'tautness': 5.0}
# {'tenure': 6.0}
# {'trend': 7.0}
# {'vow': 6.0}
# {'wrath': 8.0}
# {'activation': 5.0}
# {'acuteness': 8.0}
# {'anger': 6.0}
# {'anthropology': 9.0}
# {'barbarism': 11.0}
# {'childishness': 6.0}
# {'clerkship': 8.0}
# {'conservation': 8.0}
# {'contribution': 7.0}
# {'cure': 8.0}
# {'custodianship': 8.0}
# {'development': 9.0}
# {'emergency': 7.0}
# {'fault': 6.0}
# {'filibuster': 13.0}
# {'hell': 5.0}
# {'injunction': 7.0}
# {'memorization': 7.0}
# {'method': 6.0}
# {'modernization': 9.0}
# {'modifier': 7.0}
# {'neurosis': 8.0}
# {'overexposure': 10.0}
# {'overtone': 5.0}
# {'pathology': 11.0}
# {'precision': 6.0}
# {'reaction': 5.0}
# {'realness': 6.0}
# {'reminder': 4.0}
# {'repertoire': 4.0}
# {'requisition': 6.0}
# {'scheme': 8.0}
# {'sensationalist': 10.0}
# {'sleaze': 6.0}
# {'snub': 7.0}
# {'stability': 7.0}
# {'stalemate': 7.0}
# {'subset': 3.0}
# {'syndication': 10.0}
# {'toughness': 6.0}
# {'undoing': 8.0}
# {'uprising': 7.0}
# {'adaption': 4.0}
# {'celibacy': 5.0}
# {'confession': 6.0}
# {'disappearance': 6.0}
# {'disarray': 7.0}
# {'inspirer': 9.0}
# {'monstrosity': 7.0}
# {'nincompoop': 9.0}
# {'nymphomania': 7.0}
# {'personage': 8.0}
# {'prospect': 7.0}
# {'remembrance': 7.0}
# {'schmuck': 11.0}
# {'stillness': 6.0}
# {'technique': 7.0}
# {'toxicology': 13.0}
# {'undertone': 6.0}
# {'brilliance': 7.0}
# {'candidacy': 10.0}
# {'closeness': 7.0}
# {'clumsiness': 6.0}
# {'compartmentalization': 7.0}
# {'confirmation': 7.0}
# {'corruption': 7.0}
# {'curse': 6.0}
# {'depression': 6.0}
# {'disruption': 7.0}
# {'doublespeak': 8.0}
# {'doubter': 9.0}
# {'egomaniac': 11.0}
# {'exposure': 6.0}
# {'fineness': 7.0}
# {'forte': 5.0}
# {'friendship': 5.0}
# {'id': 8.0}
# {'inducer': 6.0}
# {'info': 4.0}
# {'juxtaposition': 7.0}
# {'kinetics': 11.0}
# {'manifestation': 6.0}
# {'option': 8.0}
# {'plea': 8.0}
# {'poise': 6.0}
# {'prude': 10.0}
# {'recognition': 6.0}
# {'redundancy': 6.0}
# {'remittance': 8.0}
# {'standstill': 7.0}
# {'submergence': 9.0}
# {'triangulation': 11.0}
# {'whereabouts': 4.0}
# {'wildness': 6.0}
# {'accusation': 7.0}
# {'acquittal': 9.0}
# {'agility': 7.0}
# {'agony': 7.0}
# ...
# {'consideration': 7.0}
# {'corruptness': 7.0}
# {'deception': 6.0}
# {'derivation': 6.0}
# {'dread': 7.0}
# {'faithlessness': 5.0}
# {'finesse': 9.0}
# {'foreknowledge': 6.0}
# {'future': 4.0}
# {'gloom': 7.0}
# {'gracefulness': 6.0}
# {'hypotheses': 5.0}
# {'impulsiveness': 5.0}
# {'incompetency': 5.0}
# {'irregularity': 8.0}
# {'irresistibility': 5.0}
# {'mysticism': 14.0}
# {'nonintervention': 11.0}
# {'originality': 5.0}
# {'parallelism': 6.0}
# {'polytheism': 15.0}
# {'positivity': 5.0}
# {'profitability': 7.0}
# {'reckoning': 8.0}
# {'sensationalism': 4.0}
# {'simplification': 6.0}
# {'snappishness': 7.0}
# {'soul': 5.0}
# {'suspiciousness': 5.0}
# {'transference': 11.0}
# {'usefulness': 4.0}
# {'accuracy': 4.0}
# {'approximation': 9.0}
# {'aversion': 6.0}
# {'backlash': 6.0}
# {'coefficient': 6.0}
# {'colonialism': 9.0}
# {'connectedness': 5.0}
# {'crudeness': 5.0}
# {'designation': 6.0}
# {'displeasure': 12.0}
# {'divination': 6.0}
# {'exception': 9.0}
# {'expectancy': 6.0}
# {'geniality': 7.0}
# {'geopolitics': 10.0}
# {'humanities': 7.0}
# {'illegibility': 5.0}
# {'impracticality': 5.0}
# {'indifference': 6.0}
# {'liberty': 6.0}
# {'meaning': 4.0}
# {'morale': 6.0}
# {'narcissism': 5.0}
# {'nuance': 5.0}
# {'ordinariness': 4.0}
# {'presumption': 9.0}
# {'reassurance': 8.0}
# {'sanity': 7.0}
# {'secession': 8.0}
# {'sin': 6.0}
# {'suspense': 8.0}
# {'synchronicity': 4.0}
# {'valor': 7.0}
# {'virility': 8.0}
# {'wannabe': 9.0}
# {'whimsy': 6.0}
# {'assumption': 7.0}
# {'awareness': 7.0}
# {'circumspection': 8.0}
# {'eccentricity': 8.0}
# {'estrangement': 6.0}
# {'foulness': 6.0}
# {'generosity': 7.0}
# {'implementation': 8.0}
# {'insubordination': 6.0}
# {'mismanagement': 8.0}
# {'permanence': 6.0}
# {'perpetuity': 7.0}
# {'preparedness': 4.0}
# {'rapport': 4.0}
# {'temptation': 7.0}
# {'variance': 8.0}
# {'acclimatization': 5.0}
# {'affront': 8.0}
# {'basis': 4.0}
# {'calmness': 6.0}
# {'constancy': 5.0}
# {'contemplation': 10.0}
# {'debut': 9.0}
# {'diabolism': 9.0}
# {'directionality': 7.0}
# {'disdain': 6.0}
# {'enrichment': 9.0}
# {'esteem': 7.0}
# {'fairness': 11.0}
# {'fascism': 7.0}
# {'humdinger': 11.0}
# {'impoliteness': 7.0}
# {'inexperience': 6.0}
# {'invalidation': 10.0}
# {'letdown': 9.0}
# {'lonesomeness': 6.0}
# {'magnificence': 5.0}
# {'mightiness': 5.0}
# {'misgiving': 7.0}
# {'nostalgia': 7.0}
# {'overcompensation': 11.0}
# {'pacifism': 7.0}
# {'prerogative': 9.0}
# {'psychophysiology': 9.0}
# {'reliability': 6.0}
# {'sanctimony': 10.0}
# {'tendency': 5.0}
# {'unseemliness': 7.0}
# {'aspect': 9.0}
# {'contempt': 6.0}
# {'convolution': 5.0}
# {'dissolution': 4.0}
# {'forgetfulness': 8.0}
# {'fruition': 5.0}
# {'hearsay': 9.0}
# {'indecisiveness': 8.0}
# {'mercifulness': 7.0}
# {'predicament': 6.0}
# {'prevalence': 5.0}
# {'riddance': 10.0}
# {'sadness': 5.0}
# {'straightforwardness': 6.0}
# {'thoughtlessness': 7.0}
# {'uneasiness': 7.0}
# {'vagueness': 6.0}
# {'ability': 4.0}
# {'alpha': 8.0}
# {'anticlimax': 9.0}
# {'aspiration': 6.0}
# {'causation': 5.0}
# {'characterization': 6.0}
# {'competency': 5.0}
# {'digression': 4.0}
# {'divisibility': 4.0}
# {'facilitation': 5.0}
# {'feasibility': 6.0}
# {'gist': 5.0}
# {'heaven': 5.0}
# {'heredity': 4.0}
# {'humanism': 7.0}
# {'humanization': 9.0}
# {'immaturity': 4.0}
# {'indulgence': 5.0}
# {'inquisitiveness': 8.0}
# {'levity': 5.0}
# {'maturity': 6.0}
# {'nonchalance': 7.0}
# {'outrageousness': 7.0}
# {'overconfidence': 8.0}
# {'permissiveness': 6.0}
# {'powerlessness': 4.0}
# {'pretension': 6.0}
# {'quirkiness': 8.0}
# {'rehabilitation': 11.0}
# {'repugnance': 7.0}
# {'selectivity': 4.0}
# {'spiritualism': 8.0}
# {'sufficiency': 7.0}
# {'truthfulness': 7.0}
# {'unwieldiness': 6.0}
# {'viciousness': 8.0}
# {'willingness': 6.0}
# {'creativity': 5.0}
# {'effect': 4.0}
# {'epitome': 7.0}
# {'experience': 6.0}
# {'fallacy': 7.0}
# {'insolence': 7.0}
# {'interest': 8.0}
# {'jealousy': 10.0}
# {'misbehavior': 7.0}
# {'pizzazz': 5.0}
# {'theatricality': 6.0}
# {'unwillingness': 6.0}
# {'activism': 9.0}
# {'allegation': 8.0}
# {'anomaly': 7.0}
# {'believability': 4.0}
# {'censorship': 10.0}
# {'cognition': 3.0}
# {'compulsion': 6.0}
# {'compulsiveness': 4.0}
# {'conformity': 7.0}
# {'dogma': 8.0}
# {'edification': 7.0}
# {'enigma': 9.0}
# {'entitlement': 11.0}
# {'evasiveness': 11.0}
# {'foreignness': 4.0}
# {'foresight': 14.0}
# {'gayness': 6.0}
# {'hardship': 7.0}
# {'incompatibility': 5.0}
# {'ineptitude': 6.0}
# {'inflection': 5.0}
# {'issuance': 7.0}
# {'loftiness': 7.0}
# {'logics': 9.0}
# {'malpractice': 7.0}
# {'meaninglessness': 4.0}
# {'monotony': 7.0}
# {'newness': 5.0}
# {'omniscience': 4.0}
# {'pluralism': 5.0}
# {'politeness': 7.0}
# {'regard': 7.0}
# {'respectability': 7.0}
# {'socialization': 6.0}
# {'sociology': 9.0}
# {'soulfulness': 5.0}
# {'suggestibility': 6.0}
# {'understatement': 5.0}
# {'unpopularity': 4.0}
# {'worldliness': 4.0}
# {'absolution': 5.0}
# {'capitulation': 6.0}
# {'closure': 9.0}
# {'competence': 5.0}
# {'comprehension': 8.0}
# {'crossness': 7.0}
# {'cynicism': 7.0}
# {'democracy': 7.0}
# {'disparity': 6.0}
# {'gratification': 7.0}
# {'inception': 6.0}
# {'interconnectedness': 6.0}
# {'lowness': 5.0}
# {'nationalism': 6.0}
# {'receptivity': 7.0}
# {'resentment': 8.0}
# {'stinginess': 4.0}
# {'vitality': 8.0}
# {'worthiness': 5.0}
# {'abstinent': 8.0}
# {'allegiance': 7.0}
# {'antimatter': 3.0}
# {'circumstance': 5.0}
# {'committal': 9.0}
# {'courtesy': 7.0}
# {'detriment': 7.0}
# {'disservice': 8.0}
# {'economics': 9.0}
# {'fundamentalism': 16.0}
# {'impunity': 7.0}
# {'legality': 5.0}
# {'normalcy': 5.0}
# {'oddness': 5.0}
# {'powers': 4.0}
# {'preciousness': 8.0}
# {'respite': 7.0}
# {'safeness': 5.0}
# {'sensitivity': 7.0}
# {'supposition': 5.0}
# {'assurance': 8.0}
# {'betrayal': 8.0}
# {'carelessness': 5.0}
# {'conspiracy': 6.0}
# {'disinterestedness': 7.0}
# {'dormancy': 5.0}
# {'ferocity': 6.0}
# {'hideousness': 6.0}
# {'humbleness': 7.0}
# {'lunacy': 8.0}
# {'methodology': 10.0}
# {'misadventure': 7.0}
# {'pacification': 8.0}
# {'parapsychology': 4.0}
# {'pretense': 9.0}
# {'priority': 6.0}
# {'repute': 7.0}
# {'severity': 6.0}
# {'sociability': 6.0}
# {'stigma': 8.0}
# {'tact': 8.0}
# {'wits': 6.0}
# {'absentmindedness': 8.0}
# {'aloneness': 6.0}
# {'conjecture': 8.0}
# {'contention': 7.0}
# {'defeatism': 7.0}
# {'elitism': 7.0}
# {'humility': 4.0}
# {'hype': 5.0}
# {'idiocy': 7.0}
# {'importance': 6.0}
# {'imprecision': 6.0}
# {'infamy': 7.0}
# {'infantilism': 7.0}
# {'libertarianism': 7.0}
# {'mood': 5.0}
# {'mutuality': 4.0}
# {'purposefulness': 9.0}
# {'quandary': 6.0}
# {'recalcitrance': 5.0}
# {'relativism': 8.0}
# {'retrospect': 9.0}
# {'uncertainty': 4.0}
# {'ambition': 6.0}
# {'arrogance': 11.0}
# {'authenticity': 5.0}
# {'commitment': 5.0}
# {'commonality': 5.0}
# {'commonness': 6.0}
# {'defensiveness': 6.0}
# {'dissonance': 5.0}
# {'ego': 6.0}
# {'euphemism': 6.0}
# {'gumption': 8.0}
# {'idiosyncrasy': 6.0}
# {'kindness': 6.0}
# {'listlessness': 6.0}
# {'naivety': 4.0}
# {'nonentity': 5.0}
# {'nothingness': 6.0}
# {'paranoia': 8.0}
# {'personification': 8.0}
# {'pettiness': 7.0}
# {'snobbery': 12.0}
# {'willfulness': 5.0}
# {'alienation': 6.0}
# {'appeal': 7.0}
# {'dreamland': 8.0}
# {'extravagance': 7.0}
# {'guiltiness': 5.0}
# {'inconvenience': 6.0}
# {'insignificance': 7.0}
# {'knowledge': 3.0}
# {'likelihood': 5.0}
# {'paradigm': 6.0}
# {'possessiveness': 8.0}
# {'purity': 5.0}
# {'regularization': 5.0}
# {'reorientation': 6.0}
# {'savagery': 7.0}
# {'sentimentality': 5.0}
# {'succession': 6.0}
# {'unworthiness': 5.0}
# {'wariness': 7.0}
# {'abstinence': 6.0}
# {'ambience': 5.0}
# {'cheapness': 8.0}
# {'dishonor': 6.0}
# {'faithfulness': 4.0}
# {'forthrightness': 7.0}
# {'gutlessness': 8.0}
# {'insight': 5.0}
# {'liberalism': 7.0}
# {'logic': 9.0}
# {'malice': 8.0}
# {'partiality': 6.0}
# {'reality': 6.0}
# {'sacredness': 5.0}
# {'subjunctive': 6.0}
# {'thankfulness': 6.0}
# {'unfaithfulness': 4.0}
# {'virtuosity': 6.0}
# {'wickedness': 8.0}
# {'appeasement': 7.0}
# {'coercion': 8.0}
# {'comprehensiveness': 6.0}
# {'determinist': 12.0}
# {'expressionism': 6.0}
# {'graciousness': 7.0}
# {'leniency': 6.0}
# {'religion': 13.0}
# {'reproach': 7.0}
# {'retentiveness': 6.0}
# {'standpoint': 6.0}
# {'ambivalence': 5.0}
# {'complicity': 6.0}
# {'concern': 9.0}
# {'copout': 9.0}
# {'desire': 5.0}
# {'determination': 6.0}
# {'exploitation': 7.0}
# {'inadequacy': 6.0}
# {'incapacity': 5.0}
# {'incongruity': 6.0}
# {'intention': 6.0}
# {'isolationism': 11.0}
# {'materialism': 8.0}
# {'maximization': 9.0}
# {'monogamy': 8.0}
# {'obsession': 5.0}
# {'past': 4.0}
# {'practicality': 5.0}
# {'preconception': 7.0}
# {'principle': 7.0}
# {'relativity': 10.0}
# {'reverence': 6.0}
# {'secretiveness': 7.0}
# {'semantics': 9.0}
# {'spontaneity': 5.0}
# {'subjection': 5.0}
# {'underachievement': 8.0}
# {'unselfishness': 8.0}
# {'version': 7.0}
# {'applicability': 5.0}
# {'clairvoyance': 5.0}
# {'conscientiousness': 6.0}
# {'creationism': 7.0}
# {'eagerness': 6.0}
# {'greatness': 7.0}
# {'hesitance': 9.0}
# {'hilarity': 7.0}
# {'illegitimacy': 5.0}
# {'imagination': 6.0}
# {'inequity': 7.0}
# {'loathsomeness': 6.0}
# {'neuroses': 8.0}
# {'offensiveness': 5.0}
# {'phraseology': 5.0}
# {'pureness': 5.0}
# {'statesmanship': 5.0}
# {'sustainability': 4.0}
# {'thoughtfulness': 8.0}
# {'tradition': 5.0}
# {'treachery': 6.0}
# {'versatility': 5.0}
# {'whim': 6.0}
# {'accountancy': 7.0}
# {'apprehension': 7.0}
# {'bias': 7.0}
# {'congruity': 7.0}
# {'contestation': 8.0}
# {'disillusionment': 8.0}
# {'dumbness': 6.0}
# {'fraud': 9.0}
# {'furtherance': 6.0}
# {'godlessness': 7.0}
# {'honor': 5.0}
# {'imposition': 8.0}
# {'incarnation': 9.0}
# {'indiscipline': 4.0}
# {'ingenuity': 6.0}
# {'judgment': 7.0}
# {'meekness': 6.0}
# {'obliviousness': 10.0}
# {'oxymoron': 7.0}
# {'renown': 7.0}
# {'significance': 7.0}
# {'trepidation': 8.0}
# {'tyranny': 6.0}
# {'vindictiveness': 8.0}
# {'volition': 6.0}
# {'amateurism': 7.0}
# {'authoritarianism': 6.0}
# {'bullheadedness': 5.0}
# {'destiny': 5.0}
# {'extremism': 7.0}
# {'finality': 7.0}
# {'fixation': 7.0}
# {'formality': 7.0}
# {'heathenism': 14.0}
# {'hopelessness': 6.0}
# {'instigation': 6.0}
# {'intuition': 6.0}
# {'mystique': 5.0}
# {'pretence': 6.0}
# {'righteousness': 5.0}
# {'surliness': 7.0}
# {'taboo': 8.0}
# {'unfairness': 7.0}
# {'wholesomeness': 4.0}
# {'earnestness': 6.0}
# {'essence': 5.0}
# {'exuberance': 8.0}
# {'fondness': 6.0}
# {'merit': 5.0}
# {'patience': 7.0}
# {'pride': 5.0}
# {'repression': 6.0}
# {'admissibility': 6.0}
# {'disenfranchisement': 8.0}
# {'disinclination': 6.0}
# {'disrepute': 7.0}
# {'fatalism': 6.0}
# {'inference': 8.0}
# {'poignancy': 9.0}
# {'probability': 3.0}
# {'prodigal': 10.0}
# {'timelessness': 5.0}
# {'veneration': 6.0}
# {'amorality': 4.0}
# {'bureaucracy': 7.0}
# {'chance': 6.0}
# {'expertise': 5.0}
# {'idealism': 8.0}
# {'improbability': 5.0}
# {'liberalization': 10.0}
# {'martyrdom': 7.0}
# {'prosperity': 6.0}
# {'readiness': 4.0}
# {'reputation': 7.0}
# {'shrewdness': 6.0}
# {'tastelessness': 7.0}
# {'unlikelihood': 6.0}
# {'appreciation': 8.0}
# {'benevolence': 7.0}
# {'empathy': 6.0}
# {'enchantment': 6.0}
# {'faith': 13.0}
# {'industriousness': 6.0}
# {'insinuation': 9.0}
# {'mystification': 8.0}
# {'neutrality': 7.0}
# {'obscurity': 5.0}
# {'passivism': 7.0}
# {'perceptiveness': 7.0}
# {'pragmatism': 8.0}
# {'precedent': 6.0}
# {'randomness': 5.0}
# {'rationality': 8.0}
# {'reincarnation': 10.0}
# {'risk': 4.0}
# {'sarcasm': 5.0}
# {'adventurousness': 9.0}
# {'audacity': 9.0}
# {'civility': 7.0}
# {'expectation': 6.0}
# {'fanaticism': 6.0}
# {'general': 15.0}
# {'hatefulness': 6.0}
# {'ideology': 6.0}
# {'imperceptibility': 5.0}
# {'inconceivability': 7.0}
# {'indecision': 8.0}
# {'invariance': 5.0}
# {'manner': 4.0}
# {'materialization': 4.0}
# {'objectification': 9.0}
# {'otherness': 5.0}
# {'peace': 5.0}
# {'privatization': 7.0}
# {'relevancy': 4.0}
# {'serendipity': 6.0}
# {'serenity': 7.0}
# {'suspicion': 7.0}
# {'value': 9.0}
# {'virtue': 6.0}
# {'analogy': 9.0}
# {'brashness': 6.0}
# {'candidness': 7.0}
# {'curiosity': 7.0}
# {'idea': 5.0}
# {'illicitness': 5.0}
# {'implication': 9.0}
# {'indiscretion': 5.0}
# {'moment': 4.0}
# {'panache': 5.0}
# {'prestige': 6.0}
# {'sexism': 8.0}
# {'discretion': 6.0}
# {'epiphany': 7.0}
# {'flimflam': 11.0}
# {'ignorance': 5.0}
# {'imprudence': 7.0}
# {'passivity': 5.0}
# {'quaintness': 7.0}
# {'ruthlessness': 6.0}
# {'sordidness': 7.0}
# {'spirit': 4.0}
# {'susceptibility': 5.0}
# {'vindication': 9.0}
# {'actualization': 8.0}
# {'assuredness': 7.0}
# {'certainty': 7.0}
# {'circumstances': 5.0}
# {'complacency': 8.0}
# {'dehumanization': 9.0}
# {'dispassion': 5.0}
# {'ethic': 9.0}
# {'fakery': 9.0}
# {'fantasy': 7.0}
# {'honesty': 6.0}
# {'irony': 5.0}
# {'keenness': 6.0}
# {'lovesickness': 8.0}
# {'misappropriation': 11.0}
# {'perversity': 6.0}
# {'reconsideration': 8.0}
# {'splendor': 7.0}
# {'territoriality': 7.0}
# {'vileness': 6.0}
# {'wonderfulness': 5.0}
# {'wont': 6.0}
# {'worthlessness': 4.0}
# {'allusion': 7.0}
# {'blessedness': 8.0}
# {'concordance': 5.0}
# {'ethos': 3.0}
# {'exponential': 5.0}
# {'fallibility': 7.0}
# {'omnipotence': 4.0}
# {'prudence': 12.0}
# {'relevance': 4.0}
# {'senselessness': 9.0}
# {'subservience': 5.0}
# {'suitability': 4.0}
# {'abstraction': 7.0}
# {'accord': 6.0}
# {'coincidence': 6.0}
# {'discernment': 7.0}
# {'eventuality': 5.0}
# {'humbug': 5.0}
# {'inefficiency': 6.0}
# {'inhumanity': 4.0}
# {'loyalty': 5.0}
# {'mercy': 13.0}
# {'misapprehension': 7.0}
# {'nonexistence': 5.0}
# {'oversight': 9.0}
# {'persuasiveness': 5.0}
# {'repentance': 8.0}
# {'ruse': 10.0}
# {'subconscious': 5.0}
# {'brainpower': 6.0}
# {'contrary': 4.0}
# {'damnation': 7.0}
# {'escapism': 7.0}
# {'holiness': 4.0}
# {'inconsideration': 7.0}
# {'indignity': 9.0}
# {'ingratitude': 5.0}
# {'insincerity': 8.0}
# {'piety': 6.0}
# {'predominance': 6.0}
# {'presumptuousness': 8.0}
# {'radicalism': 7.0}
# {'unbelief': 5.0}
# {'accountability': 6.0}
# {'antipathy': 6.0}
# {'bleakness': 7.0}
# {'disenchantment': 8.0}
# {'impudence': 5.0}
# {'mindset': 5.0}
# {'misrepresentation': 6.0}
# {'resourcefulness': 6.0}
# {'affability': 7.0}
# {'aptitude': 5.0}
# {'endearment': 7.0}
# {'existence': 4.0}
# {'foreboding': 8.0}
# {'godsend': 5.0}
# {'happenstance': 6.0}
# {'imperativeness': 8.0}
# {'nationalization': 6.0}
# {'overstatement': 7.0}
# {'paradox': 7.0}
# {'realization': 8.0}
# {'revenge': 7.0}
# {'subtlety': 5.0}
# {'synthesis': 5.0}
# {'aggravation': 8.0}
# {'fate': 5.0}
# {'greed': 7.0}
# {'wisdom': 5.0}
# {'changelessness': 8.0}
# {'courage': 6.0}
# {'egomania': 6.0}
# {'heyday': 5.0}
# {'idealist': 9.0}
# {'immortality': 7.0}
# {'impossibility': 6.0}
# {'inevitability': 5.0}
# {'insecurity': 6.0}
# {'intent': 6.0}
# {'justification': 6.0}
# {'oomph': 7.0}
# {'penance': 8.0}
# {'purpose': 6.0}
# {'rationalist': 9.0}
# {'sensibility': 8.0}
# {'specialness': 5.0}
# {'unhappiness': 5.0}
# {'unoriginality': 6.0}
# {'unreality': 5.0}
# {'vitalism': 8.0}
# {'absoluteness': 7.0}
# {'adherence': 8.0}
# {'altruism': 9.0}
# {'disloyalty': 5.0}
# {'doom': 6.0}
# {'enlightenment': 6.0}
# {'generality': 6.0}
# {'inappropriateness': 6.0}
# {'meaningfulness': 8.0}
# {'motive': 3.0}
# {'particulars': 6.0}
# {'privacy': 8.0}
# {'reaffirmation': 8.0}
# {'rhetoric': 4.0}
# {'seriousness': 6.0}
# {'stringency': 7.0}
# {'veracity': 8.0}
# {'beguilement': 7.0}
# {'docility': 5.0}
# {'egoism': 7.0}
# {'grandiosity': 4.0}
# {'gullibility': 5.0}
# {'inadvertence': 9.0}
# {'infallibility': 7.0}
# {'misanthropy': 7.0}
# {'objectivity': 5.0}
# {'optimism': 6.0}
# {'pathos': 4.0}
# {'randomization': 7.0}
# {'shamelessness': 9.0}
# {'synergy': 4.0}
# {'transcendence': 5.0}
# {'willpower': 5.0}
# {'euphoria': 8.0}
# {'morality': 4.0}
# {'theory': 8.0}
# {'deviousness': 6.0}
# {'discordance': 6.0}
# {'endlessness': 6.0}
# {'eternity': 4.0}
# {'involvement': 6.0}
# {'mortality': 7.0}
# {'romanticism': 7.0}
# {'existentialism': 8.0}
# {'glory': 7.0}
# {'incorruption': 7.0}
# {'justice': 10.0}
# {'adversity': 7.0}
# {'atonement': 11.0}
# {'cordiality': 7.0}
# {'extent': 5.0}
# {'forgiveness': 8.0}
# {'intangibility': 5.0}
# {'integrity': 4.0}
# {'neediness': 7.0}
# {'persistency': 6.0}
# {'plausibility': 5.0}
# {'selflessness': 9.0}
# {'uselessness': 4.0}
# {'impartiality': 6.0}
# {'unrighteousness': 5.0}
# {'adorability': 7.0}
# {'afterworld': 8.0}
# {'concept': 6.0}
# {'despondency': 7.0}
# {'equality': 5.0}
# {'godliness': 7.0}
# {'oppressiveness': 7.0}
# {'sublimity': 8.0}
# {'symbolism': 5.0}
# {'tenacity': 6.0}
# {'wrongness': 6.0}
# {'idealization': 10.0}
# {'injustice': 7.0}
# {'interpretation': 6.0}
# {'legacy': 8.0}
# {'responsibility': 7.0}
# {'indeterminacy': 5.0}
# {'lenience': 6.0}
# {'reasoning': 7.0}
# {'unconventionality': 6.0}
# {'adaptability': 5.0}
# {'austerity': 6.0}
# {'goodness': 4.0}
# {'justness': 8.0}
# {'limitlessness': 4.0}
# {'potentiality': 6.0}
# {'principles': 7.0}
# {'bliss': 7.0}
# {'oblivion': 7.0}
# {'interpolation': 4.0}
# {'steadfastness': 6.0}
# {'introspection': 9.0}
# {'sanctity': 4.0}
# {'ungodliness': 7.0}
# {'utopianism': 7.0}
# {'vigilantism': 9.0}
# {'psyche': 4.0}
# {'degeneracy': 10.0}
# {'luck': 5.0}
# {'mediocrity': 5.0}
# {'possibility': 7.0}
# {'realism': 6.0}
# {'subjectivity': 5.0}
# {'morals': 4.0}
# {'ambiguity': 6.0}
# {'glorification': 7.0}
# {'inconsequence': 8.0}
# {'infinitive': 9.0}
# {'absurdity': 5.0}
# {'belief': 5.0}
# {'spirituality': 5.0}
# Printing output...
